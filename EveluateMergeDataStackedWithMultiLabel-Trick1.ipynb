# %%
import copy
import json
import random

import torch
import torch.nn as nn
import numpy as np
from torch.utils.data import Dataset
import torch.nn.functional as F
from torch.optim import Adam

from collections import Counter

from torch.optim.lr_scheduler import ReduceLROnPlateau
from torch.utils.data import DataLoader, Dataset, RandomSampler, SequentialSampler
from tqdm import tqdm_notebook as tqdm

from transformers import AutoTokenizer, AutoConfig, AutoModel

from crf_layer import CRFLayer
from multiLabelTokenClassfication import MultiLabelTokenClassification
from multiLabelSequenceClassfication import MultiLabelSequenceClassification

from stackedModel import MultiLabelStackedClassification

# %%
device_Id = "1"

shema_path = './dictionary/event_schema.json'
enerm_dict_path = './dictionary/enum_tag.dict'
trigger_dict_path = './dictionary/trigger_tag.dict'
role_dict_path = './dictionary/role_tag.dict'

enerm_stacked_model_path = './models/DuEE_fin/stacked/stacked_enum.dict'
tigger_stacked_model_path = './models/DuEE_fin/stacked/stacked_trigger-multilabel.dict'
role_stacked_model_path = './models/DuEE_fin/stacked/stacked_role-multilabel-trick1.dict'

duee_fin_dev_path = './resources/duee_fin_dev.json'
duee_fin_dev_preprocess_path = './resources/duee_fin_dev_preprocess.json'

enum_role = "环节"
enum_event_type = "公司上市"
max_seq_len = 512

# %%
def load_dict(dict_path):
    """load_dict"""
    vocab = {}
    for line in open(dict_path, 'r', encoding='utf-8'):
        value, key = line.strip('\n').split('\t')
        vocab[key] = int(value)
    return vocab

# %%
label_enum_vocab = load_dict(dict_path=enerm_dict_path)
id2enumlabel = {val: key for key, val in label_enum_vocab.items()}
label_trigger_vocab = load_dict(dict_path=trigger_dict_path)
id2triggerlabel = {val: key for key, val in label_trigger_vocab.items()}
label_role_vocab = load_dict(dict_path=role_dict_path)
id2rolelabel = {val: key for key, val in label_role_vocab.items()}

# %%
def enum_data_process(dataset):
    """enum_data_process"""
    output = []
    for d_json in dataset:
        text = d_json["text"].lower().replace("\t", " ")
        labels = []
        for event in d_json.get("event_list", []):
            if event["event_type"] != "公司上市":
                continue
            for argument in event["arguments"]:
                role_type = argument["role"]
                if role_type == enum_role and argument["argument"] not in labels:
                    labels.append(argument["argument"])
        if labels:
            output.append({
                "id": d_json["id"],
                "sent_id": d_json["sent_id"],
                "text": text,
                "labels": labels
            })
    return output

# %%
def trigger_data_process(dataset):
    """data_process"""
    
    def label_data(data, start, l, _type):
        """label_data"""
        for i in range(start, start + l):
            suffix = "B-" if i == start else "I-"
            if isinstance(data[i], str):
                data[i] = []
            solt = "{}{}".format(suffix, _type)
            if solt not in data[i]:
                data[i].append(solt)
        return data
    
    def replace_control_chars(str):
        if str == '\u200b' or str == '\ufeff' or str == '\ue601' or str == '\u3000':
            return '[UNK]'
        else:
            return str

    output = []
    for d_json in dataset:
        _id = d_json["id"]
        text_a = [
            "，" if t == " " or t == "\n" or t == "\t" else replace_control_chars(t)
            for t in list(d_json["text"].lower())
        ]
        labels = ["O"] * len(text_a)
        for event in d_json.get("event_list", []):
            event_type = event["event_type"]
            start = event["trigger_start_index"]
            trigger = event["trigger"]
            if start >= 0:
                labels = label_data(labels, start, len(trigger), event_type)
        output.append({
            "id": d_json["id"],
            "sent_id": d_json["sent_id"],
            "text": d_json["text"],
            "tokens": text_a,
            "labels": labels
        })
    return output

# %%
def role_data_process(dataset):
    """data_process"""
    
    def label_data(data, start, l, _type):
        """label_data"""
        for i in range(start, start + l):
            suffix = "B-" if i == start else "I-"
            if isinstance(data[i], str):
                data[i] = []
            solt = "{}{}".format(suffix, _type)
            if solt not in data[i]:
                data[i].append(solt)
        return data
    
    def replace_control_chars(str):
        if str == '\u200b' or str == '\ufeff' or str == '\ue601' or str == '\u3000':
            return '[UNK]'
        else:
            return str

    output = []
    for d_json in dataset:
        _id = d_json["id"]
        text_a = [
            "，" if t == " " or t == "\n" or t == "\t" else replace_control_chars(t)
            for t in list(d_json["text"].lower())
        ]
        if len(d_json.get("event_list", [])) == 0:
            continue
         ### combine same event type
        event_type_mapping = {}
        for event in d_json.get("event_list", []):
            event_type = event['event_type']
            trigger = event['trigger']
            type_tuple = (event_type, trigger)
            if type_tuple not in event_type_mapping:
                event_type_mapping[type_tuple] = []
            for argument in event["arguments"]:
                if argument not in event_type_mapping[type_tuple]:
                    event_type_mapping[type_tuple].append(argument)

        for type_tuple, arguments in event_type_mapping.items():
            event_type = type_tuple[0]
            trigger = type_tuple[1]
            trigger_text = event_type+f"({trigger})："
            labels = ["O"] * len(text_a)
            for arg in arguments:
                role_type = arg["role"]
                if role_type == enum_role:
                    continue
                argument = arg["argument"]
                start = arg["argument_start_index"]
                labels = label_data(labels, start, len(argument), role_type)
            text_a_trigger = [
                "，" if t == " " or t == "\n" or t == "\t" else t
                for t in list(trigger_text.lower())
            ]
            trigger_label = ["O"] * len(text_a_trigger)
            output.append({
                "id": d_json["id"],
                "sent_id": d_json["sent_id"],
                "text": trigger_text + d_json["text"],
                "event_type": event_type,
                "trigger": trigger,
                "tokens": text_a_trigger + text_a,
                "labels": trigger_label+labels
            })
    return output

# %%
model_dict = {
    'ernie-base': AutoTokenizer.from_pretrained("nghuyong/ernie-1.0"),
    'roberta-chinese-base': AutoTokenizer.from_pretrained("hfl/chinese-roberta-wwm-ext"),
    'roberta-chinese-large': AutoTokenizer.from_pretrained("hfl/chinese-roberta-wwm-ext-large"),
}

# %%
class BaiduEnermDataset(Dataset):
    
    def __init__(self, dataset_path, label_dict_path):
        self.label_vocab = load_dict(label_dict_path)
        self.label_num = max(self.label_vocab.values()) + 1
        self.examples = []
        with open(dataset_path, 'r', encoding='utf-8') as f:
            dataset = json.loads(f.read())
            preprocess_dataset = enum_data_process(dataset)
            for d_json in tqdm(preprocess_dataset, total=len(preprocess_dataset)):
                text = d_json['text']
                b_input_ids, b_attention_masks, b_token_type_ids = [], [], []
                for tokenizer in model_dict.values():
                    PADDING = tokenizer.vocab[tokenizer.pad_token]
                    SEP = tokenizer.vocab[tokenizer.sep_token]
                    input_ids = tokenizer(text, is_split_into_words=False, add_special_tokens=True, max_length=max_seq_len, truncation=True)['input_ids']
                    tokens_input = input_ids + [PADDING] * (max_seq_len - len(input_ids))
                    attention_masks = self._get_attention_mask(input_ids, max_seq_len)
                    token_type_ids = self._get_token_type_id(input_ids, max_seq_len, sep_token=SEP)
                    b_input_ids.append(tokens_input)
                    b_attention_masks.append(attention_masks)
                    b_token_type_ids.append(token_type_ids)
                example = {
                    "input_ids": b_input_ids, "attention_masks": b_attention_masks, "token_type_ids": b_token_type_ids
                }
                example.update(d_json)
                if 'labels' in d_json:
                    labels = self.to_one_hot_vector(d_json['labels'])
                    example.update({"encoded_label": labels})
                self.examples.append(example)
                
    def to_one_hot_vector(self, labels):
        """Convert seq to one hot."""
        one_hot_vector = np.zeros(self.label_num)
        for label in labels:
            one_hot_vector[self.label_vocab[label]] = 1
        return one_hot_vector
                
    def __len__(self):
        return len(self.examples)
    
    def __getitem__(self, item_idx):
        example = {
            "id": self.examples[item_idx]["id"],
            "sent_id": self.examples[item_idx]["sent_id"],
            "text": self.examples[item_idx]["text"],
            "input_ids": torch.tensor(self.examples[item_idx]["input_ids"]).long(),
            "attention_masks": torch.tensor(self.examples[item_idx]["attention_masks"]),
            "token_type_ids": torch.tensor(self.examples[item_idx]["token_type_ids"])
        }
        if "encoded_label" in self.examples[item_idx]:
            example.update({"encoded_label": torch.tensor(self.examples[item_idx]["encoded_label"], dtype=torch.float)})
        return example

    def _get_attention_mask(self, input_ids, max_seq_len):
        """Mask for padding."""
        if len(input_ids) > max_seq_len:
            raise IndexError("Token length more than max seq length!")
        return [1] * len(input_ids) + [0] * (max_seq_len - len(input_ids))

    def _get_token_type_id(self, input_ids, max_seq_len, sep_token):
        """Segments: 0 for the first sequence, 1 for the second."""
        if len(input_ids) > max_seq_len:
            raise IndexError("Token length more than max seq length!")
        segments = []
        current_segment_id = 0
        for input_id in input_ids:
            segments.append(current_segment_id)
            if input_id == sep_token:
                current_segment_id = 1
        return segments + [0] * (max_seq_len - len(input_ids))

# %%
class BaiduTriggerDataset(Dataset):
    
    def __init__(self, dataset_path, label_dict_path, ignore_index=-100):
        self.label_vocab = load_dict(label_dict_path)
        self.label_num = max(self.label_vocab.values()) + 1
        self.examples = []
        with open(dataset_path, 'r', encoding='utf-8') as f:
            dataset = json.loads(f.read())
            preprocess_dataset = trigger_data_process(dataset)
            for d_json in tqdm(preprocess_dataset, total=len(preprocess_dataset)):
                tokens = d_json['tokens']
                b_input_ids, b_attention_masks, b_token_type_ids = [], [], []
                for tokenizer in model_dict.values():
                    PADDING = tokenizer.vocab[tokenizer.pad_token]
                    SEP = tokenizer.vocab[tokenizer.sep_token]
                    input_ids = tokenizer(tokens, is_split_into_words=True, add_special_tokens=True, max_length=max_seq_len, truncation=True)['input_ids']
                    tokens_input = input_ids + [PADDING] * (max_seq_len - len(input_ids))
                    attention_masks = self._get_attention_mask(input_ids, max_seq_len)
                    token_type_ids = self._get_token_type_id(input_ids, max_seq_len, sep_token=SEP)
                    b_input_ids.append(tokens_input)
                    b_attention_masks.append(attention_masks)
                    b_token_type_ids.append(token_type_ids)
                example = {
                    "input_ids": b_input_ids, "attention_masks": b_attention_masks, "token_type_ids": b_token_type_ids, "seq_lens": len(tokens)
                }
                example.update(d_json)
                if 'labels' in d_json:
                    labels = d_json['labels']
                    labels = labels[:(max_seq_len - 2)]
                    encoded_label = ["O"] + labels + ["O"]
                    encoded_label = self.to_one_hot_vector(encoded_label, max_seq_len - 2 - len(labels))
                    example.update({"encoded_label": encoded_label})
                self.examples.append(example)
                
    def to_one_hot_vector(self, labels, zero_padding_len = 0):
        """Convert seq to one hot."""
        one_hot_vectors = []
        for label in labels:
            one_hot_vector = np.zeros(self.label_num)
            if isinstance(label, str):
                one_hot_vector[self.label_vocab.get(label, 0)] = 1
            elif isinstance(label, list):
                for l in label:
                    one_hot_vector[self.label_vocab.get(l, 0)] = 1
            one_hot_vectors.append(one_hot_vector)
        for _ in range(zero_padding_len):
            one_hot_vector = np.zeros(self.label_num)
            one_hot_vectors.append(one_hot_vector)
        return np.array(one_hot_vectors)

    def _get_attention_mask(self, input_ids, max_seq_len):
        """Mask for padding."""
        if len(input_ids) > max_seq_len:
            raise IndexError("Token length more than max seq length!")
        return [1] * len(input_ids) + [0] * (max_seq_len - len(input_ids))

    def _get_token_type_id(self, input_ids, max_seq_len, sep_token):
        """Segments: 0 for the first sequence, 1 for the second."""
        if len(input_ids) > max_seq_len:
            raise IndexError("Token length more than max seq length!")
        segments = []
        current_segment_id = 0
        for input_id in input_ids:
            segments.append(current_segment_id)
            if input_id == sep_token:
                current_segment_id = 1
        return segments + [0] * (max_seq_len - len(input_ids))      
    
    def __len__(self):
        return len(self.examples)
    
    def __getitem__(self, item_idx):
        example = {
            "id": self.examples[item_idx]["id"],
            "sent_id": self.examples[item_idx]["sent_id"],
            "text": self.examples[item_idx]["text"],
            "input_ids": torch.tensor(self.examples[item_idx]["input_ids"]).long(),
            "attention_masks": torch.tensor(self.examples[item_idx]["attention_masks"]),
            "token_type_ids": torch.tensor(self.examples[item_idx]["token_type_ids"]),
            "seq_lens": self.examples[item_idx]["seq_lens"]
        }
        if "encoded_label" in self.examples[item_idx]:
            example.update({"encoded_label": torch.tensor(self.examples[item_idx]["encoded_label"], dtype=torch.float)})
        return example

# %%
class BaiduRoleDataset(Dataset):
    
    def __init__(self, dataset_path, label_dict_path, ignore_index=-100):
        self.label_vocab = load_dict(label_dict_path)
        self.label_num = max(self.label_vocab.values()) + 1
        self.examples = []
        with open(dataset_path, 'r', encoding='utf-8') as f:
            dataset = json.loads(f.read())
            preprocess_dataset = role_data_process(dataset)
            for d_json in tqdm(preprocess_dataset, total=len(preprocess_dataset)):
                tokens = d_json['tokens']
                b_input_ids, b_attention_masks, b_token_type_ids = [], [], []
                for tokenizer in model_dict.values():
                    PADDING = tokenizer.vocab[tokenizer.pad_token]
                    SEP = tokenizer.vocab[tokenizer.sep_token]
                    input_ids = tokenizer(tokens, is_split_into_words=True, add_special_tokens=True, max_length=max_seq_len, truncation=True)['input_ids']
                    tokens_input = input_ids + [PADDING] * (max_seq_len - len(input_ids))
                    attention_masks = self._get_attention_mask(input_ids, max_seq_len)
                    token_type_ids = self._get_token_type_id(input_ids, max_seq_len, sep_token=SEP)
                    b_input_ids.append(tokens_input)
                    b_attention_masks.append(attention_masks)
                    b_token_type_ids.append(token_type_ids)
                example = {
                    "input_ids": b_input_ids, "attention_masks": b_attention_masks, "token_type_ids": b_token_type_ids, "seq_lens": len(tokens)
                }
                example.update(d_json)
                if 'labels' in d_json:
                    labels = d_json['labels']
                    labels = labels[:(max_seq_len - 2)]
                    encoded_label = ["O"] + labels + ["O"]
                    encoded_label = self.to_one_hot_vector(encoded_label, max_seq_len - 2 - len(labels))
                    example.update({"encoded_label": encoded_label})
                self.examples.append(example)
                
    def to_one_hot_vector(self, labels, zero_padding_len = 0):
        """Convert seq to one hot."""
        one_hot_vectors = []
        for label in labels:
            one_hot_vector = np.zeros(self.label_num)
            if isinstance(label, str):
                one_hot_vector[self.label_vocab.get(label, 0)] = 1
            elif isinstance(label, list):
                for l in label:
                    one_hot_vector[self.label_vocab.get(l, 0)] = 1
            one_hot_vectors.append(one_hot_vector)
        for _ in range(zero_padding_len):
            one_hot_vector = np.zeros(self.label_num)
            one_hot_vectors.append(one_hot_vector)
        return np.array(one_hot_vectors)

    def _get_attention_mask(self, input_ids, max_seq_len):
        """Mask for padding."""
        if len(input_ids) > max_seq_len:
            raise IndexError("Token length more than max seq length!")
        return [1] * len(input_ids) + [0] * (max_seq_len - len(input_ids))

    def _get_token_type_id(self, input_ids, max_seq_len, sep_token):
        """Segments: 0 for the first sequence, 1 for the second."""
        if len(input_ids) > max_seq_len:
            raise IndexError("Token length more than max seq length!")
        segments = []
        current_segment_id = 0
        for input_id in input_ids:
            segments.append(current_segment_id)
            if input_id == sep_token:
                current_segment_id = 1
        return segments + [0] * (max_seq_len - len(input_ids))   
    
    def __len__(self):
        return len(self.examples)
    
    def __getitem__(self, item_idx):
        example = {
            "id": self.examples[item_idx]["id"],
            "sent_id": self.examples[item_idx]["sent_id"],
            "text": self.examples[item_idx]["text"],
            "event_type": self.examples[item_idx]["event_type"],
            "trigger": self.examples[item_idx]["trigger"],
            "input_ids": torch.tensor(self.examples[item_idx]["input_ids"]).long(),
            "attention_masks": torch.tensor(self.examples[item_idx]["attention_masks"]),
            "token_type_ids": torch.tensor(self.examples[item_idx]["token_type_ids"]),
            "seq_lens": self.examples[item_idx]["seq_lens"]
        }
        if "encoded_label" in self.examples[item_idx]:
            example.update({"encoded_label": torch.tensor(self.examples[item_idx]["encoded_label"], dtype=torch.float)})
        return example

# %%
dev_enerm_dataset = BaiduEnermDataset(dataset_path=duee_fin_dev_preprocess_path, label_dict_path=enerm_dict_path)
dev_trigger_dataset = BaiduTriggerDataset(dataset_path=duee_fin_dev_preprocess_path, label_dict_path=trigger_dict_path)
dev_role_dataset = BaiduRoleDataset(dataset_path=duee_fin_dev_preprocess_path, label_dict_path=role_dict_path)
# Out:
# HBox(children=(IntProgress(value=0, max=66), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1946), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1803), HTML(value='')))

# %%
len(dev_enerm_dataset)
# Out:
# 66

# %%
len(dev_trigger_dataset)
# Out:
# 1946

# %%
len(dev_role_dataset)
# Out:
# 1803

# %%
def set_seed(seed = 42):
    """Set the seed for generating random numbers on all GPUs.

    It's safe to call this function if CUDA is not available; in that case, it is silently ignored.

    Args:
        seed (int, optional): random numbers on all GPUs. Defaults to 42.
    """
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)

# %%
# setting device on GPU if available, else CPU
device = torch.device(f'cuda:{device_Id}' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
print()

#Additional Info when using cuda
if device.type == 'cuda':
    n_gpu = torch.cuda.device_count()
    print(torch.cuda.get_device_name(0))
    
    print('Memory Usage:')
    print('Allocated:', torch.cuda.memory_allocated(0)/1024**3, 'GB')
    print('Cached:   ', torch.cuda.memory_reserved(0)/1024**3, 'GB')
    
    print('CUDA Device Count:', n_gpu)
    
set_seed(seed=42)
# Out:
# Using device: cuda:1
#
# Tesla V100-PCIE-32GB
# Memory Usage:
# Allocated: 0.0 GB
# Cached:    0.0 GB
# CUDA Device Count: 3

# %%
@torch.no_grad()
def test_enerm(model, test_dataloader):
    from sklearn.metrics import f1_score, recall_score, precision_score, accuracy_score
    
    model.eval()
    step = 0
    eval_acc = 0.0
    eval_f1 = 0.0
    eval_precision = 0.0
    eval_recall = 0.0
    results = []
    test_iterator = tqdm(test_dataloader)
    for batch in test_iterator:
        _, logits = model(
            input_ids=batch['input_ids'].to(device),
            attention_mask=batch['attention_masks'].to(device),
            token_type_ids=batch['token_type_ids'].to(device),
            labels=batch['encoded_label'].to(device)
        )

        probs = torch.sigmoid(logits).data.cpu()
        probs_ids = (probs > 0.5).numpy()
        true_label = batch.get("encoded_label", None).cpu().numpy()
        probs = probs.numpy()
        pred_Y = probs_ids.flatten()
        true_Y = true_label.flatten()
        eval_acc += accuracy_score(pred_Y, true_Y)
        eval_precision += precision_score(pred_Y, true_Y, average="macro", zero_division=1)
        eval_recall += recall_score(pred_Y, true_Y, average="macro", zero_division=1)
        eval_f1 += f1_score(pred_Y, true_Y, average="macro")
        for id_, sent_id, text, label_probs, p_id in zip(batch['id'], batch['sent_id'], batch['text'], probs.tolist(), probs_ids.tolist()):
            true_indices = np.argwhere(p_id).flatten()
            labels = [id2enumlabel[true_index] for true_index in true_indices]
            results.append({"id": id_, "sent_id": sent_id, "text": text, "pred":{"probs": label_probs, "label": labels}})
        step += 1
    print({"Avg eval acc": f"{eval_acc/step:.2f}", "Avg eval precision": f"{eval_precision/step:.2f}", "Avg eval recall": f"{eval_recall/step:.2f}", "Avg eval f1": f"{eval_f1/step:.2f}"})
    return results

# %%
models = [
    torch.load(f'./models/DuEE_fin/{model_name}/enum.bin').to(device)
    for model_name in model_dict.keys()
]
enum_model = MultiLabelStackedClassification(models=models, num_labels=len(label_enum_vocab))
enum_model.load_state_dict(torch.load(enerm_stacked_model_path))

enum_model = enum_model.to(device)

test_enerm_sampler = SequentialSampler(dev_enerm_dataset)
test_enerm_dataloader = DataLoader(dev_enerm_dataset, sampler=test_enerm_sampler, batch_size = 128)
    
sentences_enum_data = test_enerm(enum_model, test_enerm_dataloader)
# Out:
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# {'Avg eval acc': '1.00', 'Avg eval precision': '1.00', 'Avg eval recall': '1.00', 'Avg eval f1': '1.00'}

# %%
@torch.no_grad()
def test_trigger(model, test_dataloader):
    from sklearn.metrics import f1_score, recall_score, precision_score, accuracy_score

    model.eval()
    step = 0
    eval_acc = 0.0
    eval_f1 = 0.0
    eval_precision = 0.0
    eval_recall = 0.0
    results = []
    test_iterator = tqdm(test_dataloader)
    for batch in test_iterator:
        _, logits = model(
            input_ids=batch['input_ids'].to(device),
            attention_mask=batch['attention_masks'].to(device),
            token_type_ids=batch['token_type_ids'].to(device)
        )

        probs = torch.sigmoid(logits).data.cpu()
        probs_ids = (probs > 0.1).numpy()
        probs = probs.numpy()
        true_Y = batch['encoded_label'].cpu().numpy()
        pred, true = [], []
        for t_ids, p_ids, seq_len in zip(true_Y, probs_ids, batch['seq_lens']):
            pred.extend(p_ids[1: seq_len - 1])
            true.extend(t_ids[1: seq_len - 1])
        pred_Y = np.array(pred).flatten()
        true_Y = np.array(true).flatten()
        eval_acc += accuracy_score(pred_Y, true_Y)
        eval_precision += precision_score(pred_Y, true_Y, average='macro', zero_division=1)
        eval_recall += recall_score(pred_Y, true_Y, average='macro', zero_division=1)
        eval_f1 += f1_score(pred_Y, true_Y, average='macro', zero_division=1)
        for id_, sent_id, text, p_list, p_ids, seq_len in zip(batch['id'], batch['sent_id'], batch['text'], probs.tolist(), probs_ids.tolist(), batch['seq_lens']):
            prob_multi, label_multi = [], []
            for index, pid in enumerate(p_ids[1: seq_len - 1]):
                true_indices = np.argwhere(pid).flatten()
                prob_multi.append(p_list[index])
                label_multi.append([id2triggerlabel[true_index] for true_index in true_indices])
            results.append({"id": id_, "sent_id":sent_id, "text": text, "pred": {"probs": prob_multi, "labels": label_multi}})
        step += 1
    print({"Avg eval acc": f"{eval_acc/step}", "Avg eval precision": f"{eval_precision/step}", "Avg eval recall": f"{eval_recall/step}", "Avg eval f1": f"{eval_f1/step}"})
    return results

# %%
models = [
    torch.load(f'./models/DuEE_fin/{model_name}/trigger-multilabel.bin').to(device)
    for model_name in model_dict.keys()
]
tigger_model = MultiLabelStackedClassification(models=models, num_labels=len(label_trigger_vocab))
tigger_model.load_state_dict(torch.load(tigger_stacked_model_path))

tigger_model = tigger_model.to(device)

test_trigger_sampler = SequentialSampler(dev_trigger_dataset)
test_trigger_dataloader = DataLoader(dev_trigger_dataset, sampler=test_trigger_sampler, batch_size = 128)
    
sentences_tigger_data = test_trigger(tigger_model, test_trigger_dataloader)
# Out:
# HBox(children=(IntProgress(value=0, max=16), HTML(value='')))
# {'Avg eval acc': '0.9998514554883412', 'Avg eval precision': '0.9990421677828802', 'Avg eval recall': '0.9988762282760667', 'Avg eval f1': '0.9989591761176594'}

# %%
@torch.no_grad()
def test_role(model, test_dataloader):
    from sklearn.metrics import f1_score, recall_score, precision_score, accuracy_score

    model.eval()
    step = 0
    eval_acc = 0.0
    eval_f1 = 0.0
    eval_precision = 0.0
    eval_recall = 0.0
    results = []
    test_iterator = tqdm(test_dataloader)
    for batch in test_iterator:
        loss, logits = model(
            input_ids=batch['input_ids'].to(device),
            attention_mask=batch['attention_masks'].to(device),
            token_type_ids=batch['token_type_ids'].to(device)
        )

        probs = torch.sigmoid(logits).data.cpu()
        probs_ids = (probs > 0.1).numpy()
        probs = probs.numpy()
        true_Y = batch['encoded_label'].cpu().numpy()
        pred, true = [], []
        for t_ids, p_ids, seq_len in zip(true_Y, probs_ids, batch['seq_lens']):
            pred.extend(p_ids[1: seq_len - 1])
            true.extend(t_ids[1: seq_len - 1])
        pred_Y = np.array(pred).flatten()
        true_Y = np.array(true).flatten()
        eval_acc += accuracy_score(pred_Y, true_Y)
        eval_precision += precision_score(pred_Y, true_Y, average='macro', zero_division=1)
        eval_recall += recall_score(pred_Y, true_Y, average='macro', zero_division=1)
        eval_f1 += f1_score(pred_Y, true_Y, average='macro', zero_division=1)
        for id_, sent_id, text, input_ids, event_type, trigger, p_list, p_ids, seq_len in zip(batch['id'], batch['sent_id'], batch['text'], batch['input_ids'], batch['event_type'], batch['trigger'], probs.tolist(), probs_ids.tolist(), batch['seq_lens']):
            prob_multi, label_multi = [], []
            for index, pid in enumerate(p_ids[1: seq_len - 1]):
                true_indices = np.argwhere(pid).flatten()
                prob_multi.append(p_list[index])
                label_multi.append([id2rolelabel[true_index] for true_index in true_indices])
            results.append({"id": id_, "sent_id":sent_id, "event_type": event_type, "trigger": trigger, "text": text, "pred": {"probs": prob_multi, "labels": label_multi}})
        step += 1
    print({"Avg eval acc": f"{eval_acc/step:.5f}", "Avg eval precision": f"{eval_precision/step:.5f}", "Avg eval recall": f"{eval_recall/step:.5f}", "Avg eval f1": f"{eval_f1/step:.5f}"})
    return results

# %%
models = [
    torch.load(f'./models/DuEE_fin/{model_name}/role-multilabel-trick1.bin').to(device)
    for model_name in model_dict.keys()
]
role_model = MultiLabelStackedClassification(models=models, num_labels=len(label_role_vocab))
role_model.load_state_dict(torch.load(role_stacked_model_path))

role_model = role_model.to(device)

test_role_sampler = SequentialSampler(dev_role_dataset)
test_role_dataloader = DataLoader(dev_role_dataset, sampler=test_role_sampler, batch_size = 128)
    
sentences_role_data = test_role(role_model, test_role_dataloader)
# Out:
# HBox(children=(IntProgress(value=0, max=15), HTML(value='')))
# {'Avg eval acc': '1.00', 'Avg eval precision': '0.99', 'Avg eval recall': '0.98', 'Avg eval f1': '0.98'}

# %%
from utils import read_by_lines, extract_result_multilabel

# %%
def event_normalization(doc):
    """event_merge"""
    for event in doc.get("event_list", []):
        argument_list = []
        argument_set = set()
        for arg in event["arguments"]:
            arg_str = "{}-{}".format(arg["role"], arg["argument"])
            if arg_str not in argument_set:
                argument_list.append(arg)
            argument_set.add(arg_str)
        event["arguments"] = argument_list

    event_list = sorted(
        doc.get("event_list", []),
        key=lambda x: len(x["arguments"]),
        reverse=True)
    new_event_list = []
    for event in event_list:
        event_type = event["event_type"]
        event_argument_set = set()
        for arg in event["arguments"]:
            event_argument_set.add("{}-{}".format(arg["role"], arg["argument"]))
        flag = True
        for new_event in new_event_list:
            if event_type != new_event["event_type"]:
                continue
            new_event_argument_set = set()
            for arg in new_event["arguments"]:
                new_event_argument_set.add("{}-{}".format(arg["role"], arg[
                    "argument"]))
            if len(event_argument_set & new_event_argument_set) == len(
                    new_event_argument_set):
                flag = False
        if flag:
            new_event_list.append(event)
    doc["event_list"] = new_event_list
    return doc

def predict_data_process(trigger_data, role_data, enum_data, schema_file):
    """predict_data_process"""
    pred_ret = []
    schema_data = read_by_lines(schema_file)
    print("trigger predict {} load.".format(len(trigger_data)))
    print("role predict {} load".format(len(role_data)))
    print("enum predict {} load".format(len(enum_data)))
    print("schema {} load from {}".format(len(schema_data), schema_file))

    schema, sent_role_mapping, sent_enum_mapping = {}, {}, {}
    for s in schema_data:
        d_json = json.loads(s)
        schema[d_json["event_type"]] = [r["role"] for r in d_json["role_list"]]

    # role depends on id and sent_id 
    for d_json in role_data:
        r_ret = extract_result_multilabel(d_json["text"], d_json["pred"]["labels"])
        role_ret = {}
        for r in r_ret:
            role_type = r["type"]
            if role_type not in role_ret:
                role_ret[role_type] = []
            role_ret[role_type].append("".join(r["text"]))
        _id = "{}\t{}\t{}\t{}".format(d_json["id"], d_json["sent_id"], d_json["event_type"], d_json["trigger"])
        if _id not in sent_role_mapping:
            sent_role_mapping[_id] = role_ret
        else:
            for role_type, vals in role_ret.items():
                if role_type in sent_role_mapping[_id]:
                    sent_role_mapping[_id][role_type].extend(vals)
                else:
                    sent_role_mapping[_id][role_type] = vals
            
    # process the enum_role data
    for d_json in enum_data:
        _id = "{}\t{}".format(d_json["id"], d_json["sent_id"])
        labels = d_json["pred"]["label"]
        sent_enum_mapping[_id] = labels

    # process trigger data
    for d_json in trigger_data:
        t_ret = extract_result_multilabel(d_json["text"], d_json["pred"]["labels"])
        pred_event_types = list(set([(t["type"], ''.join(t["text"])) for t in t_ret]))
        event_list = []
        _id = "{}\t{}".format(d_json["id"], d_json["sent_id"])
        for pred_event_type in pred_event_types:
            event_type = pred_event_type[0]
            trigger = pred_event_type[1]
            role_id = _id + "\t{}\t{}".format(event_type, trigger)
            role_list = schema[event_type]
            arguments = []
            for role_type, ags in sent_role_mapping.get(role_id, {}).items():
                if role_type not in role_list:
                    continue
                for arg in ags:
                    out = {"role": role_type, "argument": arg}
                    if out not in arguments:
                        arguments.append(out)
            # 特殊处理环节
            if event_type == enum_event_type:
                for label in sent_enum_mapping.get(_id, []):
                    arguments.append({
                        "role": enum_role,
                        "argument": label
                    })
            if arguments:
                event = {
                    "event_type": event_type,
                    "arguments": arguments,
                    "text": d_json["text"]
                }
                event_list.append(event)
        pred_ret.append({
            "id": d_json["id"],
            "sent_id": d_json["sent_id"],
            "text": d_json["text"],
            "event_list": event_list
        })
    doc_pred = {}
    for d in pred_ret:
        if d["id"] not in doc_pred:
            doc_pred[d["id"]] = {"id": d["id"], "event_list": []}
        doc_pred[d["id"]]["event_list"].extend(d["event_list"])

    # unfiy the all prediction results and save them
    doc_pred = [
        event_normalization(r)
        for r in doc_pred.values()
    ]
    print("submit data {} save".format(len(doc_pred)))
    return doc_pred

# %%
doc_pred = predict_data_process(sentences_tigger_data, sentences_role_data, sentences_enum_data, shema_path)
# Out:
# trigger predict 1946 load.
# role predict 1803 load
# enum predict 66 load
# schema 13 load from ./dictionary/event_schema.json
# submit data 1174 save

# %%
# true_sent_enum_data, true_sent_tigger_data, true_sent_role_data  = [], [], []
# with open(duee_fin_dev_preprocess_path, 'r', encoding='utf-8') as f:
#     dataset = json.loads(f.read())
#     preprocess_enum_dataset = enum_data_process(dataset)
#     preprocess_trigger_dataset = trigger_data_process(dataset)
#     preprocess_role_dataset = role_data_process(dataset)
#     for d_json in preprocess_enum_dataset:
#         true_sent_enum_data.append({"id": d_json['id'], "sent_id":d_json['sent_id'], "text": d_json['text'], "pred": {"label": d_json['label']}})
#     for d_json in preprocess_trigger_dataset:
#         labels = d_json['labels']
#         labels = labels[:(max_seq_len - 2)]
#         encoded_label = [[l] if isinstance(l , str) else l for l in labels]
#         true_sent_tigger_data.append({"id": d_json['id'], "sent_id":d_json['sent_id'], "text": d_json['text'], "pred": {"labels": encoded_label}})
#     for d_json in preprocess_role_dataset:
#         labels = d_json['labels']
#         labels = labels[:(max_seq_len - 2)]
#         encoded_label = [[l] if isinstance(l , str) else l for l in labels]
#         true_sent_role_data.append({"id": d_json['id'], "sent_id":d_json['sent_id'], "event_type": d_json['event_type'], "trigger": d_json['trigger'], "text": d_json['text'], "pred": {"labels": encoded_label}})

# %%
true_data_list = []
with open(duee_fin_dev_path, 'r', encoding='utf-8') as f:
    for line in f:
        json_data = json.loads(line)
        true_data_list.append(json_data)
pred_mapping_dict = {}
for doc in doc_pred:
    pred_mapping_dict[doc['id']] = doc

# %%
count = 0
for true_data in true_data_list:
    id_ = true_data['id']
    true_data_set = set([(argument['role'], argument['argument']) for true_event in true_data.get('event_list', []) for argument in true_event.get('arguments')])
    pred_data = pred_mapping_dict[id_]
    pred_data_set = set([(argument['role'], argument['argument']) for pred_event in pred_data.get('event_list', []) for argument in pred_event.get('arguments')])
    if len(list(true_data_set)) != len(list(pred_data_set)):
        print(id_)
        print(list(true_data_set))
        print(list(pred_data_set))
        count += 1
# Out:
# 60229be25b3f52bdbbd91ea664591a72
# [('环节', '筹备上市'), ('发行价格', '8-10美元'), ('上市公司', '理想汽车'), ('披露时间', '30日')]
# [('环节', '筹备上市'), ('上市公司', '理想汽车'), ('披露时间', '30日')]
# 10be7f956da35f15fa4a9ad2a4556960
# [('公司名称', '美团'), ('公司名称', '抖音'), ('被约谈时间', '近日'), ('约谈机构', '北京市监局'), ('公司名称', '京东'), ('公司名称', '快手'), ('公司名称', '饿了么'), ('公司名称', '微店')]
# [('公司名称', '美团'), ('约谈机构', '北京市市场监管局'), ('被约谈时间', '近日'), ('公司名称', '京东'), ('公司名称', '快手'), ('公司名称', '饿了么'), ('公司名称', '微店')]
# be11a1377c0d97bd5f5da146990597fa
# [('被投资方', '天宜上佳'), ('事件时间', '7月22日'), ('环节', '筹备上市'), ('披露时间', '近日'), ('投资方', '启赋安泰基金'), ('上市公司', '天宜上佳'), ('事件时间', '2018年6月')]
# [('上市公司', '天宜上佳'), ('披露时间', '近日'), ('环节', '筹备上市'), ('事件时间', '7月22日')]
# 364cf72ae0d2d5b94dcf6d815716b189
# [('质押方', '众达投资'), ('质押股票/股份数量', '854.68万'), ('质押物', '股份'), ('质押物所属公司', '翔鹭钨业')]
# [('质押物所属公司', '翔鹭钨业'), ('质押股票/股份数量', '854.68万'), ('质押物', '股份'), ('质权方', '海通证券'), ('质押方', '潮州市众达投资有限公司'), ('披露时间', '5月20日晚间')]
# 5259811fce42c3a4833e326fb8f847a9
# [('招标方', '河南科技大学第二附属医院'), ('中标公司', '国药控股'), ('中标金额', '3.25亿元'), ('中标公司', '国药器械'), ('中标标的', '医用耗材集中配送服务遴选供应商项目'), ('披露日期', '近日'), ('中标公司', '华润'), ('中标公司', '海王')]
# [('招标方', '河南科技大学第二附属医院'), ('中标公司', '国药控股'), ('中标金额', '3.25亿元'), ('中标标的', '医用耗材配送服务商'), ('中标日期', '近日'), ('中标标的', '医用耗材集中配送服务遴选供应商项目'), ('招标方', '湖北民族大学附属民大医院'), ('中标公司', '国药'), ('中标公司', '人福医药'), ('中标公司', '华润')]
# c45668926f8b7a09a9fff66254420147
# [('回购股份数量', '2100'), ('回购完成时间', '2020年9月8日'), ('回购方', '时富金融服务集团'), ('交易金额', '1008港元'), ('每股交易价格', '0.48港元'), ('披露时间', '9 月 8日')]
# [('回购股份数量', '2100'), ('回购完成时间', '2020年9月8日'), ('回购方', '时富金融服务集团'), ('披露时间', '9月8日'), ('交易金额', '1008港元'), ('每股交易价格', '0.48港元'), ('披露时间', '9 月 8日')]
# 23ba128e902745d21c41fdd6097fa18b
# [('回购方', '恒大高新'), ('回购股份数量', '10.69万'), ('每股交易价格', '6.1297元'), ('披露时间', '8月8日'), ('每股交易价格', '3.57元')]
# [('回购方', '恒大高新'), ('回购股份数量', '10.69万'), ('每股交易价格', '6.1297元'), ('占公司总股本比例', '0.0348%'), ('披露时间', '8月8日'), ('每股交易价格', '3.57元')]
# 597c3058dbe1d040b342be889f8d1de0
# [('收购标的', '全部已发行股本及待售贷款'), ('被收购方', 'Les Ambassadeurs Club Limited'), ('收购方', 'Project Martini Limited'), ('收购完成时间', '2019年7月24日'), ('交易金额', '1.22亿英镑')]
# [('收购方', '意马国际'), ('被收购方', 'Les Ambassadeurs Club Limited'), ('收购方', 'Project Martini Limited'), ('收购完成时间', '2019年7月24日'), ('收购标的', '全部已发行股本及待售'), ('交易金额', '1.22亿英镑'), ('披露时间', '2')]
# 9b65c2e919d3a699300e210511d1c6b9
# [('财报周期', '2018年同期'), ('净亏损', '9990万元'), ('公司名称', '欢聚时代'), ('披露时间', '8月14日早间')]
# [('公司名称', '欢聚时代'), ('财报周期', '2019年第二季度'), ('财报周期', '2'), ('净亏损', '9990万元'), ('披露时间', '8月14日早间')]
# 2c22ff09fb665ccdfcb159aaa9a2286c
# [('变动类型', '退休'), ('披露日期', '7月7日'), ('中标公司', '中国中铁'), ('高管姓名', '马云'), ('中标金额', '546.8亿元'), ('中标日期', '近期')]
# [('中标公司', '中国中铁'), ('披露日期', '7月7日'), ('中标标的', '重'), ('中标金额', '546.8亿元'), ('中标日期', '近期')]
# 35fabe18c5f8e5898ed45043d064ac8f
# [('高管职位', '公司副总经理'), ('高管姓名', '赵倩莹'), ('变动类型', '聘任'), ('变动后职位', '公司副总经理'), ('变动后职位', '董事会秘书'), ('高管职位', '董事会秘书'), ('事件时间', '近日'), ('事件时间', '自本次董事会审议通过之日起至第三届董事会任期届满之日止'), ('高管姓名', '叶潇'), ('变动类型', '辞去'), ('任职公司', '汉邦高科')]
# [('高管姓名', '王立群'), ('任职公司', '汉邦高科'), ('高管姓名', '赵倩莹'), ('变动类型', '聘任'), ('事件时间', '任期自本次董事会审议通过之日起至第三届董事会任期届满之日'), ('事件时间', '自自本次董事会审议通过之日起至第三届董事会任期届满之日'), ('变动后职位', '副总经理'), ('变动后职位', '董事会秘书')]
# e20eeecc8cc5df62b8c2c7c6d96815d5
# [('公司名称', '全新好'), ('净亏损', '1369.04万元~2019.04万元'), ('净亏损', '4350万元~5000万元'), ('财报周期', '2020年第三季度'), ('净亏损', '520.49万元'), ('净亏损', '931万元'), ('披露时间', '10月14日晚间'), ('财报周期', '2020年前三季度'), ('财报周期', '上年同期')]
# [('公司名称', '全新好'), ('净亏损', '1369.04万元~2019.04万元'), ('净亏损', '4350万元~5000万元'), ('净亏损', '520.49万元'), ('净亏损', '931万元'), ('披露时间', '10月14日晚间'), ('财报周期', '2020年前三季度'), ('财报周期', '上年同期')]
# 6840d385c03e24f37064faa6c6eae757
# [('质押股票/股份数量', '1990万'), ('质押物所属公司', '方盛制药'), ('质权方', '长沙银行股份有限公司高信支行'), ('质押物占总股比', '32.28%'), ('质押股票/股份数量', '约1779.65万'), ('事件时间', '7月7日'), ('披露时间', '7月7日晚间'), ('质押物', '股份'), ('质押股票/股份数量', '约为1.4亿'), ('事件时间', '截至本公告披露日'), ('质押物占持股比', '89.77%'), ('质押方', '张庆华')]
# [('质押股票/股份数量', '1990万'), ('质押物所属公司', '方盛制药'), ('质押物占总股比', '32.28%'), ('质押股票/股份数量', '约1779.65万'), ('质押股票/股份数量', '11779.65万'), ('事件时间', '7月7日'), ('披露时间', '7月7日晚间'), ('质押物', '股份'), ('质押股票/股份数量', '约为1.4亿'), ('事件时间', '截至本公告披露日'), ('质押物占持股比', '89.77%'), ('质押方', '张庆华'), ('质权方', '长沙银行份有限公司高信支行')]
# 059e1e8ade11b1de9ab81a728eab2c81
# [('收购方', 'Uber'), ('被收购方', 'Postmates'), ('披露时间', '6月30日')]
# [('收购方', 'Uber'), ('被收购方', 'Postmates'), ('披露时间', '6月30日'), ('被收购方', 'GrubHub')]
# 1e4227df13157e46f90e6219550f1caf
# [('收购方', '蓝帆医疗'), ('减持部分占总股本比例', '不超过5.54%'), ('披露时间', '上月'), ('股票简称', '蓝帆医疗'), ('减持方', '北京中信'), ('减持方', '蓝帆集团'), ('被收购方', '柏盛国际')]
# [('交易完成时间', '上月'), ('被收购方', '蓝医'), ('收购方', '蓝帆医疗'), ('减持部分占总股本比例', '不超过5.54%'), ('交易金额', '超过15亿元'), ('股票简称', '蓝帆医疗'), ('减持方', '北京中信'), ('减持方', '蓝帆集团')]
# 0aadf059b6a584edff8b5199bbbff2f3
# [('收购标的', '100%的股权'), ('收购方', '东华合创'), ('被收购方', '北京联银通科技有限公司'), ('交易金额', '不超过30000万元')]
# [('收购标的', '100%的股权'), ('收购方', '东华合创'), ('被收购方', '北京联银通科技有限公司')]
# edd124f781680a7c59f1b94cd6ea9483
# [('财报周期', '第二季度'), ('净亏损', '32.85亿元'), ('公司名称', '蔚来汽车'), ('披露时间', '9月25日晚间')]
# [('净亏损', '57亿美元'), ('公司名称', '蔚来汽车'), ('净亏损', '32.85亿元'), ('财报周期', '第二季度'), ('净亏损', '200亿人民币'), ('披露时间', '9月25日晚间')]
# 3bcc9e43da529f05ccfe941f1fda690e
# [('质押股票/股份数量', '1.525亿'), ('质押物占持股比', '14.06%'), ('质押方', '一致行动人'), ('质押物占总股比', '11.95%'), ('质押方', '华夏控股'), ('质押物占持股比', '32.13%'), ('质押物', '股份'), ('质押股票/股份数量', '近3.6亿'), ('事件时间', '近日'), ('质押物所属公司', '华夏幸福'), ('质押物占总股比', '5.06%')]
# [('质押物占持股比', '14.06%'), ('质押物占总股比', '11.95'), ('质押方', '华夏控股'), ('质押物占持股比', '32.13%'), ('披露时间', '6月22日'), ('质押物', '股份'), ('质押股票/股份数量', '近3.6亿'), ('质押物所属公司', '华夏幸福'), ('质押方', '其一致行动人')]
# d84ab9d2d7e322f0bd72628401a80546
# [('破产公司', '特斯拉'), ('破产公司', 'SpaceX')]
# [('破产公司', '特斯拉'), ('破产公司', 'SpaceX'), ('破产公司', '马')]
# a5e7180a72231c88095986c726acbdb2
# [('质押物占总股比', '16.11%'), ('事件时间', '2019年10月16日至2024年6月20日'), ('质押股票/股份数量', '1.1亿'), ('质押物占持股比', '9.15%'), ('质押物所属公司', '本钢板材控股股东本钢公司'), ('质押物', '股份'), ('质押股票/股份数量', '2.18亿'), ('事件时间', '截至公告披露日'), ('质押物占持股比', '4.75%'), ('事件时间', '2016年9月28日'), ('披露时间', '10月17日'), ('质押方', '本钢公司'), ('质押股票/股份数量', '624,264,469'), ('质押方', '本钢板材'), ('质权方', '中国工商银行股份有限公司本溪分行')]
# [('事件时间', '2019年10月16日至2024年6月20日'), ('质押股票/股份数量', '2.18亿'), ('质押物占持股比', '4.75%'), ('质押方', '本钢公司'), ('质押股票/股份数量', '624,264,469'), ('事件时间', '2019年10月16日'), ('披露时间', '10月17日'), ('质押物所属公司', '本钢板材'), ('质押物占持股比', '9.15%'), ('质押物占总股比', '16.11%'), ('质权方', '国泰君安证券股份有限公司'), ('质押股票/股份数量', '1.1亿'), ('质押物', '股份'), ('事件时间', '自019年10月16日至2024年6月20日'), ('事件时间', '截至公告披露日'), ('质押方', '本溪钢铁（集团）有限责任公司'), ('质权方', '中'), ('事件时间', '2016年9月28日'), ('质权方', '中国工商银行股份有限公司本溪分行')]
# e1b4853dda7dec9e7e8939996d8cc11b
# [('破产公司', '致富皮业')]
# [('债务规模', '1500万元'), ('债权人', '迁市致富皮业有限公司'), ('破产公司', '宿迁市致富皮业有限公司')]
# 2a2260436652b2a8b66bb94f95fec4ba
# [('质押方', '胡亚春'), ('质押物所属公司', '仁新科技'), ('质押股票/股份数量', '3134.80万'), ('质押物', '股'), ('披露时间', '9月17日'), ('质权方', '成都中小企业融资担保有限责任公司')]
# [('质押方', '胡亚春'), ('质押物所属公司', '仁新科技'), ('质押股票/股份数量', '3134.80万'), ('质押物', '股份'), ('事件时间', '2020年9月16日起至2021年9月15日止'), ('质押物占总股比', '34%'), ('质押股票/股份数量', '3'), ('披露时间', '9月17日'), ('质权方', '成都中小企业融资担保有限责任公司')]
# 9d90bef72a514c8f35d9213f7fa17a25
# [('披露时间', '8月5日'), ('亏损变化', '同比减亏22%'), ('财报周期', '2019年第二季度'), ('净亏损', '3800万美元'), ('公司名称', '搜狐')]
# [('公司名称', '搜'), ('公司名称', '搜狐集团'), ('披露时间', '8月5日'), ('亏损变化', '同比减亏22%'), ('财报周期', '第三季度'), ('财报周期', '2019年第二季度'), ('亏损变化', '收窄'), ('公司名称', '畅游晶茂'), ('净亏损', '2200万至3200万美元'), ('净亏损', '3800万美元'), ('公司名称', '搜狐')]
# 28488b2dd838cfdf73bba1670c5efd0c
# [('被收购方', '天津润祥锦华环保科技'), ('被收购方', '天津市津彤源环保科技'), ('收购方', '园城黄金'), ('披露时间', '3月10日晚'), ('被收购方', '天津市能昭环保科技'), ('收购标的', '100%股权'), ('收购标的', '34%股权')]
# []
# 4d8e52901d750589bfa16d1f87c78f93
# [('质押物占总股比', '49%'), ('质权方', '交行众安'), ('质押物所属公司', '广宇集团股份有限公司'), ('质押物', '股权'), ('质押物所属公司', '广宇集团股份有限公司子公司'), ('质押物占总股比', '100%'), ('质押方', '中纬实业'), ('质押方', '融晟置业'), ('事件时间', '2019年9月6日'), ('质押物占总股比', '51%'), ('披露时间', '9月8日')]
# [('质押物所属公司', '杭州融晟置业有限公司'), ('质权方', '交行众安'), ('质押物', '股权'), ('质押物所属公司', '广宇集团'), ('质押物', '股'), ('事件时间', '2019年9月6日'), ('质押物占总股比', '51%'), ('披露时间', '9月8日')]
# 9f5a07ce4a80fec9b5906287c272ed9d
# [('披露时间', '2019年5月29日'), ('交易股票/股份数量', '不超过 16,274,888'), ('减持部分占总股本比例', '不超过公司总股本的 2%'), ('减持方', '凯撒集团（香港）有限公司'), ('交易完成时间', '2019年5月29日起15个交易日后的6个月内'), ('减持方', '志凯有限公司')]
# [('减持方', '凯'), ('披露时间', '2019年5月29日'), ('减持方', '凯撒集团'), ('交易股票/股份数量', '不超过 16,274,888'), ('减持部分占总股本比例', '不超过公司总股本的 2%'), ('减持方', '志凯公司'), ('减持方', '凯撒集团（香港）有限公司'), ('交易完成时间', '2019年5月29日起15个交易日后的6个月内'), ('减持方', '志凯有限公司'), ('披露时间', '2019年9月1'), ('股票简称', '凯'), ('股票简称', '凯撒')]
# 26f979bc194afbfda0c5304eaef5c2d9
# [('每股交易价格', '3.755元'), ('回购完成时间', '2019年8月13日'), ('回购股份数量', '521.43万'), ('披露时间', '8月13日晚间'), ('回购方', '世联行')]
# [('回购股份数量', '103.67万'), ('每股交易价格', '3.755元'), ('回购完成时间', '2019年8月13日'), ('回购股份数量', '521.43万'), ('披露时间', '8月13日晚间'), ('回购方', '世联行')]
# 2cbc96da6196da23163b562ebbc0cf44
# [('回购股份数量', '660.7475万'), ('披露时间', '9月24日'), ('占公司总股本比例', '0.60%'), ('回购方', '华灿光电')]
# [('占公司总股本比例', '0.60%'), ('回购方', '华灿光电'), ('回购股份数量', '660.7475万'), ('披露时间', '9月24日'), ('每股交易价格', '5.82元'), ('回购完成时间', '2'), ('回购股份数量', '660.75万')]
# 52172a636275152c6a1107e591f443c6
# [('财报周期', '2019年度前三季度'), ('净亏损', '800万元至1,000万元'), ('公司名称', '珠海中富'), ('披露时间', '10月16日')]
# [('公司名称', '珠海中富'), ('披露时间', '10月16日'), ('财报周期', '2019年前三季度'), ('净亏损', '800万元至1000万元'), ('净亏损', '约1,000万元')]
# 66e3006c21683bf1e629617e9b0775d4
# [('环节', '筹备上市'), ('上市公司', '中金珠宝')]
# [('环节', '筹备上市'), ('上市公司', '中金珠宝'), ('披露时间', '日前')]
# 19aba86863d6456b3681dc74af1e4714
# [('环节', '正式上市'), ('上市公司', '阿里巴巴'), ('事件时间', '11月26日'), ('市值', '39993亿港元')]
# [('披露时间', '11月26日'), ('事件时间', '11月26日'), ('市值', '39993亿港元'), ('上市公司', '阿里巴巴'), ('环节', '正式上市')]
# 7abeeb7bb9e369640b0e9519b1c19741
# [('被收购方', '联杰国际有限公司'), ('交易金额', '1200万港元'), ('收购标的', '80%股权'), ('收购方', 'Permanent Master'), ('被收购方', '创富国际集团有限公司达田有限公司')]
# [('被收购方', '联杰国际有限公司'), ('交易金额', '1200万港元'), ('披露时间', '019年10月4日'), ('收购标的', '80%股权'), ('收购标的', '各0%股权'), ('收购方', 'Permanent Master'), ('收购完成时间', '201年月'), ('收购方', '华人饮食集团'), ('被收购方', '创富国际集团有限公司达田有限公司'), ('被收购方', '达达田有限公司')]
# cfd12a416a55ac54235657e15703024a
# [('财报周期', '2019年上半年'), ('净亏损', '70.8万元'), ('增持方', '巨人网络集团股份有限公司'), ('财报周期', '2018年'), ('披露时间', '近日'), ('公司名称', '上海巨堃网络科技有限公司'), ('被收购方', 'Playtika'), ('收购方', '巨人网络集团股份有限公司'), ('股票简称', '巨堃网络'), ('净亏损', '8736元')]
# [('被收购方', '上海巨堃网络科技有限公'), ('财报周期', '2019年上半年'), ('净亏损', '70.8万元'), ('收购方', '巨人网络'), ('财报周期', '2018年'), ('公司名称', '上'), ('净亏损', '8736元'), ('公司名称', '巨人网络')]
# bdb1673dffe88ed3cdbcb591d94f79d7
# [('被收购方', '智利切昆塔集团公司'), ('收购方', '中国国家电网有限公司'), ('披露时间', '6月24日'), ('收购完成时间', '24日'), ('收购标的', '100%股权')]
# [('被收购方', '智利切昆塔集团公司'), ('收购方', '中国国家电网有限公司'), ('披露时间', '6月24日'), ('收购完成时间', '2019年10月'), ('收购完成时间', '24日'), ('收购方', '美国森普'), ('收购方', '中国'), ('收购标的', '100%股权')]
# 0c647c188869ddeb9035d7f24bda307f
# [('中标标的', '祁婺高速公路项目钢材供应权'), ('中标公司', '方大九钢'), ('招标方', '江西省高速公路投资集团')]
# [('中标标的', '钢'), ('中标标的', '祁'), ('中标公司', '方大九钢'), ('中标标的', '祁婺高速公路项目钢材供应权'), ('招标方', '中江西省高速公路投资集团')]
# b6435a197ce8008aaa9a57ce053418ce
# [('上市公司', '安徽省交通建设股份有限公司'), ('环节', '筹备上市'), ('事件时间', '7月25日'), ('上市公司', '上海艾融软件股份有限公司'), ('环节', '暂停上市'), ('上市公司', '中国广核电力股份有限公司')]
# [('披露时间', '7月25日'), ('上市公司', '中国广核电力股份有限公司'), ('上市公司', '安徽省交通建设股份有限公司'), ('环节', '筹备上市'), ('事件时间', '7月25日'), ('募资金额', '4亿元'), ('环节', '暂停上市'), ('上市公司', '上')]
# 55214c917f57f57e4cc03b6366832ca8
# [('环节', '正式上市'), ('上市公司', '昆山龙腾光电股份有限公司'), ('事件时间', '8月17日')]
# [('环节', '正式上市'), ('上市公司', '龙腾光电'), ('上市公司', '昆山龙腾光电股份有限公司'), ('事件时间', '8月17日')]
# 40addec3006c04369be00921dcad90e6
# [('被收购方', '中民外滩'), ('收购方', '雅生活服务'), ('交易金额', '121亿元'), ('收购标的', '50%股权及相应债权'), ('收购方', '绿地控股'), ('被收购方', '中民未来物业服务有限公司'), ('收购标的', '60%股权'), ('收购完成时间', '今年2月份'), ('披露时间', '9月6日')]
# [('被收购方', '中民外滩'), ('收购方', '雅生活服务'), ('被收购方', '中民未来物业服务'), ('交易金额', '121亿元'), ('收购标的', '50%股权及相应债权'), ('收购方', '绿地控股'), ('被收购方', '中民未来物业服务有限公司'), ('收购标的', '60%股权'), ('收购标的', '若干股权'), ('披露时间', '9月4日'), ('收购完成时间', '今年2月份'), ('披露时间', '9月6日'), ('收购方', '中')]
# df3b32bac765c458f2ed0d351ef5254f
# [('中标公司', '中汇集团'), ('招标方', '广东省江门市新会区'), ('中标日期', '6月3日'), ('披露日期', '6月5日'), ('中标标的', '土地使用权')]
# [('中标标的', '江门新会地皮'), ('中标标的', '广东省江门市新会区一土地使用权'), ('中标公司', '中汇集团'), ('中标日期', '6月3日'), ('中标金额', '约人民币6亿元'), ('披露日期', '6月5日'), ('中标公司', '中银国际')]
# 42561c27b82461ad33cbf81dbfc7b32d
# [('高管职位', '副总裁'), ('披露日期', '二〇二〇年五月十五日'), ('事件时间', '二〇二〇年五月十五日'), ('减持方', '李静'), ('任职公司', '永辉超市股份有限公司'), ('交易股票/股份数量', '105,000'), ('股票简称', '永辉超市'), ('减持部分占总股本比例', '0.001%'), ('高管姓名', '李静'), ('变动类型', '辞去'), ('披露时间', '二〇二〇年五月十五日')]
# [('减持方', '李静'), ('交易股票/股份数量', '105,000'), ('披露时间', '二〇二〇年五月十'), ('股票简称', '永辉超市'), ('减持部分占总股本比例', '0.001%')]
# c090032982e2fc2a1c0fcaeeed32f435
# [('回购方', '国祯环保'), ('每股交易价格', '不超过人民币13.50元'), ('交易金额', '1.5亿-3亿元')]
# [('回购方', '国祯环保'), ('每股交易价格', '不超13.50元'), ('每股交易价格', '不超过人民币13.50元'), ('交易金额', '1.5亿-3亿元')]
# e63d5f8717d327f9296537e4b3562740
# [('公司名称', '乐视'), ('公司名称', '小米'), ('公司名称', '海尔'), ('披露时间', '8月29日'), ('公司名称', '海信'), ('约谈机构', '江苏省消保委'), ('公司名称', '夏普'), ('公司名称', '长虹'), ('公司名称', '创维')]
# [('约谈机构', '江苏省消保委'), ('公司名称', '创维海信小米乐视'), ('公司名称', '小小米乐视'), ('被约谈时间', '8月29日')]
# 8874c4a7816f9f95ecbf5d8c4a0f2ab7
# [('质押方', '袁雄贵'), ('质押物', '股票'), ('质押物占持股比', '76.76%'), ('质押物占总股比', '5.02%'), ('质押方', '樟树市悦玩投资管理中心'), ('质押股票/股份数量', '400万'), ('质押物所属公司', '天舟文化'), ('质押方', '樟树市悦玩投资管理中心(有限合伙)'), ('披露时间', '9月30日'), ('质押物', '股份'), ('质押股票/股份数量', '0'), ('质押股票/股份数量', '300万'), ('质押股票/股份数量', '约4239.59万'), ('事件时间', '截止目前'), ('质押方', '樟树悦玩持有公司'), ('质押物占持股比', '68.14%'), ('质押股票/股份数量', '约3218.29万')]
# [('质押方', '袁雄贵'), ('质押物占持股比', '76.76%'), ('质押物占总股比', '5.02%'), ('质押方', '樟树市悦玩投资管理中心'), ('质押物所属公司', '天舟文化'), ('质押方', '一一致行动人'), ('质押物占总股比', '5.02'), ('披露时间', '9月30日'), ('质押物', '股份'), ('质押物', '股权'), ('质押股票/股份数量', '300万'), ('事件时间', '截止目前'), ('质押股票/股份数量', '约4239.59万'), ('质押物占持股比', '68.14%'), ('质押方', '袁雄贵及')]
# d82e73bb9ef5fee94cd5defeca157c4f
# [('披露时间', '2020年3月17日'), ('回购方', '华平信息技术股份有限公司'), ('回购股份数量', '230.6万')]
# [('回购方', '华平信息技术股份有限公司'), ('回购股份数量', '230.6万')]
# 1298d0a9cc37d72805fdbd65824adbff
# [('质押物占总股比', '10.79%'), ('披露时间', '9月20日'), ('质押方', '邹鹏持'), ('质押物占持股比', '17.95%'), ('质押物', '股份'), ('质押物占持股比', '82.05%'), ('质押物所属公司', '万里石'), ('质押股票/股份数量', '472万'), ('质押股票/股份数量', '2157.57万'), ('事件时间', '截至本公告披露日'), ('质押方', '邹鹏')]
# [('质押物占总股比', '10.79'), ('披露时间', '9月20日'), ('质押物占持股比', '17.95%'), ('质押物', '股份'), ('质押物占持股比', '82.05%'), ('质押物所属公司', '万里石'), ('质押股票/股份数量', '472万'), ('质押股票/股份数量', '2157.57万'), ('事件时间', '截至本公告披露日'), ('质押方', '邹鹏')]
# f973dd0e45de9c9e7270f0271456128d
# [('减持方', '卫狮投资'), ('交易完成时间', '2019年1月31日-2019年7月23日'), ('减持部分占总股本比例', '13.19%'), ('减持方', 'CIENAENTERPRISESLIMITED'), ('交易完成时间', '2019年2月25日-2019年6月19日'), ('减持部分占总股本比例', '9.06%'), ('交易股票/股份数量', '约6329.46万'), ('股票简称', '鹏鹞环保'), ('交易股票/股份数量', '约4348.58万'), ('披露时间', '7月24日')]
# [('减持方', '卫狮投资'), ('减持方', 'CIENA ENTERPRISES'), ('交易完成时间', '2019年1月31日-2019年7月23日'), ('减持方', 'CIENA ENTERPRISES LIMITED'), ('减持部分占总股本比例', '13.19%'), ('交易完成时间', '2019年2月25日-2019年6月19日'), ('减持方', '卫狮投资有限公司'), ('交易股票/股份数量', '约6329.46万'), ('交易完成时间', '截至2019年7月23日'), ('减持部分占总股本比例', '9.06'), ('股票简称', '鹏鹞环保'), ('交易股票/股份数量', '约4348.58万'), ('披露时间', '7月24日')]
# 6ca111c4bcd011be9509cfc96978ecb9
# [('每股交易价格', '最低价为2.20港元'), ('交易金额', '37,330,980.00港元'), ('回购完成时间', '截至本公告日'), ('每股交易价格', '最高价为2.32港元'), ('回购股份数量', '16,348,000'), ('披露时间', '二○二○年九月十日'), ('占公司总股本比例', '0.11%'), ('占公司总股本比例', '0.55%'), ('回购方', '上海电气集团股份有限公司')]
# [('回购方', '上海电气集团股份有限公司'), ('每股交易价格', '最低价为2.20港元'), ('交易金额', '37,330,980.00港元'), ('每股交易价格', '最高价为2.32港元'), ('披露时间', '二○二○年九月'), ('回购股份数量', '16,348,000'), ('回购完成时间', '当'), ('占公司总股本比例', '0.11%'), ('回购股份数量', '不超过5000万'), ('占公司总股本比例', '0.55%'), ('回购完成时间', '截至本公告日')]
# 0f70d3d8f8f032dc78caba8ed06f8507
# [('变动类型', '退休'), ('变动类型', '不再担任'), ('高管职位', '党委副书记'), ('高管职位', '副局长'), ('事件时间', '2018年2月'), ('事件时间', '2018年12月'), ('高管姓名', '钱丰'), ('任职公司', '黄山市公安局')]
# []
# bff729737c2abe6457f6c44798c86e45
# [('收购标的', '17%股权'), ('回购方', '联合光伏常州'), ('交易金额', '人民币4816.39万元'), ('被收购方', '丰县晖泽光伏能源有限公司'), ('回购完成时间', '2020年9月15日'), ('收购方', '熊猫绿能')]
# [('被收购方', '丰县晖泽光伏能源'), ('交易金额', '4816.39万元'), ('交易金额', '人民币4816.39万元'), ('被收购方', '丰县晖泽光伏能源有限公司'), ('回购完成时间', '2020年9月15日'), ('收购标的', '股'), ('收购标的', '17%股权'), ('收购方', '熊猫绿能')]
# 218ccace4c8d817b735a9b202f9cfca2
# [('中标金额', '49.67亿元'), ('中标标的', '颐和嘉年城项目“14171亩土地一级开发整理及8000亩森林公园、5150亩霞飞湖开挖工程（EPC）'), ('中标日期', '近日'), ('招标方', '山西运城'), ('中标公司', '中国铁建港航局集团'), ('中标公司', '中铁第一勘察设计院集团')]
# [('中标金额', '49.67亿元'), ('中标标的', '山西运城颐和嘉年城项目“14171亩土地一级开发整理及8000亩森林公园、150亩霞飞湖开挖工程（EPC）'), ('中标日期', '近日'), ('中标标的', '5150亩霞飞湖开挖工程（EPC）'), ('招标方', '山西运城'), ('中标公司', '中国铁建港航局集团'), ('中标公司', '中铁第一勘察设计院集团')]
# 31288aabe3b01933379c62e8f1391d92
# [('中标公司', '杭州园林'), ('披露日期', '10月29日'), ('中标金额', '约25,592万元'), ('中标标的', '安徽省淮北市杜集区重点采煤沉陷区朔西湖环境治理项目（一期）EPC总承包'), ('中标日期', '2019年10月28日'), ('招标方', '淮北市朔西湖保护开发建设有限公司')]
# [('中标公司', '数字政通'), ('中标公司', '杭州园林'), ('披露日期', '10月29日'), ('中标金额', '约25,592万元'), ('中标标的', '安徽省淮北市杜集区重点采煤沉陷区朔西湖环境治理项目（一期）EPC总承包'), ('中标日期', '2019年10月28日'), ('招标方', '淮北市朔西湖保护开发建设有限公司')]
# 97bc871b37db26837929a5310fcd0c7e
# [('减持部分占总股本比例', '10.00%'), ('股票简称', '嘉友转债'), ('交易股票/股份数量', '72万'), ('减持方', '孟联'), ('交易完成时间', '2020年9月16日'), ('披露时间', '9月16日')]
# [('股票简称', '嘉友转债'), ('交易股票/股份数量', '72万'), ('减持部分占总股本比例', '10.00'), ('减持部分占总股本比例', '10%'), ('减持方', '孟联'), ('交易完成时间', '2020年9月16日'), ('股票简称', '嘉友国际'), ('披露时间', '9月16日')]
# 3b54071303da833981d7e2cf110d2d93
# [('中标公司', '博天环境 集团股份有限公司'), ('中标日期', '8月1日'), ('招标方', '湖北蔡甸区集镇'), ('中标标的', '生活污水治理一体化PPP项目社会资本采购')]
# [('中标公司', '博天环境 集团股份有限公司'), ('披露日期', '8月1日'), ('中标标的', '湖北蔡甸区集镇生活污水治理一体化PPP项目')]
# 95b545ecbb702cb049219da013b2000f
# [('回购方', '富智康集团'), ('交易金额', '138.2万港元'), ('回购完成时间', '2020年9月17日'), ('披露时间', '2020年9月17日'), ('占公司总股本比例', '140.2万'), ('每股交易价格', '0.98-0.99港元')]
# [('回购方', '富智康集团'), ('交易金额', '138.2万港元'), ('回购完成时间', '2020年9月17日'), ('回购股份数量', '140.2万'), ('每股交易价格', '0.98-0.99港')]
# e3ad61d8e83f42978fc81458de6b2fbb
# [('收购标的', '93.33%股权'), ('被收购方', '南京金智视讯技术有限公司'), ('披露时间', '7 月 16日'), ('交易金额', '3080万元'), ('收购方', '江苏东大金智信息系统有限公司')]
# [('被收购方', '金'), ('收购标的', '93.33%股权'), ('被收购方', '南京金智视讯技术有限公司'), ('收购完成时间', '截止目前'), ('披露时间', '7 月 16日'), ('交易金额', '3080万元'), ('收购方', '江苏东大金智信息系统有限公司')]
# 8a52cceda96c8b879e32135a71b0d3bd
# [('招标方', '山东泰安市中心医院分院'), ('中标公司', '中国二十二冶'), ('中标标的', '扩建项目施工总承包工程'), ('中标日期', '11月2日')]
# [('中标公司', '中国二十二冶'), ('招标方', '山东省泰安市中心医院分院'), ('招标方', '山东泰安市中心医院分院'), ('中标标的', '（市传染病医院）扩建项目施工总承包工程'), ('中标日期', '11月2日')]
# a778e56de30b412774fd94ed12e61410
# [('交易股票/股份数量', '不超过1000万'), ('交易完成时间', '本公告之日起15个交易日后的六个月内'), ('披露时间', '8月18日'), ('减持部分占总股本比例', '不超2.19%'), ('股票简称', '金盾股份'), ('减持方', '王淼根')]
# [('披露时间', '今日'), ('交易股票/股份数量', '不超过1000万'), ('减持部分占总股本比例', '2.19%'), ('披露时间', '8月18日'), ('交易完成时间', '本公告之日起15个交易日后的六个月内'), ('股票简称', '金盾股份'), ('减持部分占总股本比例', '不超.19%'), ('交易完成时间', '在公告之日起15个交易日后的六个月内'), ('减持方', '王淼根')]
# 43904e88b736ac834b8087a5d09b9ec5
# [('亏损变化', '同比扩大约35.98%'), ('财报周期', '2019年中期'), ('净亏损', '约1.97亿港元'), ('披露时间', '8月12日'), ('公司名称', '有赞')]
# [('亏损变化', '同比扩大约35.98%'), ('财报周期', '2019年中期'), ('净亏损', '约1.97亿港元'), ('净亏损', '约4.11亿港元'), ('披露时间', '8月12日'), ('财报周期', '上半年'), ('公司名称', '有赞')]
# 8b22e04af7a333f3a76d40ef6c33bc8b
# [('交易股票/股份数量', '7,000,006'), ('交易完成时间', '2019年2月18日至2019年8月7日'), ('股票简称', '富奥股份'), ('交易金额', '32,284,932.46元'), ('披露时间', '8月9日'), ('增持方', '吉林省天亿投资有限公司'), ('增持部分占总股本比例', '0.39%')]
# [('交易完成时间', '2019年2月18日至2019年8月7日'), ('交易股票/股份数量', '7,000,006'), ('股票简称', '富奥股份'), ('增持部分占总股本比例', '0.39%'), ('交易完成时间', '截至2019年8月7日'), ('交易金额', '32,284,932.46元'), ('披露时间', '8月9日'), ('增持方', '天亿投资有限公司'), ('增持方', '吉林省亿投资有限公司')]
# ad6ce7c4f547c93efc184bd1c0b2a154
# [('中标标的', '生活垃圾焚烧发电项目特许经营权'), ('招标方', '石家庄市灵寿县'), ('中标日期', '8月22日'), ('中标公司', '东方能源（河北公司）')]
# [('中标公司', '东方能源（'), ('中标日期', '8月22日'), ('中标标的', '灵寿生活垃圾焚烧发电项目'), ('中标标的', '特许经营权'), ('招标方', '石家庄市寿县')]
# 5a92f20e17a8b64eb45715c32129b0ce
# [('质押方', '江河汇众'), ('质权方', '中国银河(11.980,0.04,0.34%)证券'), ('质押物占持股比', '29.33%'), ('事件时间', '截至公告日'), ('质押股票/股份数量', '4580万'), ('质押股票/股份数量', '7055.5万'), ('质押物', '股份'), ('质押物所属公司', '江河集团'), ('事件时间', '近日'), ('质押物占总股比', '3.97%'), ('质押物占总股比', '6.11%'), ('披露时间', '9月10日'), ('质押方', '天津江河汇众企业管理合伙企业(有限合伙)')]
# [('质押方', '天津江河汇众企业管理合伙企业'), ('质押方', '江河汇众'), ('质押物', '股票'), ('质权方', '中国银河(11.980,0.04,0.34%)证券'), ('质押物占持股比', '29.33%'), ('事件时间', '截至公告日'), ('质押物占总股比', '3.97'), ('质押股票/股份数量', '4580万'), ('质押股票/股份数量', '7055.5万'), ('质押物', '股份'), ('质押物所属公司', '江河集团'), ('事件时间', '近日'), ('质押物占总股比', '6.11%'), ('披露时间', '9月10日'), ('质押方', '天津江河汇众企业管理合伙企业(有限合伙)')]
# 40eccbbcde99f8f8546567964cc5407e
# [('证券代码', '09633.HK'), ('发行价格', '33港元'), ('上市公司', '农夫山泉'), ('环节', '正式上市'), ('事件时间', '9月8日'), ('市值', '约3698亿港元')]
# [('市值', '约为4454亿港元'), ('证券代码', '09633.HK'), ('上市公司', '农夫山泉'), ('环节', '正式上市'), ('事件时间', '9月8日')]
# f7c72b88188bdb556c7863d0b4e3c847
# [('交易完成时间', '上周的大部分时间'), ('股票简称', 'Fastly')]
# []
# e9aa55070ec2cfc9dbca5f681caf4120
# [('增持方', '阿里巴巴'), ('收购标的', '部分股份'), ('被收购方', '申通'), ('被收购方', '百世汇通'), ('收购方', '阿里'), ('交易股票/股份数量', '379,179,681'), ('被收购方', '中通'), ('披露时间', '9月1日'), ('交易金额', '66亿元'), ('每股交易价格', '17.406元'), ('股票简称', '圆通速递'), ('被收购方', '韵达'), ('增持部分占总股本比例', '12％')]
# [('收购完成时间', '2015年5月'), ('被收购方', '圆通快递'), ('收购标的', '379'), ('收购标的', '部'), ('被收购方', '申通'), ('被收购方', '百世汇通'), ('被收购方', '中通'), ('增持方', '阿里'), ('披露时间', '9月1日'), ('交易股票/股份数量', '379,179,681'), ('交易金额', '66亿元'), ('每股交易价格', '17.406元'), ('被收购方', '韵达'), ('股票简称', '圆通快递'), ('增持部分占总股本比例', '12％')]
# 78acc401d1723213944dd551586e7d2b
# [('中标金额', '189,670,000元'), ('披露日期', '6月9日'), ('中标日期', '近日'), ('招标方', '中核龙原科技有限公司'), ('中标标的', '示范快堆LOT566A-一体化扩散型氢计第三次招标采购项目'), ('中标公司', '四川华都核设备制造有限公司')]
# [('中标金额', '94,835,000元'), ('中标金额', '189,670,000元'), ('披露日期', '6月9日'), ('中标日期', '近日'), ('招标方', '中核龙原科技有限公司'), ('中标标的', '示范快堆LOT566A-一体化扩散型氢计第三次招标采购项目'), ('中标公司', '四川华都核设备制造有限公司')]
# 1b37feb1c51e83fa1d98bee80ccad306
# [('亏损变化', '减少'), ('净亏损', '1,013,723.56元'), ('披露时间', '近日'), ('公司名称', '昆达天元'), ('财报周期', '2020年半年度')]
# [('亏损变化', '减少'), ('亏损变化', '同期少'), ('净亏损', '1,013,723.56元'), ('披露时间', '近日'), ('公司名称', '昆达天元'), ('财报周期', '2020年半年度')]
# 31fd49663d63bddc94e0963600b9ccc5
# [('环节', '正式上市'), ('披露时间', '２０２０年５月１８日'), ('上市公司', '浙江浙矿重工股份有限公司')]
# [('环节', '正式上市')]
# ec86cc5bd00159382d5e851f43114f7b
# [('融资金额', '2.5亿美元'), ('投资方', 'Dragoneer Investment Group'), ('投资方', 'SoftBank capital软银海外'), ('投资方', 'General Atlantic泛大西洋投资'), ('领投方', 'SoftBank capital软银海外'), ('被投资方', 'QuintoAndar'), ('融资轮次', 'D'), ('披露时间', '9月10日')]
# [('融资金额', '2.5亿美元'), ('投资方', 'Dragoneer Investment Group'), ('投资方', 'SoftBank capital软银海外'), ('投资方', 'General Atlantic泛大西洋投资'), ('领投方', 'SoftBank capital软银海外'), ('被投资方', 'QuintoAndar'), ('融资轮次', 'D'), ('披露时间', '9月10日'), ('领投方', 'eer')]
# 29cc3eca47033d64a65f75e667d85db4
# [('回购股份数量', '2.4万'), ('回购完成时间', '2019年8月21日'), ('每股交易价格', '3.34港元至3.35港元'), ('交易金额', '约8.03万港元'), ('回购方', '新鸿基公司')]
# [('回购完成时间', '2019年8月21日'), ('回购股份数量', '2.4万'), ('每股交易价格', '3.34港元至3.35港元'), ('占公司总股本比例', '约0.0012%'), ('交易金额', '约8.03万港元'), ('回购方', '新鸿基公司')]
# 88351a7d95bb194bd337977d5626bd64
# [('质押股票/股份数量', '约1.4亿'), ('质押物所属公司', '江苏江南高纤股份有限公司'), ('事件时间', '2020年6月24日'), ('质押物占总股比', '8.08%'), ('事件时间', '2020年6月23日'), ('质权方', '东吴证券股份有限公司'), ('质押方', '陶冶'), ('质押物', '股份'), ('质押物占持股比', '30.49%'), ('质押股票/股份数量', '5868万'), ('披露时间', '6月24日晚间'), ('质押物所属公司', '江南高纤'), ('质押股票/股份数量', '约1.75亿'), ('质押方', '陶国平'), ('质权方', '申万宏源证券股份有限公司'), ('事件时间', '截至本公告日')]
# [('质押股票/股份数量', '约1.4亿'), ('事件时间', '2020年6月24日'), ('事件时间', '2020年6月23日'), ('质押物占总股比', '8.08%'), ('质押物', '股份'), ('质押股票/股份数量', '1.75亿'), ('质押物占持股比', '30.49%'), ('披露时间', '6月24日晚间'), ('质押物所属公司', '有限公司'), ('质权方', '东吴证券'), ('质押物所属公司', '江南高纤'), ('事件时间', '截至本公告日'), ('质押方', '陶国平'), ('质押物所属公司', '江苏'), ('质押股票/股份数量', '5868万')]
# b14aafd91b75b4e750a98abb463aa126
# [('破产公司', '赫兹'), ('破产时间', '5月22日')]
# [('破产公司', '赫兹'), ('披露时间', '6月17日'), ('破产时间', '5月22日')]
# e6152173042a2b526992d41d8de27cb2
# [('披露时间', '2018年10月16日'), ('增持方', '于钊'), ('交易完成时间', '2018年10月17日至2018年11月16日'), ('股票简称', '盈康生命'), ('交易金额', '1亿元至2亿元')]
# [('披露时间', '2018年10月16日'), ('增持方', '于钊'), ('交易完成时间', '2018年10月17日至2018年11月16日'), ('股票简称', '盈康生命'), ('披露时间', '2018年11月16日'), ('交易金额', '1亿元至2亿元')]
# ab7c301274326468c91c1b37b104f905
# [('财报周期', '截至2019年12月31日止年度'), ('净亏损', '2.8亿港元'), ('亏损变化', '同比扩大4.6倍'), ('公司名称', '新威国际')]
# [('披露时间', '5月28日'), ('亏损变化', '同比扩大4.6倍'), ('公司名称', '新威国际'), ('财报周期', '截至2019年12月31日止年度'), ('净亏损', '2.8亿港元')]
# 605212934bdac22b5eaccb95d6bba184
# [('被收购方', '基石策略控股'), ('收购标的', '80%股权'), ('交易金额', '1000万元')]
# []
# 762398cee86858b132934bdfd95f9312
# [('公司名称', '华业资本'), ('净亏损', '逾27亿元'), ('财报周期', '2019年上半年'), ('财报周期', '2018年'), ('净亏损', '逾64亿元'), ('公司名称', '北京华业资本控股股份有限公司')]
# [('财报周期', '2019年上半年'), ('公司名称', '华业资本'), ('净亏损', '逾')]
# 4c7c6192843f92845e876cc74ee35275
# [('披露日期', '4月28日'), ('任职公司', '国联安基金'), ('变动后职位', '基金经理'), ('高管姓名', '朱靖宇')]
# [('披露日期', '4月28日'), ('任职公司', '国联安基金'), ('变动后职位', '基金经理'), ('变动类型', '增聘'), ('高管姓名', '朱靖宇')]
# ac509285e9297c8f792f2ff270b8d7c7
# [('每股交易价格', '9.16元'), ('股票简称', '洲明科技'), ('减持方', '林洺锋'), ('披露时间', '9月11日'), ('交易股票/股份数量', '4589多万'), ('交易金额', '4.2亿元')]
# [('披露时间', '今日'), ('每股交易价格', '9.16元'), ('披露时间', '9月11日早上'), ('股票简称', '巴可电子'), ('股票简称', '洲明科技'), ('减持方', '林洺锋'), ('交易股票/股份数量', '4589万'), ('交易金额', '4.2亿元')]
# 688278bdfafc38d13206285491ee5f2d
# [('回购股份数量', '1.8万'), ('回购完成时间', '2019年8月19日'), ('每股交易价格', '5.37港元及5.50港元'), ('每股交易价格', '5.35港元及5.49港元'), ('占公司总股本比例', '0.002%'), ('回购完成时间', '2019年8月16日'), ('交易金额', '约27.07万港元'), ('占公司总股本比例', '0.001%'), ('回购股份数量', '5万'), ('交易金额', '约9.71万港元'), ('回购方', '百宏实业')]
# [('回购股份数量', '6.8万'), ('回购完成时间', '2019年8月19日'), ('每股交易价格', '5.37港元及5.50港元'), ('每股交易价格', '5.35港元'), ('每股交易价格', '55.50港元'), ('交易金额', '约36.78万港元'), ('交易金额', '约27.07万港元'), ('回购完成时间', '2019年8月16日'), ('占公司总股本比例', '0.002%'), ('占公司总股本比例', '0.001%'), ('每股交易价格', '5.49港元'), ('交易金额', '约9.71万港元'), ('回购方', '百宏实业')]
# 9471af3906af6d1d76de2f66aa87ae5b
# [('收购方', '金宇车城'), ('财报周期', '2020年第一季度'), ('公司名称', '金宇车城'), ('净亏损', '14,677,185.52元'), ('披露时间', '近日'), ('被收购方', '十方环能'), ('净亏损', '16,997,987.40元'), ('财报周期', '上年同期')]
# [('收购方', '金宇车城'), ('收购完成时间', '20'), ('财报周期', '2020年第一季度'), ('公司名称', '金宇车城'), ('净亏损', '14,677,185.52元'), ('被收购方', '金宇车'), ('披露时间', '近日'), ('被收购方', '十方环能'), ('净亏损', '16,997,987.40元'), ('财报周期', '上年同期')]
# 0ec441e64727febe3be0fef936272bf8
# [('交易股票/股份数量', '不超过3066万'), ('披露时间', '5月28日'), ('减持方', '李平'), ('减持部分占总股本比例', '6%'), ('减持部分占总股本比例', '3%'), ('股票简称', '东土科技'), ('交易股票/股份数量', '不超过1551万'), ('交易完成时间', '2019年10月17日至2020年4月16日')]
# [('交易股票/股份数量', '不超过3066万'), ('披露时间', '9月18日晚间'), ('披露时间', '今年5月28日'), ('减持部分占总股本比例', '2.08%'), ('减持方', '李平'), ('减持部分占总股本比例', '不超6%'), ('减持部分占总股本比例', '6%'), ('股票简称', '东土科技'), ('减持部分占总股本比例', '3%'), ('交易股票/股份数量', '不超过1551万'), ('交易完成时间', '2019年10月17日至2020年4月16日'), ('减持部分占总股本比例', '2.08')]
# 6986269ce2175174291bc587992d1212
# [('交易完成时间', '截至2020年7月22日'), ('减持部分占总股本比例', '1%'), ('披露时间', '7月22日晚间'), ('每股交易价格', '不低于29.07元'), ('股票简称', '精研科技'), ('交易股票/股份数量', '不超过 115.3473万'), ('减持方', '赵梦亚')]
# [('交易完成时间', '截至2020年7月22日'), ('减持部分占总股本比例', '1%'), ('披露时间', '7月22日晚间'), ('每股交易价格', '不低于29.07元'), ('股票简称', '精研科技'), ('减持方', '赵梦亚'), ('交易股票/股份数量', '不超过 115.3473万'), ('交易完成时间', '2020 年 2 月 26 日')]
# 63400e83748945084f91d49ec2e954ee
# [('融资金额', '4亿人民币'), ('披露时间', '4月17日'), ('投资方', '盛宇投资'), ('事件时间', '去年'), ('投资方', '招银国际'), ('投资方', '粤科鑫泰'), ('融资轮次', 'C'), ('投资方', '渤海中盛'), ('融资轮次', 'C +'), ('领投方', '招银国际'), ('被投资方', '编程猫'), ('融资金额', '2.5亿元')]
# [('融资金额', '4亿人民币'), ('披露时间', '今'), ('披露时间', '4月17日'), ('融资金额', '2.5亿'), ('融资轮次', 'C+'), ('事件时间', '今日'), ('投资方', '芥末堆'), ('投资方', '盛宇投资'), ('事件时间', '去年'), ('投资方', '招银国际'), ('投资方', '粤科鑫泰'), ('事件时间', '截止目前'), ('投资方', '渤海中盛'), ('领投方', '招银国际'), ('被投资方', '编程猫'), ('融资金额', '2.5亿元')]
# c0ab28ea92bd444339de31e29d17c86c
# [('交易金额', '1501万美元'), ('回购方', '安东油田服务'), ('回购完成时间', '本公告日期'), ('占公司总股本比例', '约5.0%')]
# [('回购方', '安东油田服务'), ('回购完成时间', '本公告日期'), ('占公司总股本比例', '约5.0%'), ('交易金额', '1.16亿美元'), ('交易金额', '1501万美元')]
# b47ead3d6d476da0525d698415899b59
# [('交易金额', '69.48万元'), ('占公司总股本比例', '0.997%'), ('回购完成时间', '本年内至今为止'), ('回购股份数量', '20.8万'), ('回购完成时间', '2020年09月30日'), ('回购方', '康臣药业'), ('每股交易价格', '3.33港元至3.35港元'), ('回购股份数量', '842.7万')]
# [('交易金额', '69.48万元'), ('回购股份数量', '20.8万'), ('回购完成时间', '2020年09月30日'), ('回购方', '康臣药业'), ('每股交易价格', '3.33港元至3.35港元')]
# a413e8c72bba3359cc9a5cf6cea4fc8b
# [('破产公司', 'OneWeb'), ('破产时间', '今年3月')]
# [('债务规模', '10亿美元'), ('破产公司', 'OneWeb'), ('披露时间', '5月8日'), ('破产时间', '今年3月'), ('破产公司', 'Cerberus Capital Management'), ('破产公司', 'Eutelsat')]
# 713a9d5d54604e8ed43f9cb669a9d2a5
# [('财报周期', '第二季度'), ('净亏损', '6.81亿元'), ('公司名称', '瑞幸咖啡')]
# [('披露时间', '周三'), ('公司名称', '瑞幸咖啡'), ('净亏损', '6.81亿'), ('披露时间', '14日'), ('财报周期', '第二季度'), ('净亏损', '6.81亿元'), ('亏损变化', '同比扩大')]
# 51b81ce2379146b04a1440e4f6d2bf39
# [('减持部分占总股本比例', '0.8145%'), ('交易股票/股份数量', '不超过34,176,237'), ('披露时间', '2020年5月19日'), ('交易完成时间', '公告发布披露之日起15个交易日后的6个月内'), ('减持方', '张立忠'), ('股票简称', '大北农')]
# [('减持部分占总股本比例', '0.8145%'), ('交易股票/股份数量', '不超过34,176,237'), ('交易完成时间', '公公告发布披露之日起15个交易日后的6个月内'), ('披露时间', '2020年5月19日'), ('减持方', '张立忠'), ('减持方', '谈松林'), ('股票简称', '大北农'), ('减持方', '王丽娜')]
# d7b6d27d78cf7b627d2de809199744e2
# [('减持部分占总股本比例', '不超过公司总股本的3.519%'), ('股票简称', '宏盛股份'), ('减持方', '常州中科')]
# [('减持部分占总股本比例', '不超过公司总股本的3.519%'), ('减持部分占总股本比例', '3.5'), ('股票简称', '宏盛股份'), ('减持方', '常州中科')]
# f7e1ebeff3301ce9ae40b216535183d1
# [('融资金额', '6亿元'), ('被投资方', '苏州苏高新集团有限公司'), ('披露时间', '31日')]
# []
# bbc1e37960552fe00f1043fcc1d89c1e
# [('质押股票/股份数量', '50,000,000'), ('事件时间', '2019年9月23日'), ('质押方', '中国宝安(4.600,-0.12,-2.54%)集团股份有限公司'), ('质押物', '无限售流通股'), ('质押股票/股份数量', '100,000,000'), ('质押物所属公司', '马应龙药业集团股份有限公司'), ('事件时间', '截至2019年9月23日'), ('质押物占持股比', '79.26%'), ('披露时间', '2019年9月24日'), ('质押物占总股比', '23.20%'), ('事件时间', '2019年9月20日'), ('质权方', '招商银行股份有限公司深圳分行'), ('质押物占总股比', '11.60%')]
# [('质押股票/股份数量', '50,000,000'), ('质押方', '中国宝安(4.600,-0.12,-2.54%)集团股份有限公司'), ('质押方', '中国宝安(4.600,-0.12,-2.54%)集团'), ('质押物', '无限售流通股'), ('质押股票/股份数量', '100,000,000'), ('质押方', '中国宝安'), ('事件时间', '截至2019年9月23日'), ('质押物占持股比', '79.26%'), ('质押物所属公司', '马应龙药业集团股份有限公司'), ('质押物占总股比', '23.20%'), ('事件时间', '2019年9月20日'), ('披露时间', '2019年9月2'), ('质押物占总股比', '11.60%'), ('质权方', '招商银行(34.040,-0.47,-1.36%)股份有限公司深圳分行')]
# 7e3cb563cdb77a2f4cbbd851f0eae26e
# [('交易股票/股份数量', '不超过1.56亿'), ('披露时间', '10月16日晚间'), ('交易股票/股份数量', '0.44亿'), ('减持方', '武汉当代科技产业集团股份有限公司'), ('减持方', '湖北省联合发展投资集团有限公司'), ('股票简称', '天风证券'), ('减持部分占总股本比例', '0.67%'), ('减持部分占总股本比例', '2.34%')]
# [('交易股票/股份数量', '不超过1.56亿'), ('披露时间', '10月16日晚间'), ('交易股票/股份数量', '0.44亿'), ('减持方', '武汉当代科技产业集团股份有限公司'), ('减持方', '湖北省联合发展投资集团有限公司'), ('交易完成时间', '本周'), ('股票简称', '天风证券'), ('减持部分占总股本比例', '2.34%'), ('减持部分占总股本比例', '0.67%'), ('披露时间', '10月15日晚间'), ('减持方', '天风证券'), ('股票简称', '天风')]
# cb84b1331e94c777edefd24185b45cdd
# [('融资轮次', 'A+'), ('投资方', 'CMC资本'), ('披露时间', '7月1日'), ('被投资方', 'HIFIVE'), ('融资金额', '数千万元')]
# [('融资轮次', 'A+'), ('融资轮次', 'A'), ('投资方', 'CMC资本'), ('披露时间', '7月1日'), ('被投资方', 'HIFIVE'), ('融资轮次', 'A＋'), ('被投资方', '成都嗨翻屋科技有限公司'), ('融资金额', '数千万元')]
# 44e7342ec26ae7955009df9262dfc022
# [('披露时间', '6 月 29日'), ('质押物', '股权'), ('质押物所属公司', '*ST盐湖'), ('质押股票/股份数量', '8400万'), ('质押方', '青海省国有资产投资管理有限公司')]
# [('披露时间', '6 月 29日'), ('质押物', '股权'), ('质押物所属公司', '*ST盐湖'), ('质押股票/股份数量', '8400万'), ('质押物', '股'), ('质押方', '青海省国有资产投资管理有限公司')]
# a72e8ff7e882b7f2ed3722bb740cc3f4
# [('收购完成时间', '2020年中期'), ('被收购方', 'Tiffany&Co'), ('收购方', 'LVMH集团'), ('交易金额', '约为162亿美元'), ('披露时间', '6月2日')]
# [('收购完成时间', '2020年中期'), ('被收购方', 'Tiffany'), ('收购方', 'LVMH集团'), ('披露时间', '2019年11月'), ('交易金额', '约为162亿美元'), ('收购方', 'LVM')]
# d007691e8001bd7944bfd1c3cc500ead
# [('回购股份数量', '8.7万'), ('披露时间', '10月20日'), ('每股交易价格', '4.44-4.46港元'), ('被收购方', '江苏开磷瑞阳化工股份有限公司'), ('收购方', '*ST毅达'), ('回购方', '李氏大药厂'), ('交易金额', '38.77万港元'), ('回购完成时间', '2019年10月21日')]
# [('回购股份数量', '8.7万'), ('每股交易价格', '4.44-4.46港元'), ('回购方', '李氏大药厂'), ('交易金额', '38.77万港元'), ('回购完成时间', '2019年10月21日')]
# a979eb961424193bdd6eb8fc3eeabc2d
# [('高管姓名', '程昱'), ('事件时间', '近期'), ('披露日期', '昨日'), ('变动后公司名称', '苹果中国'), ('变动后职位', 'COO'), ('高管姓名', '王秀娟'), ('变动后职位', '总经理'), ('变动类型', '任命'), ('变动类型', '离职'), ('高管职位', '创始人'), ('任职公司', '大街网'), ('高管职位', 'COO'), ('任职公司', '美图公司'), ('变动后公司名称', '美图公司')]
# [('高管姓名', '程昱'), ('高管职位', '大'), ('事件时间', '近期'), ('披露日期', '昨日'), ('变动后职位', 'COO'), ('高管姓名', '王秀娟'), ('高管职位', '总经理'), ('变动类型', '任命'), ('变动类型', '离职'), ('高管职位', 'COO'), ('任职公司', '美图公司'), ('披露日期', '2017年11月')]
# 85661a9e2b4d9e5dbb9931dd466688f0
# [('上市公司', '河南金丹乳酸科技股份有限公司'), ('事件时间', '2020年7月20日'), ('上市公司', '北京竞业达数码科技(5.100,-0.04,-0.78%)股份有限公司'), ('上市公司', '东莞市奥海科技股份有限公司'), ('上市公司', '厦门力鼎光电(13.360,4.08,43.97%)股份有限公司'), ('上市公司', '新亚强硅化学股份有限公司'), ('上市公司', '广东蒙泰高新纤维股份有限公司'), ('事件时间', '2020年4月16日'), ('事件时间', '昨日'), ('事件时间', '2020年5月21日'), ('事件时间', '2020年4月29日'), ('环节', '筹备上市'), ('事件时间', '2020年4月9日'), ('上市公司', '温州市冠盛汽车零部件集团股份有限公司'), ('事件时间', '2020年1月16日'), ('事件时间', '2020年6月11日'), ('上市公司', '深圳欧陆通电子股份有限公司'), ('上市公司', '华丰动力股份有限公司')]
# [('上市公司', '东莞市奥海科技股份有限公司'), ('披露时间', '昨日'), ('事件时间', '2020年4月16日'), ('事件时间', '昨日'), ('事件时间', '2020年5月21日'), ('事件时间', '2020年4月29日'), ('上市公司', '广东蒙泰高新纤维股份有限公司'), ('上市公司', '河'), ('事件时间', '2020年4月9日'), ('环节', '筹备上市'), ('事件时间', '2020年1月16日'), ('上市公司', '华丰动力股份有限公司')]
# 8a5d58c463f4546abd62eaf9f35f5536
# [('高管姓名', '谢单'), ('变动类型', '提名'), ('变动后职位', '第十届董事会非独立董事候选人'), ('高管姓名', '于洋'), ('高管姓名', '林新阳'), ('高管姓名', '王乐祥'), ('高管姓名', '王全弟'), ('变动后职位', '第十届董事会独立董事候选人'), ('高管姓名', '龚神佑'), ('高管姓名', '郭华平'), ('任职公司', '博汇纸业')]
# []
# fd9b06c4db82e8633490b96c4ee5aae1
# [('变动后职位', '副总裁'), ('高管姓名', '马祥'), ('变动类型', '聘任'), ('变动后职位', '财务总监'), ('任职公司', '金龙汽车'), ('高管姓名', '梁明煅'), ('高管姓名', '张斌'), ('披露日期', '9月4日晚间'), ('事件时间', '9月4日晚间'), ('变动类型', '出任'), ('高管姓名', '吴文彬')]
# [('高管姓名', '马祥'), ('变动后职位', '副总裁'), ('变动类型', '聘任'), ('变动后职位', '财务总监'), ('事件时间', '任期至本届董事会届满之日'), ('高管姓名', '梁明煅'), ('任职公司', '金龙汽车'), ('变动后职位', '公'), ('高管姓名', '张斌'), ('披露日期', '9月4日晚间'), ('变动类型', '出任'), ('事件时间', '任'), ('高管姓名', '吴文彬')]
# c3d146174a529bccf105d48723908e67
# [('债务规模', '20亿美元'), ('债权人', 'GSO Capital Partners'), ('破产时间', '当地时间5月4日'), ('债权人', 'Anchorage Capital'), ('破产公司', 'Chinos Holdings')]
# [('破产时间', '当地时间5月4日'), ('破产公司', 'GSO Capital Partners'), ('债务规模', '20亿美元'), ('破产公司', 'Chinos Holdings')]
# 59d2b231d286e3b50b1771fa782256eb
# [('事件时间', '11月26日'), ('募资金额', '134亿美金'), ('上市公司', '阿里巴巴'), ('环节', '正式上市'), ('证券代码', '9988.HK')]
# [('披露时间', '11月26日'), ('事件时间', '11月26日'), ('募资金额', '134亿美金'), ('上市公司', '阿里巴巴'), ('环节', '正式上市'), ('证券代码', '9988.HK')]
# ef89d66dee9130201645146f45a41cf3
# [('投资方', '合肥市产业投资引导基金有限公司'), ('领投方', '合肥市产业投资引导基金有限公司'), ('融资金额', '5亿元'), ('上市公司', '威马汽车'), ('融资金额', '10亿元'), ('环节', '筹备上市'), ('披露时间', '10月份'), ('投资方', '上海汽车工业(集团)总公司'), ('被投资方', '威马汽车'), ('融资轮次', 'D'), ('事件时间', '年内')]
# [('投资方', '合肥市产业投资引导基金有限公司'), ('融资金额', '1'), ('领投方', '合肥市产业投资引导基金有限公司'), ('融资金额', '5亿元'), ('上市公司', '威马汽车'), ('融资金额', '10亿元'), ('环节', '筹备上市'), ('投资方', '上海汽车工业(集团)总公司'), ('被投资方', '威马汽车'), ('融资轮次', 'D')]
# ae14f65f7fafb7095e8b4fcb503bf943
# [('收购标的', '股份'), ('收购方', '山东黄金'), ('交易金额', '3.92亿澳元'), ('被收购方', '卡帝诺资源有限公司')]
# [('收购方', '山东黄金香港'), ('交易金额', '约为3.92亿澳'), ('交易金额', '约为3.92亿澳元'), ('被收购方', '卡帝诺'), ('被收购方', '卡帝诺资源有限公司'), ('收购方', '山东黄金'), ('收购标的', '若干卡帝诺期权')]
# 564eff1dbf9fafd5114961448c63cbf9
# [('回购股份数量', '19.8万'), ('占公司总股本比例', '0.204%'), ('回购方', '精熙国际'), ('回购完成时间', '本年度内至今为止'), ('回购股份数量', '167.6万'), ('每股交易价格', '最高回购价0.5800港币'), ('回购完成时间', '2020年5月28日'), ('每股交易价格', '0.5821港币'), ('交易金额', '11.525324万港币')]
# [('回购股份数量', '19.8万'), ('回购方', '精熙国际'), ('回购完成时间', '本年度内至今为止'), ('回购股份数量', '167.6万'), ('交易金额', '11.525324万港币'), ('每股交易价格', '最高回购价0.5800港币'), ('占公司总股本比例', '0.204'), ('回购完成时间', '2020年5月28日'), ('每股交易价格', '0.5821港币'), ('回购股份数量', '1')]
# 77efcfbf05f603fe3bdf9880d931df7f
# [('中标日期', '8月19日'), ('招标方', '中国移动湖南公司长沙公司'), ('中标金额', '544万元'), ('披露日期', '8月19日'), ('中标标的', '2020-2021年度ICT短名单采购项目'), ('中标公司', '中科恒运')]
# [('中标日期', '今日'), ('中标日期', '8月19日'), ('中标金额', '544万元'), ('中标标的', 'IC'), ('披露日期', '8月19日'), ('中标标的', '2020-2021年度ICT短名单采购项目'), ('招标方', '中国移动长沙分公司'), ('中标公司', '中科恒运'), ('招标方', '中国移动')]
# 99677802a924c36f5eb5b3bd8f3a8f63
# [('质押物所属公司', '日照银行股份有限公司威海分行'), ('质押物占持股比', '46.94%'), ('披露时间', '11月11日晚间'), ('质押方', '好当家集团'), ('质押股票/股份数量', '3000万'), ('质押物', '股份'), ('质押物占持股比', '4.98%'), ('质押物所属公司', '好当家集团'), ('质押物占总股比', '2.05%'), ('质押物占总股比', '19.36%'), ('质押物', '流通股'), ('质权方', '日照银行股份有限公司威海分行'), ('事件时间', '2020年11月9日')]
# [('质押物所属公司', '山东好当家海洋发展股份有限公司'), ('质押物', '无限售流通股'), ('质押物占持股比', '46.94%'), ('披露时间', '11月11日晚间'), ('事件时间', '近'), ('质押股票/股份数量', '3000万'), ('质押股票/股份数量', '约2.83亿'), ('质押方', '好当家集团'), ('质押物所属公司', '好当家'), ('质押物占总股比', '19.36'), ('质权方', '日照银行'), ('质押物所属公司', '好当家集团'), ('质押物', '股份'), ('质押物', '股'), ('质押物占持股比', '4.98%'), ('质押物占总股比', '2.05%'), ('质权方', '日照银行股份有限公司威海分行'), ('事件时间', '2020年11月9日'), ('质押方', '好当家集团有限公司')]
# 74f4c33e74fbfb742daf8fb9bd5d178e
# [('每股交易价格', '15.96元'), ('回购完成时间', '2019年8月26日'), ('高管姓名', '袁健芳'), ('变动类型', '离职'), ('任职公司', '凯众股份'), ('高管姓名', '王慕昊'), ('回购方', '凯众股份'), ('披露日期', '8月21日'), ('回购股份数量', '9.9万')]
# [('每股交易价格', '15.96元'), ('回购完成时间', '2019年8月26日'), ('披露时间', '8月21日'), ('回购方', '凯众股份'), ('回购股份数量', '9.9万')]
# f166fad0ccfbb2149755d0fec84327db
# [('质押物占持股比', '54.30%'), ('质押方', '北京北明伟业控股有限公司'), ('事件时间', '截至2019年11月4日'), ('质押物', '股权'), ('质押物', '股份'), ('质押物占总股比', '7.77%'), ('质押股票/股份数量', '128,370,000'), ('披露时间', '2019年11月6日'), ('质押物所属公司', '石家庄常山北明科技股份有限公司')]
# [('质押物占持股比', '54.30%'), ('质押方', '北京北明伟业控股有限公司'), ('事件时间', '截至2019年11月4日'), ('质押物', '股份'), ('质押物占总股比', '7.77'), ('质押股票/股份数量', '128,370,000'), ('质押物所属公司', '石家庄常山北明科技股份有限公司')]
# 3de57cbbda70c2a02b2ebc25ba5d160b
# [('交易金额', '193.47万港元'), ('回购完成时间', '9月13日'), ('回购股份数量', '700万'), ('回购方', '中油燃气')]
# [('回购股份数量', '约2618万'), ('交易金额', '193.47万港元'), ('回购完成时间', '9月13日'), ('回购股份数量', '700万'), ('回购方', '中油燃气')]
# a1bd71fe0cfe304011ffac59c7dc663b
# [('减持方', '王安祥'), ('股票简称', '八菱科技'), ('披露时间', '2020年8月20日')]
# [('减持方', '王安祥')]
# ce1447cfb82a125308a6ae04fc449ce8
# [('变动类型', '退休'), ('环节', '正式上市'), ('高管姓名', '马云'), ('上市公司', '贝壳找房')]
# [('环节', '正式上市'), ('上市公司', '贝壳找房')]
# 73a84c980943108dc6b17f2f65ce7300
# [('收购方', '雅生活'), ('交易金额', '不超过5亿元'), ('被收购方', '新中民物业'), ('被收购方', '中民物业'), ('收购标的', '60%股权'), ('交易金额', '20.6亿'), ('披露时间', '9月26日'), ('交易金额', '15.6亿元')]
# [('收购方', '彩'), ('收购方', '雅生活'), ('被收购方', '广州粤华物业'), ('被收购方', '哈尔滨景阳物业'), ('被收购方', '青岛华仁物业'), ('收购标的', '各0%股权'), ('被收购方', '新中民物业'), ('被收购方', '中民物业'), ('收购标的', '60%股权'), ('交易金额', '不超过5亿元'), ('交易金额', '15.6亿元'), ('披露时间', '9月26日'), ('收购完成时间', '今年上半年'), ('收购标的', '60%股')]
# e4cd61a0e02d0eb73146b84b342d0c39
# [('亏损变化', '减少'), ('公司名称', '宏达矿业'), ('披露时间', '近日'), ('净亏损', '4,803,269.03元'), ('财报周期', '2020年半年度')]
# [('亏损变化', '减少'), ('公司名称', '宏达矿业'), ('披露时间', '近日'), ('净亏损', '4,803,269.03元'), ('亏损变化', '同期亏损减少'), ('财报周期', '2020年半年度')]
# 8890b579b0d3948776d8651eb32be6da
# [('中标标的', '滁河流域水环境综合治理项目'), ('交易完成时间', '近30日内'), ('交易股票/股份数量', '53.35万'), ('中标公司', '美尚生态'), ('股票简称', '美尚生态'), ('增持方', '北向资金'), ('披露日期', '10月25日晚间'), ('增持部分占总股本比例', '0.12%'), ('中标金额', '约9.3亿元')]
# [('披露日期', '10月25日晚间'), ('中标标的', '滁河流域水环境综合治理项目'), ('中标金额', '约9.3亿元'), ('中标公司', '美尚生态')]
# 8fbb1cef11c15d6c518a9da45b302265
# [('回购方', '腾讯'), ('交易金额', '2.2085亿港元'), ('披露时间', '9月5日'), ('回购股份数量', '67.66万')]
# [('交易金额', '2.2亿港元'), ('回购完成时间', '8月28日'), ('回购股份数量', '67.66万'), ('回购完成时间', '至今'), ('披露时间', '9月5日'), ('交易金额', '2.2085亿港元'), ('回购方', '腾讯')]
# c281623fc63f5f3aa4c37fb48d6f4fee
# [('投资方', '赛富投资基金'), ('融资轮次', 'A'), ('投资方', '方和资本'), ('被投资方', '青岛慧拓智能机器有限公司'), ('领投方', '赛富投资基金'), ('投资方', '汉能创投'), ('事件时间', '近日'), ('融资金额', '近亿元')]
# [('投资方', '赛富投资基金'), ('融资轮次', 'Pre-A'), ('事件时间', '2018年'), ('融资轮次', 'A'), ('投资方', '国科嘉和投资'), ('投资方', '方和资本'), ('被投资方', '青岛慧拓智能机器有限公司'), ('投资方', '汉能创投'), ('领投方', '赛富投资基金'), ('事件时间', '近日'), ('融资金额', '近亿元'), ('披露时间', '日')]
# 37002d4eff4d1083d3ec46e26d571844
# [('中标金额', '1.64亿元'), ('中标日期', '近日'), ('中标公司', '高能环境'), ('中标标的', '顺义区生活垃圾处理中心焚烧三期工程-五大主机系统成套设备采购、安装总承包”项目'), ('披露日期', '6月1日')]
# [('中标金额', '1.64亿元'), ('中标日期', '近日'), ('中标标的', '生生活垃圾处理中心焚烧三期工程-五大主机系统成套设备采购、安装总承包'), ('招标方', '北京顺义区'), ('中标公司', '高能环境'), ('披露日期', '6月1日'), ('中标标的', '顺义区生活垃圾处理中心焚烧三期工程-五大主机系统成套设备采购、安装总承包')]
# a1bc81929b321d686b38fa03d47f72bc
# [('质押物', '股权'), ('质押方', '袁永峰'), ('质押物所属公司', '苏州东山精密制造股份有限公司'), ('质押方', '袁永刚'), ('披露时间', '2020年6月23日')]
# [('质押物', '股份'), ('质押方', '袁永峰'), ('事件时间', '近日'), ('质押物所属公司', '苏州东山精密制造股份有限公司'), ('质押方', '袁永刚'), ('披露时间', '2020年6月2')]
# c7a9c13af8c0206d4f3f51bd37b6951e
# [('任职公司', '深圳市京基智农时代股份有限公司'), ('披露日期', '9月15日晚间'), ('变动类型', '聘任'), ('高管职位', '副总裁兼董事会秘书'), ('事件时间', '近日'), ('高管姓名', '胡琴'), ('高管姓名', '陈凯鸿'), ('变动类型', '辞去'), ('变动后职位', '董事会秘书')]
# [('任职公司', '深圳市京基智农时代股份有限公司'), ('披露日期', '9月15日晚间'), ('变动类型', '聘任'), ('变动后公司名称', '深圳市京基智农时代股份有限公司'), ('高管姓名', '陈凯鸿'), ('变动后职位', '董事会秘书')]
# acf4bc47212e621399c5aaecac5fa14a
# [('收购方', '*ST毅达'), ('披露时间', '10月20日晚间'), ('被收购方', '江苏开磷瑞阳化工股份有限公司')]
# [('收购完成时间', '22日'), ('被收购方', '江苏开磷瑞阳化工股份有限公司'), ('收购方', '通产丽星'), ('披露时间', '10月20日晚间')]
# 3b584ec6c2b890e2cb00732983866e4f
# [('净亏损', '130亿日元'), ('披露时间', '今日'), ('财报周期', '去年同期'), ('公司名称', '本田汽车'), ('财报周期', '2020财年第四季度'), ('净亏损', '295亿日元')]
# [('净亏损', '130亿日元'), ('财报周期', '去年同期'), ('公司名称', '本田汽车'), ('财报周期', '2020财年第四季度'), ('净亏损', '295亿日元'), ('亏损变化', '转盈为亏'), ('披露时间', '5月12日')]
# 4d3be5cbdf891d95178be418fa544b69
# [('质权方', '平安证券股份有限公司'), ('质押股票/股份数量', '320万'), ('质押物', '股份'), ('事件时间', '2019年8月28日'), ('质押物占总股比', '8.63%'), ('披露时间', '二〇一九年八月二十九日'), ('质押股票/股份数量', '9,854万'), ('质押方', '成都天齐实业（集团）有限公司'), ('质押物所属公司', '天齐锂业股份有限公司')]
# [('质权方', '兴业银行'), ('质押股票/股份数量', '670万'), ('质权方', '平安证券股份有限公司'), ('事件时间', '截止2019年8月28日'), ('质押股票/股份数量', '320万'), ('质押物', '股份'), ('事件时间', '2019年8月28日'), ('披露时间', '二〇一九年八月二十'), ('质押物占总股比', '8.63%'), ('质押股票/股份数量', '9,854万'), ('质押方', '成都天齐实业（集团）有限公司'), ('质押物所属公司', '天齐锂业股份有限公司')]
# eb1ec48cdc510b7173c038e8e2c0f457
# [('破产公司', '安徽淮化股份有限公司'), ('公司名称', '安徽淮化股份有限公司'), ('净亏损', '4.28亿元'), ('财报周期', '去年'), ('披露时间', '7月24日')]
# [('破产公司', '安徽淮化股份有限公司'), ('披露时间', '7月24日')]
# 110172ed54efd82889602647552dd906
# [('招标方', '福建省龙岩市、三明市'), ('中标金额', '超千万元'), ('披露日期', '7月2日'), ('中标公司', '神州控股'), ('中标标的', '多个“新基建”项目')]
# [('中标标的', '福建'), ('中标金额', '729亿元'), ('披露日期', '7月2日'), ('中标公司', '神州控股'), ('中标日期', '7月2日'), ('招标方', '福建省数字办')]
# 42f9842f52aa76f2619ff45fa254dfb9
# [('回购完成时间', '2019年9月11日'), ('交易金额', '0.606万港币'), ('每股交易价格', '最低回购价60.4600港币'), ('回购完成时间', '本年度内至今为止'), ('占公司总股本比例', '0.56%'), ('回购方', '汇丰控股'), ('回购股份数量', '11540.4892万'), ('每股交易价格', '最高回购价60.6900港币'), ('每股交易价格', '60.6港币'), ('回购股份数量', '0.01万')]
# [('回购完成时间', '2019年9月11日'), ('交易金额', '0.606万港币'), ('每股交易价格', '最低回购价60.4600港币'), ('回购方', '汇丰控股'), ('每股交易价格', '最高回购价60.6900港币'), ('每股交易价格', '60.6港币'), ('回购股份数量', '0.01万')]
# ee2e515f1bd646584e4fb99a7d4ebf4a
# [('交易完成时间', '9月9日至12日'), ('股票简称', '万达信息'), ('交易金额', '约2.97亿元'), ('增持方', '中国人寿'), ('披露时间', '9月12日晚间'), ('交易股票/股份数量', '约2244.73万'), ('增持部分占总股本比例', '约为2.05%'), ('每股交易价格', '约13.24元')]
# [('交易完成时间', '9月9日至12日'), ('股票简称', '万达信息'), ('交易金额', '约2.97亿元'), ('增持方', '中国人寿'), ('披露时间', '9月12日晚间'), ('交易股票/股份数量', '约2244.73万'), ('增持部分占总股本比例', '约为2.05%'), ('每股交易价格', '约13.24元'), ('增持部分占总股本比例', '22.05%')]
# dccba1c3295b1ace98a0ab5e17b2b22a
# [('质押方', '西安聚华网络小额贷款有限公司'), ('事件时间', '截至本公告披露日'), ('质押物所属公司', '广誉远'), ('质押物占持股比', '93.30%'), ('质权方', '西安聚华网络小额贷款有限公司'), ('质押物', '股份'), ('质押股票/股份数量', '374万'), ('质押物占总股比', '13.82%'), ('质押股票/股份数量', '6798.4万'), ('质押物', '流通股'), ('质押物占总股比', '0.76%'), ('披露时间', '10月15日'), ('事件时间', '2019年10月15日'), ('质押方', '东盛集团')]
# [('质押物所属公司', '广誉远'), ('质押物占持股比', '93.30%'), ('质押物', '限售流通股'), ('质押物占总股比', '13.82'), ('质权方', '西安聚华网络小额贷款有限公司'), ('质押物', '股份'), ('质押股票/股份数量', '374万'), ('质押股票/股份数量', '6798.4万'), ('事件时间', '截至本公告披露日'), ('质押物占总股比', '0.76%'), ('披露时间', '10月15日'), ('事件时间', '2019年10月15日'), ('质押方', '东盛集团')]
# 4924a1575c9a34bf2ab94db22276645a
# [('中标金额', '86.85亿元人民币'), ('中标标的', '新高速公路项目'), ('中标公司', '四川成渝高速公路')]
# [('中标标的', '天府新区至邛崃高速公路项目'), ('中标公司', '中交建'), ('中标金额', '86.85亿元人民币'), ('中标公司', '四川成渝高速公路')]
# 5a86f6b6ce888f62b8311925ea655643
# [('投资方', '腾讯'), ('融资轮次', 'B'), ('投资方', '58同城'), ('被收购方', 'WHYLAB实验室'), ('融资轮次', 'A'), ('收购完成时间', '2019年'), ('融资金额', '2亿美元'), ('被投资方', '转转'), ('披露时间', '9月11日'), ('事件时间', '2017年4月'), ('收购方', '转转'), ('融资金额', '3亿美元')]
# [('投资方', '腾讯'), ('融资轮次', 'B'), ('投资方', '58同城'), ('融资轮次', 'A'), ('被投资方', '转转'), ('披露时间', '9月11日'), ('事件时间', '2017年4月'), ('被投资方', '8城'), ('融资金额', '3亿美元'), ('事件时间', '9月11日')]
# 925ff725d0c4b23387d011c37cdd377e
# [('上市公司', '百威亚太'), ('市值', '突破3800亿港元'), ('事件时间', '今日'), ('披露时间', '9月30日'), ('证券代码', '01876.HK'), ('环节', '正式上市')]
# []
# 76e991541d5ba919309b396785ea136e
# [('被收购方', 'Semma Therapeutics'), ('披露时间', '9月3日'), ('交易金额', '9.5亿美元'), ('收购方', 'Vertex Pharmaceuticals')]
# [('被收购方', 'Semma'), ('收购方', 'Vertex'), ('交易金额', '9.5亿美元'), ('披露时间', '9月3日'), ('收购方', 'Ve')]
# 2bab08331282ecfa146ca8bf86a5d9be
# [('净亏损', '2.4亿元-3.58亿元'), ('净亏损', '1.67亿元-2.84亿元'), ('财报周期', '第三季度'), ('公司名称', '隆平高科'), ('亏损变化', '收窄'), ('披露时间', '10月14日晚间'), ('财报周期', '2020年前三季度')]
# [('净亏损', '2.4亿元-3.58亿元'), ('净亏损', '1.67亿元-2.84亿元'), ('公司名称', '隆平高科'), ('亏损变化', '收窄'), ('披露时间', '10月14日晚间'), ('财报周期', '2020年前三季度')]
# 304b7dbafe4ac46f7d4d44f9c5949164
# [('被投资方', '宁波小灵狗出行科技有限公司'), ('融资轮次', 'A'), ('融资金额', '6.877亿元人民币'), ('投资方', '杭州普兆'), ('披露时间', '6月2日'), ('投资方', '鄞城集团')]
# [('被投资方', '宁波小灵狗出行科技有限公司'), ('融资轮次', 'A'), ('投资方', '杭州普兆'), ('融资金额', '6.877亿元'), ('披露时间', '6月2日'), ('投资方', '鄞城集团'), ('融资金额', '6')]
# 889dd7d47f1098d53e95efee5a3b8bcd
# [('减持部分占总股本比例', '9.90%'), ('交易完成时间', '5月26日至8月24日期间'), ('交易股票/股份数量', '440万'), ('减持方', '4名股东'), ('交易金额', '约7.51亿元'), ('减持方', '杰智控股有限公司'), ('股票简称', '中简科技'), ('减持部分占总股本比例', '9.00%'), ('股票简称', '富瀚微'), ('交易股票/股份数量', '3600.03万'), ('交易金额', '约11.12亿元'), ('交易完成时间', '5月27日至11月27日期间')]
# [('交易金额', '约0.92亿元'), ('交易完成时间', '5月26日至8月24日期间'), ('减持部分占总股本比例', '9.00%'), ('减持部分占总股本比例', '9.90%'), ('交易股票/股份数量', '3600.03万'), ('减持方', '宇信科技'), ('交易金额', '5.24亿元'), ('交易金额', '2.95亿'), ('股票简称', '众合科技'), ('减持方', '杭州海富恒歆股权投资合伙企业(有限合伙)'), ('交易股票/股份数量', '440万'), ('减持方', '杰智控股有限公司'), ('股票简称', '中简科技'), ('交易金额', '约11.12亿元'), ('减持方', '福建龙溪轴承(集团)股份有限公司'), ('股票简称', '兴'), ('股票简称', '富瀚'), ('减持方', '兴业证券'), ('交易完成时间', '5月27日至11月27日'), ('交易金额', '约7.51亿元'), ('减持方', '浙江浙大网新教育发展有限公司'), ('减持方', '重要股东')]
# cb88c571960fefd1fe83c777b18264ba
# [('收购标的', '基带芯片资产'), ('被收购方', '英特尔'), ('收购方', '苹果'), ('披露时间', '7月24'), ('交易金额', '超过10亿美元')]
# [('被收购方', '英特尔'), ('收购方', '苹果'), ('收购标的', '基'), ('披露时间', '7月24'), ('收购完成时间', '到下周'), ('交易金额', '超过10亿美元')]
# b902d981d8f171c50cee8de91ce65869
# [('上市公司', '永泰生物'), ('净亏损', '5000万'), ('财报周期', '半年'), ('环节', '筹备上市'), ('公司名称', '永泰生物')]
# [('环节', '筹备上市'), ('上市公司', '永泰生物')]
# c972f83aff4c5e50362c99ac30c259f5
# [('披露日期', '2020年5月15日'), ('中标标的', '朔州南山环境能源项目（生活垃圾焚烧发电项目和餐厨垃圾处理项目）特许经营项目'), ('中标金额', '不超过人民币 6.6亿元'), ('中标公司', '中国能源建设集团山西电力建设有限公司'), ('中标公司', '绿色动力环保集团股份有限公司'), ('中标日期', '2020年5月14日'), ('招标方', '山西省朔州市发展和改革委员会')]
# [('中标日期', '2020年5月14日'), ('招标方', '朔州市发展和改'), ('披露日期', '2020年5月1'), ('中标标的', '朔州南山环境能源项目（生活垃圾焚烧发电项目和餐厨垃圾处理项目）特许经营项目'), ('中标金额', '不超过人民币 6.6亿元'), ('中标公司', '绿色动力环保集团股份有限公司'), ('中标公司', '中国能源建设集团山西电力建设有限公司'), ('招标方', '山西省朔州市发展和改革委员会')]
# cb45d8347c85df7bb9b9dca553fdf5e3
# [('回购完成时间', '2020年5月13日'), ('交易金额', '2110.574万港币'), ('回购完成时间', '本年度内至今为止'), ('每股交易价格', '6.0028港币'), ('回购股份数量', '3568.2万'), ('回购方', '兖州煤业'), ('每股交易价格', '最高回购价6.0200港币'), ('回购股份数量', '351.6万'), ('占公司总股本比例', '1.828%'), ('每股交易价格', '最低回购价5.9500港币')]
# [('占公司总股本比例', '1'), ('回购完成时间', '2020年5月13日'), ('交易金额', '2110.574万港币'), ('每股交易价格', '6.0028港币'), ('回购方', '兖州煤业'), ('回购完成时间', '本'), ('每股交易价格', '最高回购价6.0200港币'), ('回购股份数量', '351.6万'), ('每股交易价格', '最低回购价5.9500港币')]
# a7048435b1a1b8f0b2a2df7310e2c0a8
# [('上市公司', '北京慧辰资道资讯股份有限公司'), ('环节', '筹备上市'), ('事件时间', '２０２０年４月３０日')]
# [('募资金额', '约为６３，５２３．２８万元'), ('事件时间', '２０２０年４月３０日'), ('环节', '筹备上市'), ('事件时间', '２０２０年７月７日'), ('上市公司', '北京慧辰资道资讯股份有限公司'), ('发行价格', '３４．２１元')]
# 553343fde39ccdf51e094cb0af76fac6
# [('中标公司', '广电运通'), ('中标金额', '1.27亿元'), ('披露日期', '午间'), ('招标方', '中国邮政储蓄银行'), ('中标标的', '超级柜员机(STM)集中采购项目')]
# [('中标公司', '广电运通'), ('中标金额', '1.27亿元'), ('中标公司', '赛隆药业'), ('披露日期', '午间'), ('招标方', '中国邮政储蓄银行'), ('中标标的', '超级柜员机(STM)集中采购项目'), ('中标日期', '近')]
# bb5f92c1295ec1d9cd42302990830c4f
# [('被收购方', '苏州科技大学天平学院'), ('收购方', '中国春来教育'), ('披露时间', '近日')]
# [('被收购方', '苏州科技大学平学院'), ('收购方', '春来教育'), ('收购方', '中国春来教育'), ('披露时间', '7月26日'), ('收购完成时间', '近日'), ('被收购方', '天平学院')]
# 9e75608bda619473c525cf95d968ae9b
# [('环节', '筹备上市'), ('事件时间', '10月29日'), ('上市公司', '国投电力'), ('披露时间', '10月29日晚间')]
# [('上市公司', 'G'), ('事件时间', '伦敦时间10月29日'), ('披露时间', '10月29日'), ('上市公司', '沪伦通'), ('环节', '筹备上市'), ('上市公司', '国投电力')]
# 21d90ab46ca347a7d23c9b313fce6821
# [('发行价格', '7.36元'), ('披露时间', '10月29日'), ('募资金额', '99.88亿元'), ('环节', '正式上市'), ('事件时间', '10月29日'), ('上市公司', '重庆农村商业银行')]
# [('发行价格', '7.36元'), ('事件时间', '2019年'), ('上市公司', '养元食品'), ('披露时间', '10月29日'), ('事件时间', '今日'), ('募资金额', '99.88亿元'), ('环节', '正式上市'), ('事件时间', '10月29日'), ('上市公司', '今创集团'), ('上市公司', '重庆农村商业银行')]
# c10417c2e7842598af525822e23d3bb6
# [('公司名称', '软银集团'), ('财报周期', '2019财年'), ('披露时间', '4月14日'), ('净亏损', '7500亿日元')]
# [('净亏损', '1.2265亿日元'), ('公司名称', '软银集团'), ('披露时间', '4月14日'), ('财报周期', '2019财年'), ('净亏损', '1.35万亿日元'), ('净亏损', '7500亿日元')]
# 05ac3cdb47f5feee80c4cd9f093dfe20
# [('中标标的', '集成电路项目'), ('中标公司', '太极实业子公司'), ('中标金额', '18亿元')]
# [('中标标的', '集成电路项目'), ('中标金额', '18亿元')]
# a9f36beab8a29e76bf203965387c3488
# ...
# [('变动类型', '退休'), ('变动后职位', '财务总监'), ('变动后职位', '集'), ('任职公司', '东亚银行'), ('披露日期', '6月23日'), ('变动类型', '委任'), ('事件时间', '2020年9月1日'), ('事件时间', '2020年9月1日起'), ('高管姓名', '马云'), ('变动后职位', '总经理兼策划及调控处主管'), ('高管姓名', '杜晓明')]
# 42c5425d56008d9e1492baf86f725d1d
# [('交易股票/股份数量', '不超过677万'), ('减持方', '神思科技投资'), ('减持部分占总股本比例', '4%'), ('股票简称', '神思电子'), ('交易完成时间', '减持之日起六个月内')]
# [('减持部分占总股本比例', '不超过公司总股本4%'), ('交易股票/股份数量', '不超过677万'), ('减持部分占总股本比例', '不超过4%'), ('减持方', '神思科技投资'), ('股票简称', '神思电子'), ('交易完成时间', '可减持之日起六个月内')]
# 3fcaee2ee42561f206d56234c36ed240
# [('被投资方', 'OnceSec Medical'), ('投资方', 'Sirtex Medical US Holdings'), ('融资金额', '3000万美元'), ('投资方', 'Grand Decade Developments Limited')]
# [('投资方', 'Sirtex Med'), ('投资方', 'Sirtex'), ('投资方', '远医药'), ('融资金额', '3000万美元'), ('投资方', 'Gr'), ('被投资方', 'OnceSec Medical'), ('领投方', '大')]
# 2860f2af57bcc2fd49793fd99cccd4f9
# [('回购方', 'IMAX CHINA'), ('回购完成时间', '2020年6月5日'), ('每股交易价格', '11.2555港币'), ('回购完成时间', '本年度内至今为止'), ('每股交易价格', '最低回购价11.1600港币'), ('每股交易价格', '最高回购价11.3000港币'), ('占公司总股本比例', '0.807%'), ('交易金额', '28.476494万港币'), ('回购股份数量', '287.32万'), ('回购股份数量', '2.53万')]
# [('回购方', 'IMAX CHINA'), ('回购完成时间', '2020年6月5日'), ('每股交易价格', '11.2555港币'), ('每股交易价格', '最低回购价11.1600港币'), ('每股交易价格', '最高回购价11.3000港币'), ('交易金额', '28.476494万港币'), ('回购股份数量', '2.53万')]
# 329a9645d9bcf7f8a4bff79d40b864ba
# [('公司名称', 'ST威龙'), ('净亏损', '1.38亿元'), ('财报周期', '2020年半年度'), ('披露时间', '8月27日')]
# [('净亏损', '9128.45万元'), ('净亏损', '1.38亿元'), ('公司名称', 'ST威龙'), ('财报周期', '2020年半年度'), ('披露时间', '今日下午'), ('亏损变化', '同比减少54.12%'), ('披露时间', '8月27日')]
# 22b8bf75f98e2b4c3b9f4c5d6b1aa3fa
# [('中标公司', '重庆设计院'), ('招标方', '重庆祥泰燃气有限公司'), ('中标标的', '“南川-两江新区天然气管道工程”、“东胜-大有天然气管道工程”项目'), ('中标日期', '近日')]
# [('招标方', '重庆祥泰燃气有限公司'), ('中标日期', '近日'), ('中标标的', '南川-两江新区天然气管道工程'), ('中标公司', '重庆设计院'), ('中标标的', '东胜-大有天然气管道工程')]
# 788062e5606b832ad8344a1aa8d6c7b3
# [('财报周期', '截至2019年7月31日止财政年度'), ('公司名称', '全民国际'), ('亏损变化', '减少')]
# [('亏损变化', '减少'), ('公司名称', '全民国际'), ('财报周期', '截至2019年7月31日止财政年度'), ('亏损变化', '大幅少'), ('财报周期', '2')]
# 3c7229b90ebd8e225fe7e9b768bc0ca8
# [('质权方', '国元证券及浙商证券'), ('质押物占总股比', '16.53%'), ('质押方', '上峰控股'), ('质押物所属公司', '上峰水泥'), ('质押物', '股份'), ('质押物占持股比', '8.61%'), ('披露时间', '7月31日'), ('质押股票/股份数量', '2262.5万'), ('质押股票/股份数量', '1.3450亿'), ('质押物占持股比', '51.23%'), ('事件时间', '截止公告披露日')]
# [('质押方', '上峰控股'), ('质押物所属公司', '上峰水泥'), ('质权方', '国元证券'), ('质押物', '股份'), ('质押物占总股比', '16.5'), ('质押物占持股比', '8.61%'), ('事件时间', '近日'), ('披露时间', '7月31日'), ('质权方', '浙商证券'), ('质押股票/股份数量', '2262.5万'), ('质押股票/股份数量', '1.3450亿'), ('质押物占持股比', '51.23%'), ('事件时间', '截止公告披露日')]
# 888ef0bb42f405734bf4ce1020e71c57
# [('增持方', '中原证券总裁'), ('披露时间', '7月13日'), ('交易完成时间', '今年5月份'), ('股票简称', '中州证券'), ('交易股票/股份数量', '100万'), ('交易完成时间', '7月13日'), ('增持方', '河南投资集团'), ('交易股票/股份数量', '315.3万')]
# [('交易股票/股份数量', '9785.8万'), ('披露时间', '7月13日'), ('增持部分占总股本比例', '8.19%'), ('交易完成时间', '今年5月份'), ('股票简称', '中原证券'), ('增持方', '总裁'), ('交易股票/股份数量', '100万'), ('增持方', '河南投资集团'), ('交易股票/股份数量', '315.3万')]
# 0030e0e30b5e996b421bf56dd198783f
# [('股票简称', '蓝黛传动'), ('交易金额', '4313.40万元'), ('增持方', '高管'), ('交易金额', '3004.21万元'), ('交易股票/股份数量', '1591.42万'), ('股票简称', '联络互动'), ('股票简称', '梦洁股份'), ('交易金额', '5569.97万元'), ('交易完成时间', '7月10日~7月23日'), ('交易股票/股份数量', '780.00万')]
# [('股票简称', '蓝黛传动'), ('交易金额', '4313.40万元'), ('增持方', '高管'), ('交易金额', '3004.21万元'), ('股票简称', '高斯贝尔'), ('股票简称', '美吉姆'), ('交易股票/股份数量', '1591.42万'), ('交易完成时间', '近10'), ('股票简称', '联络互动'), ('股票简称', '梦洁股份'), ('股票简称', '爱施德'), ('交易金额', '5569.97万元'), ('股票简称', '华东'), ('交易完成时间', '7月10日~7月23日'), ('股票简称', '金卡智能'), ('交易股票/股份数量', '780.00万'), ('交易完成时间', '近10日')]
# 7501f24ef19c0c7faea6220e8e44d94c
# [('净亏损', '5950万元'), ('公司名称', '51talk'), ('净亏损', '2670万'), ('披露时间', '日前'), ('亏损变化', '同比下降60.2%'), ('财报周期', '第二季度'), ('财报周期', '2019年第一季度')]
# [('净亏损', '2670万元'), ('公司名称', '51talk'), ('披露时间', '日前'), ('亏损变化', '同比下降60.2%'), ('财报周期', '第二季度'), ('财报周期', '2019年第一季度')]
# 592ccbe2dfd698ee2ebba9097d7bdc09
# [('披露时间', '7月6日晚间'), ('破产公司', '誉衡集团')]
# [('披露时间', '7月15日'), ('破产公司', '誉衡集团'), ('债务规模', '约为6.87亿元'), ('破产公司', '誉衡药业'), ('披露时间', '7月6日晚间')]
# 5b6a38726686003851bceb4d9ad337a7
# [('披露时间', '周五'), ('财报周期', '2020财年第三财季'), ('净亏损', '10.8亿美元'), ('公司名称', '埃克森美孚')]
# [('公司名称', '埃克森美孚'), ('财报周期', '2020财年第三财季'), ('披露时间', '周五前'), ('披露时间', '盘前'), ('净亏损', '10.8亿美元')]
# ced5a4bcf1c77eed6a01061572830531
# [('质押股票/股份数量', '8.18亿'), ('质押股票/股份数量', '4.5913亿'), ('质押物占持股比', '63.78%'), ('质押物', '股份'), ('事件时间', '截至公告披露日'), ('披露时间', '8月12日'), ('事件时间', '近日'), ('质押物所属公司', '协鑫集成'), ('质押物占总股比', '16.10%'), ('质押方', '营口其印投资管理有限公司')]
# [('质押股票/股份数量', '8.18亿'), ('质押物占持股比', '63.78%'), ('质押股票/股份数量', '4.5913亿'), ('质押物', '股份'), ('事件时间', '截至公告披露日'), ('质押方', '上海其印投资管理有限公司'), ('披露时间', '8月12日'), ('事件时间', '近日'), ('质押物所属公司', '协鑫集成'), ('质押方', '营口其印投资管理有限公司'), ('质押物占总股比', '16.10')]
# 4e42f9375b757fc82935a46228b9a6a2
# [('事件时间', '自2020年6月26日起'), ('高管职位', '公司非执行董事'), ('高管姓名', 'Richard Raymond Weissend'), ('披露日期', '6 月 26日'), ('变动类型', '辞任'), ('变动后职位', '公司非执行董事'), ('变动类型', '委任'), ('高管姓名', 'Rudolf Gijsbert Servaas van den Brink'), ('任职公司', '华润啤酒')]
# [('事件时间', '自2020年6月26日起'), ('高管姓名', 'Richard Raymond Weissend'), ('高管职位', '非执行董事'), ('披露日期', '6 月 26日'), ('变动类型', '辞任'), ('变动后职位', '非执行董事'), ('变动类型', '委任'), ('高管姓名', 'Rudolf Gijsbert Serva'), ('高管姓名', 'Rudolf Gijsbert Servaas van den Brink'), ('任职公司', '华润啤酒')]
# 62cc1b632c0c4c249a0343b79ae35a00
# [('回购完成时间', '本年内至今为止'), ('占公司总股本比例', '0.188%'), ('每股交易价格', '3.13港元至3.15港元'), ('交易金额', '56.59万元'), ('回购完成时间', '2020年08月27日'), ('回购股份数量', '373.7万'), ('回购股份数量', '18万'), ('回购方', '新鸿基公司')]
# [('每股交易价格', '3.13港元至3.15港元'), ('交易金额', '56.59万元'), ('回购完成时间', '2020年08月27日'), ('回购股份数量', '18万'), ('回购方', '新鸿基公司')]
# 64812f73b75c10a87a9c08cd990075bf
# [('事件时间', '8月7日'), ('质押股票/股份数量', '46,885,800'), ('披露时间', '8月7日'), ('质押物占总股比', '5.53%'), ('质押物', '股份'), ('质押物占持股比', '50.11%'), ('质押物所属公司', '水晶光电'), ('质押股票/股份数量', '62,017,020'), ('质押方', '星星集团'), ('事件时间', '截至本公告披露日')]
# [('质押股票/股份数量', '46,885,800'), ('披露时间', '8月7日'), ('质押物占总股比', '5.53%'), ('质押物', '股份'), ('质押物占持股比', '50.11%'), ('质押物所属公司', '水晶光电'), ('质押股票/股份数量', '62,017,020'), ('质押方', '星星集团'), ('事件时间', '截至本公告披露日')]
# 758facdb614483d69a9b436ecf836cb9
# [('交易股票/股份数量', '31.5万'), ('股票简称', '中芯国际'), ('披露时间', '5月19日'), ('减持方', '陈山枝'), ('交易金额', '575万港元'), ('交易完成时间', '5月19日'), ('每股交易价格', '18.3港元')]
# [('交易金额', '约375万港'), ('交易股票/股份数量', '31.5万'), ('股票简称', '中芯国际'), ('减持方', '陈山枝'), ('交易金额', '575万港元'), ('交易完成时间', '5月19日'), ('每股交易价格', '6.4港元'), ('每股交易价格', '18.3港元')]
# 4550ecce93a5825529dc99f09cab9ad8
# [('披露时间', '今天上午'), ('公司名称', '中行某市分行'), ('约谈机构', '银保监局')]
# [('被约谈时间', '今天上午'), ('公司名称', '中行某市分行')]
# 57f7010f6177bea90e94b14be1c988f0
# [('减持部分占总股本比例', '5%'), ('减持方', '施雄飚'), ('交易股票/股份数量', '不超过4891.57万'), ('减持部分占总股本比例', '0.0786%'), ('减持部分占总股本比例', '0.0419%'), ('减持方', '薛长煌'), ('减持方', '王启辉'), ('减持方', '夏璠林'), ('交易股票/股份数量', '不超76.87'), ('减持方', '施延军'), ('交易股票/股份数量', '不超过 41.00万'), ('披露时间', '10月22日晚间'), ('股票简称', '金字火腿')]
# [('减持部分占总股本比例', '5%'), ('减持方', '施雄飚'), ('交易股票/股份数量', '不超过4891.57万'), ('减持部分占总股本比例', '5.12%'), ('减持部分占总股本比例', '0.0786%'), ('减持部分占总股本比例', '0.0419%'), ('减持方', '薛长煌'), ('减持方', '夏璠林'), ('减持方', '王启辉'), ('减持方', '实控人高管'), ('披露时间', '10月22日晚间'), ('交易股票/股份数量', '不超76.87'), ('交易股票/股份数量', '不超过 41.00万'), ('减持方', '施延军'), ('减持方', '重要股东'), ('股票简称', '金字火腿')]
# 62d4c9cb539dab354faf591b6fe96952
# [('破产公司', '太阳马戏娱乐集团'), ('披露时间', '3月19日')]
# [('债务规模', '9亿')]
# 5ef130d81fcde399d9d123e4c675fb12
# [('交易金额', '168.63万元'), ('增持方', '非独立董事'), ('增持方', '高管'), ('披露时间', '近日'), ('股票简称', '成都银行'), ('交易股票/股份数量', '20.07万'), ('交易完成时间', '截止今日')]
# [('增持方', '高管'), ('增持方', '董事'), ('增持方', '高高管'), ('交易金额', '168万'), ('披露时间', '近日'), ('交易金额', '不低于133.43万元'), ('股票简称', '成都银行'), ('交易股票/股份数量', '20.07万'), ('交易金额', '311亿元'), ('增持方', '董董事')]
# 3e32eaea5d999df221dd13d217c2bc24
# [('环节', '筹备上市'), ('上市公司', '无锡奥特维科技股份有限公司')]
# [('环节', '筹备上市'), ('披露时间', '今日'), ('上市公司', '无锡奥特维科技股份有限公司')]
# e6160a3c31f3f4b4c879ff0bc32bd025
# [('变动类型', '接任'), ('高管姓名', '郑建强'), ('变动类型', '卸任'), ('披露日期', '7月24日'), ('高管职位', '监事'), ('高管姓名', '龚玥婷'), ('任职公司', '北京沃芽科技有限公司')]
# [('高管职位', '法定代表人'), ('变动后职位', '监'), ('变动类型', '接任'), ('高管姓名', '郑建强'), ('变动后公司名称', '芽'), ('事件时间', '7月24日'), ('高管职位', '监事'), ('高管姓名', '龚玥婷'), ('变动类型', '卸任'), ('高管职位', '执行董事'), ('任职公司', '北京沃芽科技有限公司')]
# a0e9cf0b693b1404c47acda576478d83
# [('交易金额', '48亿元人民币'), ('收购方', '苏宁国际'), ('收购标的', '80%股份'), ('披露时间', '两个月前'), ('被收购方', '家乐福中国')]
# [('收购方', '苏宁易购集团股份有限公司'), ('交易金额', '48亿元人民币'), ('被收购方', '家乐福'), ('收购方', '苏宁国际'), ('收购方', '苏宁易购'), ('披露时间', '8月26日晚'), ('收购标的', '80%股份'), ('收购完成时间', '两个月前'), ('披露时间', '9月16日下午'), ('被收购方', '家'), ('被收购方', '荷兰家乐福中国控股公司')]
# edf13710930c19423b55aae4ade94726
# [('回购完成时间', '自股东大会审议通过回购股份方案之日起不超过12个月'), ('每股交易价格', '不超过人民币13.50元'), ('回购方', '安徽 国祯环保节能科技股份有限公司'), ('交易金额', '不低于人民币15,000万元'), ('披露时间', '2020年7月16日'), ('交易金额', '不超过人民币30,000万元')]
# [('每股交易价格', '不超过人民币13.50元'), ('回购方', '安徽 国祯环保节能科技股份有限公司'), ('回购完成时间', '自股东大会审议通过回购股份方案之日起不超过12个'), ('交易金额', '不低于人民币15,000万元'), ('交易金额', '不超过人民币30,000万元')]
# 17618ee5a8093a0d3faa3745a1711db2
# [('回购完成时间', '2020年5月8日'), ('披露时间', '5月8日'), ('每股交易价格', '5.80-5.93港元'), ('回购股份数量', '550万'), ('交易金额', '3234.54万港元')]
# [('回购完成时间', '2020年5月8日'), ('披露时间', '5月8日'), ('回购股份数量', '550万'), ('每股交易价格', '5.80-5.93港元'), ('回购方', '兖州煤业股份'), ('交易金额', '3234.54万港元')]
# 5eb169e8a7709e83a3844aab9e5bd618
# [('质押物占持股比', '7.91%'), ('质押物', '股份'), ('披露时间', '5月13日晚间'), ('质押股票/股份数量', '约为366万'), ('质权方', '华泰联合证券有限责任公司'), ('质押方', '深圳市宝德投资控股有限公司'), ('质押物所属公司', '中青宝')]
# [('事件时间', '2020年4月21日至2020年5月6日'), ('质押物占持股比', '7.91%'), ('披露时间', '5月13日晚间'), ('质押物', '股份'), ('质押股票/股份数量', '约为366万'), ('质权方', '华泰联合证券有限责任公司'), ('质押方', '深圳市宝德投资控股有限公司'), ('质押物所属公司', '中青宝')]
# 6cb030f29839a21abb1a5afced823d7f
# [('交易金额', '506.28万港元'), ('回购完成时间', '2020年9月18日'), ('回购方', '雷蛇'), ('回购股份数量', '294.9万'), ('每股交易价格', '1.71-1.72港元'), ('披露时间', '2020年9月18日')]
# [('每股交易价格', '1.71-1.72港'), ('交易金额', '506.28万港元'), ('回购完成时间', '2020年9月18日'), ('回购方', '雷蛇'), ('回购股份数量', '294.9万')]
# a1b8886107b089c27d5312bf77f73f95
# [('被收购方', '夏尔'), ('收购方', '百时美施贵宝'), ('交易金额', '740亿美元'), ('披露时间', '2019年1月'), ('交易金额', '620亿美元'), ('收购方', '武田'), ('收购完成时间', '2019年1月'), ('被收购方', '新基公司'), ('收购完成时间', '2019年11月')]
# [('被收购方', '夏尔'), ('交易金额', '620亿美元'), ('收购方', '武田'), ('收购完成时间', '2019年'), ('收购完成时间', '2019年1月'), ('被收购方', '百时美施贵宝')]
# da952dae7579b776d6d492dd370f4bf0
# [('股票简称', '圣邦股份'), ('交易股票/股份数量', '不超过470.33万'), ('减持方', '世纪维盛'), ('减持部分占总股本比例', '3.03%'), ('交易完成时间', '本减持计划公告之日起15个交易日后的6个月内')]
# [('减持方', '世纪维盛'), ('股票简称', '圣邦股份'), ('交易股票/股份数量', '不超过470.33万'), ('交易完成时间', '本减持计划公告之日起15个交易日后的6个月')]
# f1cb7078b587eb7d3a66108e304abd36
# [('中标金额', '10.14亿元'), ('中标日期', '近日'), ('中标公司', '上海市浦东新区建设（集团）有限公司')]
# [('中标日期', '近日'), ('中标标的', '重大工程项目'), ('中标金额', '10.14亿元'), ('中标日期', '近期'), ('中标公司', '上海市浦东新区建设（集团）有限公司')]
# 94e281cf1486f22d3c97c9d74c8060c8
# [('中标标的', '生活垃圾焚烧发电项目'), ('招标方', '辉县市'), ('中标公司', '城发环境'), ('披露日期', '7月25日晚间'), ('中标金额', '约4.22亿元')]
# [('中标标的', '辉县市生活垃圾焚烧发电项目'), ('中标公司', '城发环境'), ('披露日期', '7月25日晚间'), ('中标金额', '约4.22亿元')]
# 5d2a4299fcabb0627b8a8a1cd445f19d
# [('质押方', '叶利明'), ('质押方', '盛洋电器'), ('披露时间', '6月22日'), ('披露时间', '2020年6月22日'), ('质押物', '股'), ('质押股票/股份数量', '3000万'), ('质押股票/股份数量', '1500万'), ('质押物所属公司', '盛洋科技')]
# [('质押方', '叶利明'), ('质押股票/股份数量', '3000万'), ('披露时间', '6月22日'), ('事件时间', '2020年6月22日'), ('质押股票/股份数量', '1500万'), ('质押物所属公司', '盛洋科技')]
# 2ac1dee1fa24794c8f42c49d41157629
# [('披露时间', '9月9日'), ('减持部分占总股本比例', '4%'), ('交易完成时间', '任意连续90日内'), ('交易股票/股份数量', '不超过19，964，600'), ('交易完成时间', '2019年9月16日-2020年3月13日'), ('交易股票/股份数量', '不超过39，929，201'), ('减持部分占总股本比例', '2%'), ('股票简称', '依顿电子'), ('减持方', '依顿投资有限公司')]
# [('股票简称', '依顿电子'), ('减持部分占总股本比例', '不超过公司股份总数4%'), ('交易完成时间', '自本减持计划公告之日起三个交易日后六个月内'), ('交易完成时间', '2019年9月16日-2020年3月13日'), ('交易股票/股份数量', '不超过39，929，201'), ('披露时间', '9月9日'), ('减持方', '依顿投资有限公司')]
# cf393c2b24f7b4b7466ba80733d81ee3
# [('披露日期', '8月23日'), ('中标公司', '光大国际'), ('中标日期', '8月23日'), ('中标金额', '73934.74万元'), ('中标标的', '甘肃凉州区静脉产业园PPP项目')]
# [('中标标的', '甘肃'), ('披露日期', '8月23日'), ('招标方', '甘肃武威市凉州区')]
# 7d12b262f8ab51e9c05c9a1b3b211785
# [('披露时间', '6月11日'), ('被投资方', '上海陆家嘴金融贸易区开发股份有限公司'), ('事件时间', '6月8日至9日'), ('融资金额', '人民币15亿元')]
# []
# fc24b4af852814f503d323a07fb32d04
# [('破产时间', '2020年9月23日'), ('披露时间', '11月16日'), ('债权人', 'PT . Pandega Desain Weharima'), ('破产公司', 'PT . Tritama Barata Makmur'), ('债权人', 'CV . Media Konsultindo'), ('债务规模', '约37.87亿印尼盾')]
# [('破产时间', '2020年9月23日'), ('披露时间', '11月16日'), ('破产公司', 'T'), ('破产公司', 'PT . Tritama Barata Makmur'), ('债务规模', '约37.87亿印尼盾')]
# 991ac911efd143f4ea51b336be43b48e
# [('减持方', '傅梅城'), ('交易股票/股份数量', '不超过140,453,896'), ('股票简称', '华策影视'), ('减持部分占总股本比例', '不超过公司现有总股本的8%'), ('交易完成时间', '本减持计划公告之日起3个交易日后的6个月内'), ('减持方', '傅斌星'), ('减持方', '杭州大策投资有限公司'), ('披露时间', '11月8日')]
# [('减持方', '傅梅城'), ('交易股票/股份数量', '不超过140,453,896'), ('减持部分占总股本比例', '5%'), ('股票简称', '华策影视'), ('交易完成时间', '自本减持计划公告之日起3个交易日后的6个月内'), ('减持部分占总股本比例', '不超过公司现有总股本的8%'), ('减持方', '傅斌星'), ('减持方', '大策投资'), ('减持方', '杭州大策投资有限公司'), ('披露时间', '11月8日')]
# ed766762a97387eca946efd11faad973
# [('上市公司', '农夫山泉'), ('证券代码', 'HK:9633'), ('环节', '正式上市'), ('募资金额', '约为82亿港元'), ('市值', '接近4000亿港元')]
# [('环节', '正式上市')]
# 929b5db5f74cd5a7dc5406430113b144
# [('回购完成时间', '2019年8月7日'), ('回购方', '渣打集团'), ('回购股份数量', '145万'), ('交易金额', '913.17万英镑'), ('每股交易价格', '6.204-6.388英镑')]
# [('回购完成时间', '2019年8月7日'), ('回购方', '渣打集团'), ('回购完成时间', '8月5日'), ('回购股份数量', '145万'), ('交易金额', '913.17万英镑'), ('每股交易价格', '6.204-6.388英镑')]
# a1c37c9fc04e3ce2c67a090f1ec185ce
# [('披露时间', '10月18日'), ('净亏损', '净利润约-2.4亿元'), ('财报周期', '2019年前三季度'), ('公司名称', '*ST华源')]
# [('披露时间', '10月18日'), ('公司名称', '*ST华源'), ('财报周期', '2019年前三季度'), ('净亏损', '约2.1亿元'), ('净亏损', '约-2.4亿元')]
# cc412c149c1b3151494a81d3f974fe26
# [('任职公司', '国安国际'), ('披露日期', '10月31日'), ('变动类型', '委任'), ('事件时间', '自2019年11月1日起'), ('高管姓名', '王淑贞'), ('变动后职位', '公司秘书')]
# [('任职公司', '国安国际'), ('披露日期', '10月31日'), ('变动类型', '委任'), ('变动后职位', '公'), ('事件时间', '自2019年11月1日起'), ('高管姓名', '王淑贞'), ('变动后职位', '秘书')]
# 31ea06d39027d7f3b589f95d5d86cf78
# [('高管姓名', '张胜'), ('变动后公司名称', '中国国航'), ('变动后职位', '副总裁'), ('变动类型', '聘任')]
# [('变动后职位', '副总裁'), ('变动类型', '聘任'), ('任职公司', '中国国航'), ('变动后职位', '公司总裁'), ('高管姓名', '张胜')]
# 8816e4cf02ed4c07816bee91e381fa32
# [('破产公司', '成都美美力诚百货有限公司'), ('破产时间', '2020年8月6号'), ('披露时间', '8月29日')]
# [('破产时间', '2020年8月6号'), ('破产时间', '9月9日'), ('破产公司', '成都美美力诚百货有限公司'), ('披露时间', '8日'), ('破产公司', '力诚国际贸易股份有限公司'), ('破产时间', '8月29日')]
# 4b85c8ea1820c6b4b0628930d36f45cb
# [('占公司总股本比例', '0.58%'), ('每股交易价格', '最低价格为62.18元'), ('披露时间', '2020年8月7日'), ('每股交易价格', '最高价格为116.37元'), ('回购股份数量', '1,523,685'), ('披露时间', '2020年2月7日'), ('回购完成时间', '2020年8月5日'), ('每股交易价格', '101.81元'), ('交易金额', '不低于人民币15,000万元'), ('每股交易价格', '不超过人民币90元'), ('交易金额', '人民币15,046.23万元'), ('回购完成时间', '2020年2月6日至2020年8月5日'), ('回购方', '三棵树涂料股份有限公司'), ('交易金额', '不超过人民币30,000万元')]
# [('占公司总股本比例', '0.58%'), ('每股交易价格', '最低价格为62.18元'), ('每股交易价格', '最高价格为116.37元'), ('回购股份数量', '1,523,685'), ('披露时间', '2020年8月'), ('交易金额', '人民币15,046.23万元'), ('交易金额', '不低于人民币15,000万元'), ('每股交易价格', '不超过人民币90元'), ('每股交易价格', '101.81元'), ('回购方', '三棵树涂料股份有限公司'), ('交易金额', '不超过人民币30,000万元')]
# 3875f7e37d915a4e6f765076eec77d2c
# [('减持部分占总股本比例', '不超公司总股本的2%'), ('股票简称', '弘亚数控'), ('交易股票/股份数量', '432万'), ('披露时间', '前一天'), ('减持方', '李茂洪')]
# [('交易股票/股份数量', '432万'), ('股票简称', '弘亚数控'), ('减持部分占总股本比例', '不超公司总股本的2%'), ('减持方', '李茂洪')]
# f7234e3c850238317266871b9a80ce46
# [('减持方', '孙伯荣'), ('披露时间', '6月9日晚间'), ('股票简称', '天泽信息'), ('交易完成时间', '15个交易日后的6个月内'), ('减持部分占总股本比例', '不超过5.91%'), ('交易股票/股份数量', '不超过2518.04万')]
# [('减持方', '孙伯荣'), ('减持方', '中住集团'), ('披露时间', '6月9日晚间'), ('股票简称', '天泽信息'), ('减持部分占总股本比例', '不超过6%'), ('交易完成时间', '15个交易日后的6个月内'), ('减持部分占总股本比例', '不超过5.91%'), ('交易股票/股份数量', '不超过2518.04万'), ('股票简称', '捷捷微')]
# fd32290984416e3f4697b5e647beaacd
# [('披露时间', '2020年6月23日'), ('回购完成时间', '2020年6月22日'), ('回购股份数量', '332,037'), ('回购方', '浩云科技股份有限公司')]
# [('回购股份数量', '332,037'), ('回购方', '浩云科技股份有限公司'), ('披露时间', '2020年7月1')]
# c151f85ef79ca6f4a270badc6ce7c146
# [('中标标的', '费用智能审核与RPA财务标准化流程系统采购项目'), ('披露日期', '7月10日'), ('中标公司', '北京令才科技有限公司'), ('中标日期', '日前'), ('招标方', '中原农业保险股份有限公司')]
# [('中标公司', '北'), ('中标标的', '费费用智能审核与RPA财务标准化流程系统采购项目'), ('披露日期', '7月10日'), ('中标日期', '日前'), ('中标标的', '“费用智能审核与RPA财务标准化流程系统采购项目'), ('招标方', '中原农业保险股份有限公司'), ('中标公司', '令')]

# %%
count
# Out:
# 630

# %%
for d_json in sentences_tigger_data:
    if d_json['id'] == '059e1e8ade11b1de9ab81a728eab2c81':
        r_ret = extract_result_multilabel(d_json["text"], d_json["pred"]["labels"])
        probs_ids = (np.array(d_json["pred"]["probs"]) > 0.1)
        label_multi = []
        for index, pid in enumerate(probs_ids[1:]):
            true_indices = np.argwhere(pid).flatten()
            label_multi.append([id2triggerlabel[true_index] for true_index in true_indices])
        print(label_multi)
#         print(d_json["pred"]["labels"])
        print(extract_result_multilabel(d_json["text"], label_multi))
        print(r_ret)
# Out:
# [['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['B-企业收购'], ['I-企业收购'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O']]
# [{'start': 25, 'text': ['收', '购'], 'type': '企业收购'}]
# [{'start': 25, 'text': ['收', '购'], 'type': '企业收购'}]

# %%
for d_json in sentences_role_data:
    if d_json['id'] == 'be11a1377c0d97bd5f5da146990597fa':
        r_ret = extract_result_multilabel(d_json["text"], d_json["pred"]["labels"])
        print(d_json["text"])
#         print(d_json["pred"]["labels"][d_json["text"].find("8-10美元"):d_json["text"].find("8-10美元")+1])
#         print(d_json["pred"]["probs"][d_json["text"].find("8-10美元")+1:d_json["text"].find("8-10美元")+2][0])
#         probs_ids = (np.array(d_json["pred"]["probs"]) > 0.1)
#         label_multi = []
#         for index, pid in enumerate(probs_ids[1:]):
#             true_indices = np.argwhere(pid).flatten()
#             label_multi.append([id2rolelabel[true_index] for true_index in true_indices])
# #         print(label_multi)
# #         print(d_json["pred"]["labels"])
#         print(extract_result_multilabel(d_json["text"], label_multi))
        print(r_ret)
# Out:
# 公司上市(上市)：安泰科技间接参股公司天宜上佳22日科创板上市原标题：安泰科技(7.880,0.05,0.64%)间接参股公司天宜上佳22日科创板上市
#  来源：中国证券网 上证报中国证券网讯(记者 孔子元)安泰科技公告，近日，公司持股18.61%的启赋安泰基金所投资的标的企业天宜上佳拟于7月22日在上交所科创板挂牌上市。启赋安泰基金于2018年6月完成对天宜上佳的股权投资，持股1.96%。本次发行结束后，启赋安泰基金持有天宜上佳股份数量为786万股，持股比例1.75%。
# [{'start': 19, 'text': ['天', '宜', '上', '佳'], 'type': '上市公司'}, {'start': 110, 'text': ['近', '日'], 'type': '披露时间'}, {'start': 144, 'text': ['7', '月', '2', '2', '日'], 'type': '事件时间'}]
# 企业融资(投资)：安泰科技间接参股公司天宜上佳22日科创板上市原标题：安泰科技(7.880,0.05,0.64%)间接参股公司天宜上佳22日科创板上市
#  来源：中国证券网 上证报中国证券网讯(记者 孔子元)安泰科技公告，近日，公司持股18.61%的启赋安泰基金所投资的标的企业天宜上佳拟于7月22日在上交所科创板挂牌上市。启赋安泰基金于2018年6月完成对天宜上佳的股权投资，持股1.96%。本次发行结束后，启赋安泰基金持有天宜上佳股份数量为786万股，持股比例1.75%。
# [{'start': 19, 'text': ['天', '宜', '上', '佳'], 'type': '被投资方'}, {'start': 124, 'text': ['启', '赋', '安', '泰', '基', '金'], 'type': '投资方'}, {'start': 168, 'text': ['2', '0', '1', '8', '年', '6', '月'], 'type': '事件时间'}]

# %%
def evaluate_mergedata(predict_doc, true_merge_dataset_path):
    true_data_list = []
    with open(true_merge_dataset_path, 'r', encoding='utf-8') as f:
        for line in f:
            json_data = json.loads(line)
            true_data_list.append(json_data)
    predict_mapping_dict = {}
    for doc in predict_doc:
        predict_mapping_dict[doc['id']] = doc
    count_predict = 0
    count_true = 0
    count_correct = 0
    for true_data in true_data_list:
        if true_data['id'] not in predict_mapping_dict:
            if 'event_list' in true_data:
                print('error: ', true_data)
        else:
            predict_doc = predict_mapping_dict[true_data['id']]
            pred_data_set = set([(pred_event['event_type'], argument['role'], argument['argument']) for pred_event in predict_doc.get('event_list', []) for argument in pred_event.get('arguments')])
            true_data_set = set([(true_event['event_type'], argument['role'], argument['argument']) for true_event in true_data.get('event_list', []) for argument in true_event.get('arguments')])
            count_predict += len(list(pred_data_set))
            count_true += len(list(true_data_set))
            count_correct += len(list(pred_data_set & true_data_set))
    p = count_correct / max(1, count_predict)  # precision
    r = count_correct / max(1, count_true)  # recall
    f1 = 2 * r * p / max(1e-9, r + p) # f1 score
    s = count_true  # support

    print("{:>10}{:>10}{:>10}{:>10}\n".format("precision", "recall", "f1-score", "support"))
    formatter = "{:>10.3f}{:>10.3f}{:>10.3f}{:>10d}".format
    print(formatter(p, r, f1, s))
    print("")

# %%
evaluate_mergedata(doc_pred, duee_fin_dev_path)
# Out:
#  precision    recall  f1-score   support
#
#      0.737     0.778     0.757      7061
