# %%
import copy
import json
import random

import torch
import torch.nn as nn
import numpy as np
from torch.utils.data import Dataset
import torch.nn.functional as F
from torch.optim import Adam

from collections import Counter

from torch.optim.lr_scheduler import ReduceLROnPlateau
from torch.utils.data import DataLoader, Dataset, RandomSampler, SequentialSampler
from tqdm import tqdm_notebook as tqdm

from transformers import AutoTokenizer, AutoConfig, AutoModel

from crf_layer import CRFLayer
from multiLabelTokenClassfication import MultiLabelTokenClassification
from multiLabelSequenceClassfication import MultiLabelSequenceClassification

from utils import read_by_lines, extract_result_multilabel

# %%
device_Id = "1"
folder_name = "ernie-base"
tokenizer_model = "nghuyong/ernie-1.0"

shema_path = './dictionary/event_schema.json'
enerm_dict_path = './dictionary/enum_tag.dict'
trigger_dict_path = './dictionary/trigger_tag.dict'
role_dict_path = './dictionary/role_tag.dict'

enerm_model_path = f'./models/DuEE_fin/{folder_name}/enum.bin'
tigger_model_path = f'./models/DuEE_fin/{folder_name}/trigger-multilabel.bin'
role_model_path = f'./models/DuEE_fin/{folder_name}/role-multilabel-trick1.bin'

duee_fin_dev_path = './resources/duee_fin_dev.json'
duee_fin_dev_preprocess_path = './resources/duee_fin_dev_preprocess.json'

enum_role = "环节"
enum_event_type = "公司上市"
max_seq_len = 512

# %%
def load_dict(dict_path):
    """load_dict"""
    vocab = {}
    for line in open(dict_path, 'r', encoding='utf-8'):
        value, key = line.strip('\n').split('\t')
        vocab[key] = int(value)
    return vocab

# %%
label_enum_vocab = load_dict(dict_path=enerm_dict_path)
id2enumlabel = {val: key for key, val in label_enum_vocab.items()}
label_trigger_vocab = load_dict(dict_path=trigger_dict_path)
id2triggerlabel = {val: key for key, val in label_trigger_vocab.items()}
label_role_vocab = load_dict(dict_path=role_dict_path)
id2rolelabel = {val: key for key, val in label_role_vocab.items()}

# %%
def enum_data_process(dataset):
    """enum_data_process"""
    output = []
    for d_json in dataset:
        text = d_json["text"].lower().replace("\t", " ")
        labels = []
        for event in d_json.get("event_list", []):
            if event["event_type"] != "公司上市":
                continue
            for argument in event["arguments"]:
                role_type = argument["role"]
                if role_type == enum_role and argument["argument"] not in labels:
                    labels.append(argument["argument"])
        if labels:
            output.append({
                "id": d_json["id"],
                "sent_id": d_json["sent_id"],
                "text": text,
                "labels": labels
            })
    return output

# %%
def trigger_data_process(dataset):
    """data_process"""
    
    def label_data(data, start, l, _type):
        """label_data"""
        for i in range(start, start + l):
            suffix = "B-" if i == start else "I-"
            if isinstance(data[i], str):
                data[i] = []
            solt = "{}{}".format(suffix, _type)
            if solt not in data[i]:
                data[i].append(solt)
        return data
    
    def replace_control_chars(str):
        if str == '\u200b' or str == '\ufeff' or str == '\ue601' or str == '\u3000':
            return '[UNK]'
        else:
            return str

    output = []
    for d_json in dataset:
        _id = d_json["id"]
        text_a = [
            "，" if t == " " or t == "\n" or t == "\t" else replace_control_chars(t)
            for t in list(d_json["text"].lower())
        ]
        labels = ["O"] * len(text_a)
        for event in d_json.get("event_list", []):
            event_type = event["event_type"]
            start = event["trigger_start_index"]
            trigger = event["trigger"]
            if start >= 0:
                labels = label_data(labels, start, len(trigger), event_type)
        output.append({
            "id": d_json["id"],
            "sent_id": d_json["sent_id"],
            "text": d_json["text"],
            "tokens": text_a,
            "labels": labels
        })
    return output

# %%
def role_data_process(dataset):
    """data_process"""
    
    def label_data(data, start, l, _type):
        """label_data"""
        for i in range(start, start + l):
            suffix = "B-" if i == start else "I-"
            if isinstance(data[i], str):
                data[i] = []
            solt = "{}{}".format(suffix, _type)
            if solt not in data[i]:
                data[i].append(solt)
        return data
    
    def replace_control_chars(str):
        if str == '\u200b' or str == '\ufeff' or str == '\ue601' or str == '\u3000':
            return '[UNK]'
        else:
            return str

    output = []
    for d_json in dataset:
        _id = d_json["id"]
        text_a = [
            "，" if t == " " or t == "\n" or t == "\t" else replace_control_chars(t)
            for t in list(d_json["text"].lower())
        ]
        if len(d_json.get("event_list", [])) == 0:
            continue
         ### combine same event type
        event_type_mapping = {}
        for event in d_json.get("event_list", []):
            event_type = event['event_type']
            trigger = event['trigger']
            type_tuple = (event_type, trigger)
            if type_tuple not in event_type_mapping:
                event_type_mapping[type_tuple] = []
            for argument in event["arguments"]:
                if argument not in event_type_mapping[type_tuple]:
                    event_type_mapping[type_tuple].append(argument)

        for type_tuple, arguments in event_type_mapping.items():
            event_type = type_tuple[0]
            trigger = type_tuple[1]
            trigger_text = event_type+f"({trigger})："
            labels = ["O"] * len(text_a)
            for arg in arguments:
                role_type = arg["role"]
                if role_type == enum_role:
                    continue
                argument = arg["argument"]
                start = arg["argument_start_index"]
                labels = label_data(labels, start, len(argument), role_type)
            if d_json["id"] == "10be7f956da35f15fa4a9ad2a4556960":
                print(labels)
            text_a_trigger = [
                "，" if t == " " or t == "\n" or t == "\t" else t
                for t in list(trigger_text.lower())
            ]
            trigger_label = ["O"] * len(text_a_trigger)
            output.append({
                "id": d_json["id"],
                "sent_id": d_json["sent_id"],
                "text": trigger_text + d_json["text"],
                "event_type": event_type,
                "trigger": trigger,
                "tokens": text_a_trigger + text_a,
                "labels": trigger_label+labels
            })
    return output

# %%
tokenizer = AutoTokenizer.from_pretrained(tokenizer_model)

# %%
PADDING = tokenizer.vocab[tokenizer.pad_token]
SEP = tokenizer.vocab[tokenizer.sep_token]

# %%
class BaiduEnermDataset(Dataset):
    
    def __init__(self, dataset_path, label_dict_path):
        self.label_vocab = load_dict(label_dict_path)
        self.label_num = max(self.label_vocab.values()) + 1
        self.examples = []
        with open(dataset_path, 'r', encoding='utf-8') as f:
            dataset = json.loads(f.read())
            preprocess_dataset = enum_data_process(dataset)
            for d_json in preprocess_dataset:
                text = d_json['text']
                input_ids = tokenizer(text, is_split_into_words=False, add_special_tokens=True, max_length=max_seq_len, truncation=True)['input_ids']
                tokens_input = input_ids + [PADDING] * (max_seq_len - len(input_ids))
                attention_masks = self._get_attention_mask(input_ids, max_seq_len)
                token_type_ids = self._get_token_type_id(input_ids, max_seq_len)
                example = {
                    "input_ids": tokens_input,
                    "attention_masks": attention_masks,
                    "token_type_ids": token_type_ids
                }
                example.update(d_json)
                if 'labels' in d_json:
                    labels = self.to_one_hot_vector(d_json['labels'])
                    example.update({"encoded_label": labels})
                self.examples.append(example)
                
    def to_one_hot_vector(self, labels):
        """Convert seq to one hot."""
        one_hot_vector = np.zeros(self.label_num)
        for label in labels:
            one_hot_vector[self.label_vocab[label]] = 1
        return one_hot_vector
                
    def __len__(self):
        return len(self.examples)
    
    def __getitem__(self, item_idx):
        example = {
            "id": self.examples[item_idx]["id"],
            "sent_id": self.examples[item_idx]["sent_id"],
            "text": self.examples[item_idx]["text"],
            "input_ids": torch.tensor(self.examples[item_idx]["input_ids"]).long(),
            "attention_masks": torch.tensor(self.examples[item_idx]["attention_masks"]),
            "token_type_ids": torch.tensor(self.examples[item_idx]["token_type_ids"])
        }
        if "encoded_label" in self.examples[item_idx]:
            example.update({"encoded_label": torch.tensor(self.examples[item_idx]["encoded_label"], dtype=torch.float)})
        return example

    def _get_attention_mask(self, input_ids, max_seq_len):
        """Mask for padding."""
        if len(input_ids) > max_seq_len:
            raise IndexError("Token length more than max seq length!")
        return [1] * len(input_ids) + [0] * (max_seq_len - len(input_ids))

    def _get_token_type_id(self, input_ids, max_seq_len):
        """Segments: 0 for the first sequence, 1 for the second."""
        if len(input_ids) > max_seq_len:
            raise IndexError("Token length more than max seq length!")
        segments = []
        current_segment_id = 0
        for input_id in input_ids:
            segments.append(current_segment_id)
            if input_id == SEP:
                current_segment_id = 1
        return segments + [0] * (max_seq_len - len(input_ids))

# %%
class BaiduTriggerDataset(Dataset):
    
    def __init__(self, dataset_path, label_dict_path, ignore_index=-100):
        self.label_vocab = load_dict(label_dict_path)
        self.label_num = max(self.label_vocab.values()) + 1
        self.examples = []
        with open(dataset_path, 'r', encoding='utf-8') as f:
            dataset = json.loads(f.read())
            preprocess_dataset = trigger_data_process(dataset)
            for d_json in preprocess_dataset:
                tokens = d_json['tokens']
                input_ids = tokenizer(tokens, is_split_into_words=True, add_special_tokens=True, max_length=max_seq_len, truncation=True)['input_ids']
                tokens_input = input_ids + [PADDING] * (max_seq_len - len(input_ids))
                attention_masks = self._get_attention_mask(input_ids, max_seq_len)
                token_type_ids = self._get_token_type_id(input_ids, max_seq_len)
                example = {
                    "input_ids": tokens_input,
                    "attention_masks": attention_masks,
                    "token_type_ids": token_type_ids,
                    "seq_lens": len(tokens)
                }
                example.update(d_json)
                if 'labels' in d_json:
                    labels = d_json['labels']
                    labels = labels[:(max_seq_len - 2)]
                    encoded_label = ["O"] + labels + ["O"]
                    encoded_label = self.to_one_hot_vector(encoded_label, max_seq_len - 2 - len(labels))
                    example.update({"encoded_label": encoded_label})
                self.examples.append(example)
                
    def to_one_hot_vector(self, labels, zero_padding_len = 0):
        """Convert seq to one hot."""
        one_hot_vectors = []
        for label in labels:
            one_hot_vector = np.zeros(self.label_num)
            if isinstance(label, str):
                one_hot_vector[self.label_vocab.get(label, 0)] = 1
            elif isinstance(label, list):
                for l in label:
                    one_hot_vector[self.label_vocab.get(l, 0)] = 1
            one_hot_vectors.append(one_hot_vector)
        for _ in range(zero_padding_len):
            one_hot_vector = np.zeros(self.label_num)
            one_hot_vectors.append(one_hot_vector)
        return np.array(one_hot_vectors)

    def _get_attention_mask(self, input_ids, max_seq_len):
        """Mask for padding."""
        if len(input_ids) > max_seq_len:
            raise IndexError("Token length more than max seq length!")
        return [1] * len(input_ids) + [0] * (max_seq_len - len(input_ids))

    def _get_token_type_id(self, input_ids, max_seq_len):
        """Segments: 0 for the first sequence, 1 for the second."""
        if len(input_ids) > max_seq_len:
            raise IndexError("Token length more than max seq length!")
        segments = []
        current_segment_id = 0
        for input_id in input_ids:
            segments.append(current_segment_id)
            if input_id == SEP:
                current_segment_id = 1
        return segments + [0] * (max_seq_len - len(input_ids))        
    
    def __len__(self):
        return len(self.examples)
    
    def __getitem__(self, item_idx):
        example = {
            "id": self.examples[item_idx]["id"],
            "sent_id": self.examples[item_idx]["sent_id"],
            "text": self.examples[item_idx]["text"],
            "input_ids": torch.tensor(self.examples[item_idx]["input_ids"]).long(),
            "attention_masks": torch.tensor(self.examples[item_idx]["attention_masks"]),
            "token_type_ids": torch.tensor(self.examples[item_idx]["token_type_ids"]),
            "seq_lens": self.examples[item_idx]["seq_lens"]
        }
        if "encoded_label" in self.examples[item_idx]:
            example.update({"encoded_label": torch.tensor(self.examples[item_idx]["encoded_label"], dtype=torch.float)})
        return example

# %%
class BaiduRoleDataset(Dataset):
    
    def __init__(self, dataset_path, label_dict_path, ignore_index=-100):
        self.label_vocab = load_dict(label_dict_path)
        self.label_num = max(self.label_vocab.values()) + 1
        self.examples = []
        with open(dataset_path, 'r', encoding='utf-8') as f:
            dataset = json.loads(f.read())
            preprocess_dataset = role_data_process(dataset)
            for d_json in preprocess_dataset:
                tokens = d_json['tokens']
                input_ids = tokenizer(tokens, is_split_into_words=True, add_special_tokens=True, max_length=max_seq_len, truncation=True)['input_ids']
                tokens_input = input_ids + [PADDING] * (max_seq_len - len(input_ids))
                attention_masks = self._get_attention_mask(input_ids, max_seq_len)
                token_type_ids = self._get_token_type_id(input_ids, max_seq_len)
                example = {
                    "input_ids": tokens_input,
                    "attention_masks": attention_masks,
                    "token_type_ids": token_type_ids,
                    "seq_lens": len(tokens)
                }
                example.update(d_json)
                if 'labels' in d_json:
                    labels = d_json['labels']
                    labels = labels[:(max_seq_len - 2)]
                    encoded_label = ["O"] + labels + ["O"]
                    encoded_label = self.to_one_hot_vector(encoded_label, max_seq_len - 2 - len(labels))
                    example.update({"encoded_label": encoded_label})
                self.examples.append(example)
                
    def to_one_hot_vector(self, labels, zero_padding_len = 0):
        """Convert seq to one hot."""
        one_hot_vectors = []
        for label in labels:
            one_hot_vector = np.zeros(self.label_num)
            if isinstance(label, str):
                one_hot_vector[self.label_vocab.get(label, 0)] = 1
            elif isinstance(label, list):
                for l in label:
                    one_hot_vector[self.label_vocab.get(l, 0)] = 1
            one_hot_vectors.append(one_hot_vector)
        for _ in range(zero_padding_len):
            one_hot_vector = np.zeros(self.label_num)
            one_hot_vectors.append(one_hot_vector)
        return np.array(one_hot_vectors)

    def _get_attention_mask(self, input_ids, max_seq_len):
        """Mask for padding."""
        if len(input_ids) > max_seq_len:
            raise IndexError("Token length more than max seq length!")
        return [1] * len(input_ids) + [0] * (max_seq_len - len(input_ids))

    def _get_token_type_id(self, input_ids, max_seq_len):
        """Segments: 0 for the first sequence, 1 for the second."""
        if len(input_ids) > max_seq_len:
            raise IndexError("Token length more than max seq length!")
        segments = []
        current_segment_id = 0
        for input_id in input_ids:
            segments.append(current_segment_id)
            if input_id == SEP:
                current_segment_id = 1
        return segments + [0] * (max_seq_len - len(input_ids))        
    
    def __len__(self):
        return len(self.examples)
    
    def __getitem__(self, item_idx):
        example = {
            "id": self.examples[item_idx]["id"],
            "sent_id": self.examples[item_idx]["sent_id"],
            "text": self.examples[item_idx]["text"],
            "event_type": self.examples[item_idx]["event_type"],
            "trigger": self.examples[item_idx]["trigger"],
            "input_ids": torch.tensor(self.examples[item_idx]["input_ids"]).long(),
            "attention_masks": torch.tensor(self.examples[item_idx]["attention_masks"]),
            "token_type_ids": torch.tensor(self.examples[item_idx]["token_type_ids"]),
            "seq_lens": self.examples[item_idx]["seq_lens"]
        }
        if "encoded_label" in self.examples[item_idx]:
            example.update({"encoded_label": torch.tensor(self.examples[item_idx]["encoded_label"], dtype=torch.float)})
        return example

# %%
dev_enerm_dataset = BaiduEnermDataset(dataset_path=duee_fin_dev_preprocess_path, label_dict_path=enerm_dict_path)
dev_trigger_dataset = BaiduTriggerDataset(dataset_path=duee_fin_dev_preprocess_path, label_dict_path=trigger_dict_path)
dev_role_dataset = BaiduRoleDataset(dataset_path=duee_fin_dev_preprocess_path, label_dict_path=role_dict_path)
# Out:
# [['B-约谈机构'], ['I-约谈机构'], ['I-约谈机构'], ['I-约谈机构'], ['I-约谈机构'], 'O', 'O', ['B-公司名称'], ['I-公司名称'], 'O', ['B-公司名称'], ['I-公司名称'], ['I-公司名称'], 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ['B-被约谈时间'], ['I-被约谈时间'], 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ['B-公司名称'], ['I-公司名称'], 'O', ['B-公司名称'], ['I-公司名称'], 'O', ['B-公司名称'], ['I-公司名称'], 'O', ['B-公司名称'], ['I-公司名称'], 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']

# %%
len(dev_enerm_dataset)
# Out:
# 66

# %%
len(dev_trigger_dataset)
# Out:
# 1946

# %%
len(dev_role_dataset)
# Out:
# 1803

# %%
def set_seed(seed = 42):
    """Set the seed for generating random numbers on all GPUs.

    It's safe to call this function if CUDA is not available; in that case, it is silently ignored.

    Args:
        seed (int, optional): random numbers on all GPUs. Defaults to 42.
    """
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)

# %%
# setting device on GPU if available, else CPU
device = torch.device(f'cuda:{device_Id}' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
print()

#Additional Info when using cuda
if device.type == 'cuda':
    n_gpu = torch.cuda.device_count()
    print(torch.cuda.get_device_name(0))
    
    print('Memory Usage:')
    print('Allocated:', torch.cuda.memory_allocated(0)/1024**3, 'GB')
    print('Cached:   ', torch.cuda.memory_reserved(0)/1024**3, 'GB')
    
    print('CUDA Device Count:', n_gpu)
    
set_seed(seed=42)
# Out:
# Using device: cuda:1
#
# Tesla V100-PCIE-32GB
# Memory Usage:
# Allocated: 0.0 GB
# Cached:    0.0 GB
# CUDA Device Count: 3

# %%
@torch.no_grad()
def test_enerm(model, test_dataloader):
    from sklearn.metrics import f1_score, recall_score, precision_score, accuracy_score
    
    model.eval()
    step = 0
    eval_acc = 0.0
    eval_f1 = 0.0
    eval_precision = 0.0
    eval_recall = 0.0
    results = []
    test_iterator = tqdm(test_dataloader)
    for batch in test_iterator:
        _, logits = model(
            input_ids=batch['input_ids'].to(device),
            attention_mask=batch['attention_masks'].to(device),
            token_type_ids=batch['token_type_ids'].to(device),
            labels=batch['encoded_label'].to(device)
        )

        probs = torch.sigmoid(logits).data.cpu()
        probs_ids = (probs > 0.5).numpy()
        true_label = batch.get("encoded_label", None).cpu().numpy()
        probs = probs.numpy()
        pred_Y = probs_ids.flatten()
        true_Y = true_label.flatten()
        eval_acc += accuracy_score(pred_Y, true_Y)
        eval_precision += precision_score(pred_Y, true_Y, average="macro", zero_division=1)
        eval_recall += recall_score(pred_Y, true_Y, average="macro", zero_division=1)
        eval_f1 += f1_score(pred_Y, true_Y, average="macro")
        for id_, sent_id, text, label_probs, p_id in zip(batch['id'], batch['sent_id'], batch['text'], probs.tolist(), probs_ids.tolist()):
            true_indices = np.argwhere(p_id).flatten()
            labels = [id2enumlabel[true_index] for true_index in true_indices]
            results.append({"id": id_, "sent_id": sent_id, "text": text, "pred":{"probs": label_probs, "label": labels}})
        step += 1
    print({"Avg eval acc": f"{eval_acc/step:.2f}", "Avg eval precision": f"{eval_precision/step:.2f}", "Avg eval recall": f"{eval_recall/step:.2f}", "Avg eval f1": f"{eval_f1/step:.2f}"})
    return results

# %%
enum_model = torch.load(enerm_model_path).to(device)

test_enerm_sampler = SequentialSampler(dev_enerm_dataset)
test_enerm_dataloader = DataLoader(dev_enerm_dataset, sampler=test_enerm_sampler, batch_size = 512)
    
sentences_enum_data = test_enerm(enum_model, test_enerm_dataloader)
# Out:
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# {'Avg eval acc': '1.00', 'Avg eval precision': '1.00', 'Avg eval recall': '1.00', 'Avg eval f1': '1.00'}

# %%
@torch.no_grad()
def test_trigger(model, test_dataloader):
    from sklearn.metrics import accuracy_score
    
    model.eval()
    step = 0
    eval_acc = 0.0
    eval_f1 = 0.0
    eval_precision = 0.0
    eval_recall = 0.0
    results = []
    test_iterator = tqdm(test_dataloader)
    for batch in test_iterator:
        _, logits = model(
            input_ids=batch['input_ids'].to(device),
            attention_mask=batch['attention_masks'].to(device),
            token_type_ids=batch['token_type_ids'].to(device)
        )

        probs = torch.sigmoid(logits).data.cpu()
        probs_ids = (probs > 0.5).numpy()
        probs = probs.numpy()
        true_Y = batch['encoded_label'].cpu().numpy()
        batch_size = true_Y.shape[0]
        batch_precision, batch_recall, batch_f1 = 0.0, 0.0, 0.0
        for text, t_ids, p_ids, seq_len in zip(batch["text"], true_Y, probs_ids, batch['seq_lens']):
            true_label, pred_label = [], []
            for pid in p_ids[1: seq_len - 1]:
                true_indices = np.argwhere(pid).flatten()
                pred_label.append([id2triggerlabel[true_index] for true_index in true_indices])
            p_ret = extract_result_multilabel(text, pred_label)
            pred_event_types = set([(p["type"], ''.join(p["text"]), p["start"]) for p in p_ret])
            for tid in t_ids[1: seq_len - 1]:
                true_indices = np.argwhere(tid).flatten()
                true_label.append([id2triggerlabel[true_index] for true_index in true_indices])
            t_ret = extract_result_multilabel(text, true_label)
            true_event_types = set([(t["type"], ''.join(t["text"]), t["start"]) for t in t_ret])
            count_predict = len(list(pred_event_types))
            count_true = len(list(true_event_types))
            count_correct = len(list(pred_event_types & true_event_types))
            p = count_correct / max(1, count_predict)  # precision
            r = count_correct / max(1, count_true)  # recall
            batch_precision += p
            batch_recall += r
            batch_f1 += 2 * r * p / max(1e-9, r + p) # f1 score
        eval_acc += accuracy_score(probs_ids.flatten(), true_Y.flatten())
        eval_precision += batch_precision / batch_size
        eval_recall += batch_recall / batch_size
        eval_f1 += batch_f1 / batch_size
        for id_, sent_id, text, p_list, p_ids, seq_len in zip(batch['id'], batch['sent_id'], batch['text'], probs.tolist(), probs_ids.tolist(), batch['seq_lens']):
            prob_multi, label_multi = [], []
            for index, pid in enumerate(p_ids[1: seq_len - 1]):
                true_indices = np.argwhere(pid).flatten()
                prob_multi.append(p_list[index])
                label_multi.append([id2triggerlabel[true_index] for true_index in true_indices])
            results.append({"id": id_, "sent_id":sent_id, "text": text, "pred": {"probs": prob_multi, "labels": label_multi}})
        step += 1
    print({"Avg eval acc": f"{eval_acc/step:.2f}", "Avg eval precision": f"{eval_precision/step:.2f}", "Avg eval recall": f"{eval_recall/step:.2f}", "Avg eval f1": f"{eval_f1/step:.2f}"})
    return results

# %%
tigger_model = torch.load(tigger_model_path).to(device)

test_trigger_sampler = SequentialSampler(dev_trigger_dataset)
test_trigger_dataloader = DataLoader(dev_trigger_dataset, sampler=test_trigger_sampler, batch_size = 512)
    
sentences_tigger_data = test_trigger(tigger_model, test_trigger_dataloader)
# Out:
# HBox(children=(IntProgress(value=0, max=4), HTML(value='')))
# {'Avg eval acc': '1.00', 'Avg eval precision': '0.62', 'Avg eval recall': '0.65', 'Avg eval f1': '0.63'}

# %%
@torch.no_grad()
def test_role(model, test_dataloader):
    from sklearn.metrics import f1_score, recall_score, precision_score, accuracy_score

    model.eval()
    step = 0
    eval_acc = 0.0
    eval_f1 = 0.0
    eval_precision = 0.0
    eval_recall = 0.0
    results = []
    test_iterator = tqdm(test_dataloader)
    for batch in test_iterator:
        loss, logits = model(
            input_ids=batch['input_ids'].to(device),
            attention_mask=batch['attention_masks'].to(device),
            token_type_ids=batch['token_type_ids'].to(device)
        )

        probs = torch.sigmoid(logits).data.cpu()
        probs_ids = (probs > 0.3).numpy()
        probs = probs.numpy()
        true_Y = batch['encoded_label'].cpu().numpy()
        batch_size = true_Y.shape[0]
        batch_precision, batch_recall, batch_f1 = 0.0, 0.0, 0.0
        for text, t_ids, p_ids, seq_len in zip(batch["text"], true_Y, probs_ids, batch['seq_lens']):
            true_label, pred_label = [], []
            for pid in p_ids[1: seq_len - 1]:
                true_indices = np.argwhere(pid).flatten()
                pred_label.append([id2rolelabel[true_index] for true_index in true_indices])
            p_ret = extract_result_multilabel(text, pred_label)
            pred_event_types = set([(p["type"], ''.join(p["text"]), p["start"]) for p in p_ret])
            for tid in t_ids[1: seq_len - 1]:
                true_indices = np.argwhere(tid).flatten()
                true_label.append([id2rolelabel[true_index] for true_index in true_indices])
            t_ret = extract_result_multilabel(text, true_label)
            true_event_types = set([(t["type"], ''.join(t["text"]), t["start"]) for t in t_ret])
            count_predict = len(list(pred_event_types))
            count_true = len(list(true_event_types))
            count_correct = len(list(pred_event_types & true_event_types))
            p = count_correct / max(1, count_predict)  # precision
            r = count_correct / max(1, count_true)  # recall
            batch_precision += p
            batch_recall += r
            batch_f1 += 2 * r * p / max(1e-9, r + p) # f1 score
        eval_acc += accuracy_score(probs_ids.flatten(), true_Y.flatten())
        eval_precision += batch_precision / batch_size
        eval_recall += batch_recall / batch_size
        eval_f1 += batch_f1 / batch_size
        for id_, sent_id, text, input_ids, event_type, trigger, p_list, p_ids, seq_len in zip(batch['id'], batch['sent_id'], batch['text'], batch['input_ids'], batch['event_type'], batch['trigger'], probs.tolist(), probs_ids.tolist(), batch['seq_lens']):
            prob_multi, label_multi = [], []
            for index, pid in enumerate(p_ids[1: seq_len - 1]):
                true_indices = np.argwhere(pid).flatten()
                prob_multi.append(p_list[index])
                label_multi.append([id2rolelabel[true_index] for true_index in true_indices])
            results.append({"id": id_, "sent_id":sent_id, "event_type": event_type, "trigger": trigger, "text": text, "tokens": tokenizer.convert_ids_to_tokens(input_ids), "pred": {"probs": prob_multi, "labels": label_multi}})
        step += 1
    print({"Avg eval acc": f"{eval_acc/step:.2f}", "Avg eval precision": f"{eval_precision/step:.2f}", "Avg eval recall": f"{eval_recall/step:.2f}", "Avg eval f1": f"{eval_f1/step:.2f}"})
    return results

# %%
role_model = torch.load(role_model_path).to(device)

test_role_sampler = SequentialSampler(dev_role_dataset)
test_role_dataloader = DataLoader(dev_role_dataset, sampler=test_role_sampler, batch_size = 512)
    
sentences_role_data = test_role(role_model, test_role_dataloader)
# Out:
# HBox(children=(IntProgress(value=0, max=4), HTML(value='')))
# {'Avg eval acc': '1.00', 'Avg eval precision': '0.67', 'Avg eval recall': '0.74', 'Avg eval f1': '0.69'}

# %%
def event_normalization(doc):
    """event_merge"""
    for event in doc.get("event_list", []):
        argument_list = []
        argument_set = set()
        for arg in event["arguments"]:
            arg_str = "{}-{}".format(arg["role"], arg["argument"])
            if arg_str not in argument_set:
                argument_list.append(arg)
            argument_set.add(arg_str)
        event["arguments"] = argument_list

    event_list = sorted(
        doc.get("event_list", []),
        key=lambda x: len(x["arguments"]),
        reverse=True)
    new_event_list = []
    for event in event_list:
        event_type = event["event_type"]
        event_argument_set = set()
        for arg in event["arguments"]:
            event_argument_set.add("{}-{}".format(arg["role"], arg["argument"]))
        flag = True
        for new_event in new_event_list:
            if event_type != new_event["event_type"]:
                continue
            new_event_argument_set = set()
            for arg in new_event["arguments"]:
                new_event_argument_set.add("{}-{}".format(arg["role"], arg[
                    "argument"]))
            if len(event_argument_set & new_event_argument_set) == len(
                    new_event_argument_set):
                flag = False
        if flag:
            new_event_list.append(event)
    doc["event_list"] = new_event_list
    return doc

def predict_data_process(trigger_data, role_data, enum_data, schema_file):
    """predict_data_process"""
    pred_ret = []
    schema_data = read_by_lines(schema_file)
    print("trigger predict {} load.".format(len(trigger_data)))
    print("role predict {} load".format(len(role_data)))
    print("enum predict {} load".format(len(enum_data)))
    print("schema {} load from {}".format(len(schema_data), schema_file))

    schema, sent_role_mapping, sent_enum_mapping = {}, {}, {}
    for s in schema_data:
        d_json = json.loads(s)
        schema[d_json["event_type"]] = [r["role"] for r in d_json["role_list"]]

    # role depends on id and sent_id 
    for d_json in role_data:
        r_ret = extract_result_multilabel(d_json["text"], d_json["pred"]["labels"])
        role_ret = {}
        for r in r_ret:
            role_type = r["type"]
            if role_type not in role_ret:
                role_ret[role_type] = []
            role_ret[role_type].append("".join(r["text"]))
        _id = "{}\t{}\t{}\t{}".format(d_json["id"], d_json["sent_id"], d_json["event_type"], d_json["trigger"])
        if _id not in sent_role_mapping:
            sent_role_mapping[_id] = role_ret
        else:
            for role_type, vals in role_ret.items():
                if role_type in sent_role_mapping[_id]:
                    sent_role_mapping[_id][role_type].extend(vals)
                else:
                    sent_role_mapping[_id][role_type] = vals
            
    # process the enum_role data
    for d_json in enum_data:
        _id = "{}\t{}".format(d_json["id"], d_json["sent_id"])
        labels = d_json["pred"]["label"]
        sent_enum_mapping[_id] = labels

    # process trigger data
    for d_json in trigger_data:
        t_ret = extract_result_multilabel(d_json["text"], d_json["pred"]["labels"])
        pred_event_types = list(set([(t["type"], ''.join(t["text"])) for t in t_ret]))
        event_list = []
        _id = "{}\t{}".format(d_json["id"], d_json["sent_id"])
        for pred_event_type in pred_event_types:
            event_type = pred_event_type[0]
            trigger = pred_event_type[1]
            role_id = _id + "\t{}\t{}".format(event_type, trigger)
            role_list = schema[event_type]
            arguments = []
            for role_type, ags in sent_role_mapping.get(role_id, {}).items():
                if role_type not in role_list:
                    continue
                for arg in ags:
                    out = {"role": role_type, "argument": arg}
                    if out not in arguments:
                        arguments.append(out)
            # 特殊处理环节
            if arguments and event_type == enum_event_type:
                for label in sent_enum_mapping.get(_id, []):
                    arguments.append({
                        "role": enum_role,
                        "argument": label
                    })
            if arguments:
                event = {
                    "event_type": event_type,
                    "arguments": arguments,
                    "text": d_json["text"]
                }
                event_list.append(event)
        pred_ret.append({
            "id": d_json["id"],
            "sent_id": d_json["sent_id"],
            "text": d_json["text"],
            "event_list": event_list
        })
    doc_pred = {}
    for d in pred_ret:
        if d["id"] not in doc_pred:
            doc_pred[d["id"]] = {"id": d["id"], "event_list": []}
        doc_pred[d["id"]]["event_list"].extend(d["event_list"])

    # unfiy the all prediction results and save them
    doc_pred = [
        event_normalization(r)
        for r in doc_pred.values()
    ]
    print("submit data {} save".format(len(doc_pred)))
    return doc_pred

# %%
doc_pred = predict_data_process(sentences_tigger_data, sentences_role_data, sentences_enum_data, shema_path)
# Out:
# trigger predict 1946 load.
# role predict 1803 load
# enum predict 66 load
# schema 13 load from ./dictionary/event_schema.json
# submit data 1174 save

# %%
# true_sent_enum_data, true_sent_tigger_data, true_sent_role_data  = [], [], []
# with open(duee_fin_dev_preprocess_path, 'r', encoding='utf-8') as f:
#     dataset = json.loads(f.read())
#     preprocess_enum_dataset = enum_data_process(dataset)
#     preprocess_trigger_dataset = trigger_data_process(dataset)
#     preprocess_role_dataset = role_data_process(dataset)
#     for d_json in preprocess_enum_dataset:
#         true_sent_enum_data.append({"id": d_json['id'], "sent_id":d_json['sent_id'], "text": d_json['text'], "pred": {"label": d_json['label']}})
#     for d_json in preprocess_trigger_dataset:
#         labels = d_json['labels']
#         labels = labels[:(max_seq_len - 2)]
#         encoded_label = [[l] if isinstance(l , str) else l for l in labels]
#         true_sent_tigger_data.append({"id": d_json['id'], "sent_id":d_json['sent_id'], "text": d_json['text'], "pred": {"labels": encoded_label}})
#     for d_json in preprocess_role_dataset:
#         labels = d_json['labels']
#         labels = labels[:(max_seq_len - 2)]
#         encoded_label = [[l] if isinstance(l , str) else l for l in labels]
#         true_sent_role_data.append({"id": d_json['id'], "sent_id":d_json['sent_id'], "event_type": d_json['event_type'], "trigger": d_json['trigger'], "text": d_json['text'], "pred": {"labels": encoded_label}})

# %%
true_data_list = []
with open(duee_fin_dev_path, 'r', encoding='utf-8') as f:
    for line in f:
        json_data = json.loads(line)
        true_data_list.append(json_data)
pred_mapping_dict = {}
for doc in doc_pred:
    pred_mapping_dict[doc['id']] = doc

# %%
count = 0
for true_data in true_data_list:
    id_ = true_data['id']
    true_data_set = set([(argument['role'], argument['argument']) for true_event in true_data.get('event_list', []) for argument in true_event.get('arguments')])
    pred_data = pred_mapping_dict[id_]
    pred_data_set = set([(argument['role'], argument['argument']) for pred_event in pred_data.get('event_list', []) for argument in pred_event.get('arguments')])
    if len(list(true_data_set)) != len(list(pred_data_set)):
        print(id_)
        print(list(true_data_set))
        print(list(pred_data_set))
        count += 1
# Out:
# 10be7f956da35f15fa4a9ad2a4556960
# [('公司名称', '美团'), ('公司名称', '饿了么'), ('约谈机构', '北京市监局'), ('公司名称', '京东'), ('公司名称', '快手'), ('被约谈时间', '近日'), ('公司名称', '抖音'), ('公司名称', '微店')]
# [('中标公司', '中国中铁'), ('变动类型', '退休'), ('中标金额', '546.8亿元'), ('中标标的', '重大工程项目'), ('高管姓名', '马云'), ('披露日期', '7月7日'), ('中标日期', '近期')]
# 35fabe18c5f8e5898ed45043d064ac8f
# [('变动类型', '聘任'), ('事件时间', '自本次董事会审议通过之日起至第三届董事会任期届满之日止'), ('高管姓名', '叶潇'), ('高管职位', '董事会秘书'), ('变动后职位', '公司副总经理'), ('任职公司', '汉邦高科'), ('事件时间', '近日'), ('变动类型', '辞去'), ('高管姓名', '赵倩莹'), ('变动后职位', '董事会秘书'), ('高管职位', '公司副总经理')]
# [('高管职位', '副总经理'), ('高管姓名', '叶潇'), ('高管职位', '董事会秘书'), ('任职公司', '汉邦高科'), ('变动类型', '辞职'), ('变动类型', '辞去'), ('高管姓名', '赵倩莹'), ('事件时间', '近日')]
# 6840d385c03e24f37064faa6c6eae757
# [('质押股票/股份数量', '1990万'), ('质押物所属公司', '方盛制药'), ('披露时间', '7月7日晚间'), ('质押物占总股比', '32.28%'), ('质押方', '张庆华'), ('质押物占持股比', '89.77%'), ('质权方', '长沙银行股份有限公司高信支行'), ('质押股票/股份数量', '约1779.65万'), ('质押股票/股份数量', '约为1.4亿'), ('质押物', '股份'), ('事件时间', '截至本公告披露日'), ('事件时间', '7月7日')]
# [('质押股票/股份数量', '1990万'), ('质押物所属公司', '方盛制药'), ('披露时间', '7月7日晚间'), ('质押物占总股比', '32.28%'), ('质押方', '张庆华'), ('质押物占持股比', '89.77%'), ('质押股票/股份数量', '约779.65万'), ('质权方', '长沙银行股份有限公司高信支行'), ('事件时间', '截至本公告披露日'), ('质押物', '股份'), ('质押股票/股份数量', '1779.65万'), ('质押股票/股份数量', '约为1.4亿'), ('质权方', '长沙银行份有限公司高信支行'), ('事件时间', '7月7日')]
# 059e1e8ade11b1de9ab81a728eab2c81
# [('被收购方', 'Postmates'), ('收购方', 'Uber'), ('披露时间', '6月30日')]
# [('被收购方', 'Postmates'), ('被收购方', 'GrubHub'), ('收购方', 'Uber'), ('披露时间', '6月30日')]
# 1e4227df13157e46f90e6219550f1caf
# [('被收购方', '柏盛国际'), ('减持部分占总股本比例', '不超过5.54%'), ('收购方', '蓝帆医疗'), ('减持方', '蓝帆集团'), ('披露时间', '上月'), ('减持方', '北京中信'), ('股票简称', '蓝帆医疗')]
# [('减持部分占总股本比例', '不超过5.54%'), ('收购方', '蓝帆医疗'), ('收购完成时间', '去年'), ('披露时间', '上月'), ('交易金额', '超过15亿元'), ('减持方', '北京中信'), ('股票简称', '蓝帆医疗'), ('收购方', '柏盛国际'), ('交易金额', '15亿元')]
# 0aadf059b6a584edff8b5199bbbff2f3
# [('被收购方', '北京联银通科技有限公司'), ('交易金额', '不超过30000万元'), ('收购方', '东华合创'), ('收购标的', '100%的股权')]
# [('被收购方', '联银通'), ('收购方', '东华合创'), ('被收购方', '北京联银通科技有限公司'), ('收购标的', '100%的股权'), ('交易金额', '不超过30000万元')]
# edd124f781680a7c59f1b94cd6ea9483
# [('公司名称', '蔚来汽车'), ('披露时间', '9月25日晚间'), ('净亏损', '32.85亿元'), ('财报周期', '第二季度')]
# [('收购标的', '居然金融核心业务金融系统软件平台'), ('交易金额', '3.35亿元'), ('交易金额', '3400万元'), ('被收购方', '居然之家（天津）融资担保有限公司'), ('交易金额', '1亿元'), ('被收购方', '居然之家金融控股有限公司'), ('收购标的', '100%股权'), ('被收购方', '北京居然之家小额贷款有限责任公司'), ('披露时间', '近日'), ('收购方', '居然之家')]
# [('交易金额', '3.35亿元'), ('交易金额', '3400万元'), ('交易金额', '1亿元'), ('收购方', '居然之家（天津）融资担保有限公司'), ('收购标的', '100%股权'), ('被收购方', '北京居然之家小额贷款有限责任公司'), ('披露时间', '近日'), ('收购方', '居然之家')]
# 5a92f20e17a8b64eb45715c32129b0ce
# [('质押物所属公司', '江河集团'), ('事件时间', '近日'), ('质押方', '江河汇众'), ('质押股票/股份数量', '7055.5万'), ('质押物占总股比', '6.11%'), ('质押物占总股比', '3.97%'), ('质押方', '天津江河汇众企业管理合伙企业(有限合伙)'), ('事件时间', '截至公告日'), ('质押股票/股份数量', '4580万'), ('披露时间', '9月10日'), ('质押物', '股份'), ('质押物占持股比', '29.33%'), ('质权方', '中国银河(11.980,0.04,0.34%)证券')]
# [('质押方', '天津江河汇众企业管理合伙企业'), ('质押物占总股比', '3.97'), ('质押物所属公司', '江河集团'), ('质押物', '股票'), ('事件时间', '近日'), ('质押方', '江河汇众'), ('质押股票/股份数量', '7055.5万'), ('质押物占总股比', '6.11%'), ('质押股票/股份数量', '4580万'), ('事件时间', '截至公告日'), ('质押方', '天津江河汇众企业'), ('披露时间', '9月10日'), ('质押物占总股比', '29.33%'), ('质押物', '股份'), ('质权方', '中国银河(11.980,0.04,0.34%)证券')]
# 40eccbbcde99f8f8546567964cc5407e
# [('上市公司', '农夫山泉'), ('市值', '约3698亿港元'), ('发行价格', '33港元'), ('证券代码', '09633.HK'), ('事件时间', '9月8日'), ('环节', '正式上市')]
# [('环节', '正式上市'), ('上市公司', '农夫山泉'), ('事件时间', '9月8日'), ('证券代码', '09633.HK')]
# f7c72b88188bdb556c7863d0b4e3c847
# [('股票简称', 'Fastly'), ('交易完成时间', '上周的大部分时间')]
# []
# e9aa55070ec2cfc9dbca5f681caf4120
# [('增持方', '阿里巴巴'), ('收购标的', '部分股份'), ('交易金额', '66亿元'), ('增持部分占总股本比例', '12％'), ('被收购方', '申通'), ('收购方', '阿里'), ('被收购方', '中通'), ('披露时间', '9月1日'), ('被收购方', '韵达'), ('股票简称', '圆通速递'), ('被收购方', '百世汇通'), ('交易股票/股份数量', '379,179,681'), ('每股交易价格', '17.406元')]
# [('增持方', '阿里巴巴'), ('交易金额', '66亿元'), ('股票简称', '四通一达'), ('股票简称', '圆'), ('增持部分占总股本比例', '12％'), ('披露时间', '9月1日'), ('股票简称', '圆通快递'), ('增持方', '阿里网络'), ('交易股票/股份数量', '379,179,681'), ('每股交易价格', '17.406元')]
# 33d158b2c8455b3477c2cfcb872d510c
# [('占公司总股本比例', '约5.0%'), ('交易金额', '1501万美元'), ('回购方', '安东油田服务'), ('回购完成时间', '本公告日期')]
# [('交易金额', '1.16亿美元'), ('回购方', '安东油田服务'), ('占公司总股本比例', '约38.5'), ('回购完成时间', '本公告日期'), ('占公司总股本比例', '约5.0%'), ('交易金额', '1501万美元')]
# a413e8c72bba3359cc9a5cf6cea4fc8b
# [('破产公司', 'OneWeb'), ('破产时间', '今年3月')]
# [('破产公司', 'Cerberus Capital Management'), ('披露时间', '5月8日'), ('破产时间', '今年3月')]
# 17e2fa2ba6ced3d8897a58646305aeae
# [('披露时间', '昨天'), ('财报周期', '2018年'), ('净亏损', '约40亿-50亿元'), ('财报周期', '2019年上半年'), ('公司名称', '锦州银行'), ('净亏损', '约5亿-10亿元')]
# [('披露时间', '昨天'), ('净亏损', '约40亿-50亿元'), ('财报周期', '2019年上半年'), ('公司名称', '锦州银行'), ('净亏损', '约5亿-10亿元')]
# 713a9d5d54604e8ed43f9cb669a9d2a5
# [('财报周期', '第二季度'), ('公司名称', '瑞幸咖啡'), ('净亏损', '6.81亿元')]
# [('公司名称', '瑞幸咖啡'), ('净亏损', '6.81亿'), ('财报周期', '第二季度'), ('披露时间', '周三(14日'), ('净亏损', '6.81亿元'), ('亏损变化', '同比大'), ('亏损变化', '扩大')]
# 51b81ce2379146b04a1440e4f6d2bf39
# [('交易完成时间', '公告发布披露之日起15个交易日后的6个月内'), ('减持方', '张立忠'), ('交易股票/股份数量', '不超过34,176,237'), ('披露时间', '2020年5月19日'), ('减持部分占总股本比例', '0.8145%'), ('股票简称', '大北农')]
# [('减持方', '张立忠'), ('交易股票/股份数量', '不超过34,176,237'), ('披露时间', '2020年5月19日'), ('减持方', '谈松林'), ('减持部分占总股本比例', '0.8145%'), ('交易完成时间', '2020年7月15日'), ('股票简称', '大北农'), ('减持方', '王丽娜')]
# d7b6d27d78cf7b627d2de809199744e2
# [('减持部分占总股本比例', '不超过公司总股本的3.519%'), ('减持方', '常州中科'), ('股票简称', '宏盛股份')]
# [('减持部分占总股本比例', '不超过公司总股本的3.519%'), ('减持方', '常州中科'), ('股票简称', '宏盛股份'), ('减持部分占总股本比例', '3.519%')]
# f7e1ebeff3301ce9ae40b216535183d1
# [('披露时间', '31日'), ('被投资方', '苏州苏高新集团有限公司'), ('融资金额', '6亿元')]
# []
# bbc1e37960552fe00f1043fcc1d89c1e
# [('质押物', '无限售流通股'), ('事件时间', '2019年9月23日'), ('披露时间', '2019年9月24日'), ('质押物占总股比', '23.20%'), ('事件时间', '截至2019年9月23日'), ('质押股票/股份数量', '50,000,000'), ('质押物占总股比', '11.60%'), ('质押物占持股比', '79.26%'), ('事件时间', '2019年9月20日'), ('质押方', '中国宝安(4.600,-0.12,-2.54%)集团股份有限公司'), ('质权方', '招商银行股份有限公司深圳分行'), ('质押股票/股份数量', '100,000,000'), ('质押物所属公司', '马应龙药业集团股份有限公司')]
# [('变动类型', '聘任'), ('披露日期', '9月4日晚间'), ('任职公司', '金龙汽车'), ('变动后职位', '财财务总监'), ('高管姓名', '梁明煅'), ('变动后职位', '公司财务总监'), ('高管姓名', '马祥'), ('高管姓名', '张斌'), ('高管姓名', '吴文彬'), ('变动后职位', '副总裁')]
# ae14f65f7fafb7095e8b4fcb503bf943
# [('交易金额', '3.92亿澳元'), ('收购方', '山东黄金'), ('被收购方', '卡帝诺资源有限公司'), ('收购标的', '股份')]
# [('被收购方', '卡帝诺'), ('交易金额', '约为3.92亿澳元'), ('收购方', '山东黄金香港'), ('收购标的', '股份'), ('收购方', '山东黄金'), ('交易金额', '约为3.92亿澳')]
# 77efcfbf05f603fe3bdf9880d931df7f
# [('中标日期', '8月19日'), ('中标标的', '2020-2021年度ICT短名单采购项目'), ('中标公司', '中科恒运'), ('招标方', '中国移动湖南公司长沙公司'), ('中标金额', '544万元'), ('披露日期', '8月19日')]
# [('中标日期', '8月19日'), ('中标标的', '2020-2021年度ICT短名单采购项目'), ('中标公司', '中科恒运'), ('中标日期', '今日'), ('中标金额', '544万元'), ('招标方', '中国移动'), ('招标方', '中国移动长沙分公司'), ('披露日期', '8月19日'), ('中标标的', 'ICT项目')]
# 99677802a924c36f5eb5b3bd8f3a8f63
# [('质押方', '好当家集团'), ('质押股票/股份数量', '3000万'), ('质押物所属公司', '好当家集团'), ('事件时间', '2020年11月9日'), ('质押物所属公司', '日照银行股份有限公司威海分行'), ('质权方', '日照银行股份有限公司威海分行'), ('质押物占总股比', '19.36%'), ('质押物占总股比', '2.05%'), ('质押物占持股比', '46.94%'), ('质押物', '流通股'), ('质押物', '股份'), ('披露时间', '11月11日晚间'), ('质押物占持股比', '4.98%')]
# [('质押股票/股份数量', '3000万'), ('质押物占总股比', '19.36'), ('质押物所属公司', '山东好当家海洋发展股份有限公司'), ('质押物所属公司', '好当家集团'), ('质押方', '好当家集团'), ('事件时间', '2020年11月9日'), ('质押物占总股比', '2.05%'), ('事件时间', '2020年11月10日'), ('事件时间', '近日'), ('质押物所属公司', '好当家'), ('披露时间', '11月11日晚间'), ('质押物占持股比', '4.98%'), ('质押物', '无限售流通股'), ('质权方', '日照银行股份有限公司威海分行'), ('质押股票/股份数量', '约为6.03亿'), ('质押物占持股比', '46.94%'), ('事件时间', '2020年11月09日'), ('质押方', '好当家集团有限公司'), ('质押股票/股份数量', '约2.83亿'), ('质押物', '股份')]
# 74f4c33e74fbfb742daf8fb9bd5d178e
# [('每股交易价格', '15.96元'), ('高管姓名', '王慕昊'), ('回购完成时间', '2019年8月26日'), ('任职公司', '凯众股份'), ('披露日期', '8月21日'), ('回购方', '凯众股份'), ('高管姓名', '袁健芳'), ('回购股份数量', '9.9万'), ('变动类型', '离职')]
# [('每股交易价格', '15.96元'), ('回购完成时间', '2019年8月26日'), ('回购方', '凯众股份'), ('披露时间', '8月21日'), ('回购股份数量', '9.9万')]
# f166fad0ccfbb2149755d0fec84327db
# [('财报周期', '上年同期'), ('净亏损', '2.73亿元'), ('亏损变化', '收窄'), ('财报周期', '截至今年6月底止中期'), ('净亏损', '2.14亿元'), ('公司名称', '平安好医生')]
# [('财报周期', '上年同期'), ('净亏损', '2.73亿元'), ('亏损变化', '收窄'), ('财报周期', '截至今年6月底止中期'), ('净亏损', '2.14亿元'), ('公司名称', '平安好医生'), ('净亏损', '2.08亿元')]
# dccba1c3295b1ace98a0ab5e17b2b22a
# [('质权方', '西安聚华网络小额贷款有限公司'), ('质押物占总股比', '13.82%'), ('事件时间', '2019年10月15日'), ('质押方', '西安聚华网络小额贷款有限公司'), ('质押股票/股份数量', '374万'), ('质押物占持股比', '93.30%'), ('质押物', '流通股'), ('质押物占总股比', '0.76%'), ('质押股票/股份数量', '6798.4万'), ('质押物', '股份'), ('质押物所属公司', '广誉远'), ('事件时间', '截至本公告披露日'), ('披露时间', '10月15日'), ('质押方', '东盛集团')]
# [('质权方', '西安聚华网络小额贷款有限公司'), ('事件时间', '2019年10月15日'), ('质押物占总股比', '13.82'), ('质押股票/股份数量', '374万'), ('质押物占持股比', '93.30%'), ('质押股票/股份数量', '6798.4万'), ('质押物', '股份'), ('质押物所属公司', '广誉远'), ('披露时间', '10月15日'), ('事件时间', '截至本公告披露日'), ('质押物占总股比', '0.76%)')]
# ed4af7246c72b0026a18efae196e88b6
# [('股票简称', '同享科技'), ('减持方', '上海宝源胜知投资管理有限公司'), ('交易完成时间', '今年7月27日'), ('交易股票/股份数量', '8万'), ('交易金额', '112.91万元'), ('披露时间', '近日')]
# [('股票简称', '同享科技'), ('交易完成时间', '今年7月27日'), ('交易股票/股份数量', '8万'), ('交易金额', '112.91万元'), ('减持方', '宝源胜知投资')]
# 4108b8772b3142a4b4169d74b83ab0bd
# [('亏损变化', '减少'), ('公司名称', '韶华文化'), ('财报周期', '2020年半年度'), ('披露时间', '近日'), ('净亏损', '293,376.03元')]
# [('亏损变化', '减少'), ('公司名称', '韶华文化'), ('财报周期', '上年同期'), ('财报周期', '2020年半年度'), ('披露时间', '近日'), ('净亏损', '293,376.03元')]
# 4924a1575c9a34bf2ab94db22276645a
# [('中标标的', '新高速公路项目'), ('中标金额', '86.85亿元人民币'), ('中标公司', '四川成渝高速公路')]
# [('中标公司', '中交建'), ('中标金额', '86.85亿元人民币'), ('中标公司', '四川成渝高速公路'), ('中标标的', '天府新区至邛崃高速公路项目')]
# 5a86f6b6ce888f62b8311925ea655643
# [('事件时间', '2017年4月'), ('融资轮次', 'B'), ('融资金额', '2亿美元'), ('投资方', '腾讯'), ('被收购方', 'WHYLAB实验室'), ('融资金额', '3亿美元'), ('收购完成时间', '2019年'), ('投资方', '58同城'), ('融资轮次', 'A'), ('披露时间', '9月11日'), ('收购方', '转转'), ('被投资方', '转转')]
# [('事件时间', '2017年4月'), ('融资轮次', 'B'), ('事件时间', '9月11日'), ('融资金额', '2亿美元'), ('投资方', '腾讯'), ('融资金额', '3亿美元'), ('投资方', '58同城'), ('融资轮次', 'A'), ('披露时间', '9月11日'), ('收购方', '转转'), ('被投资方', '转转')]
# [('事件时间', '截至公告披露日'), ('质押物占持股比', '63.78%'), ('质押物所属公司', '协鑫集成'), ('质押股票/股份数量', '8.18亿'), ('披露时间', '8月12日'), ('质押物占总股比', '16.10'), ('质押物', '股份')]
# 4e42f9375b757fc82935a46228b9a6a2
# [('高管职位', '公司非执行董事'), ('披露日期', '6 月 26日'), ('事件时间', '自2020年6月26日起'), ('变动类型', '辞任'), ('高管姓名', 'Richard Raymond Weissend'), ('变动类型', '委任'), ('变动后职位', '公司非执行董事'), ('高管姓名', 'Rudolf Gijsbert Servaas van den Brink'), ('任职公司', '华润啤酒')]
# [('高管姓名', 'Rudolf Gijsbert Servaas van'), ('披露日期', '6 月 26日'), ('事件时间', '自2020年6月26日起'), ('变动类型', '辞任'), ('高管姓名', 'Richard Raymond Weissend'), ('变动后职位', '非执行董事'), ('变动类型', '委任'), ('高管姓名', 'Rudolf Gijsbert Servaas van den Brink'), ('任职公司', '华润啤酒'), ('高管职位', '非执行董事')]
# c3bfb43872e76ecb6cfb26520f96bcbc
# [('收购方', '浪潮国际'), ('披露时间', '9月19日'), ('收购完成时间', '2018年'), ('被收购方', '天元通信')]
# [('收购方', '互联互通'), ('披露时间', '本'), ('披露时间', '9月19日'), ('收购完成时间', '2018年'), ('被收购方', '天元通信')]
# 758facdb614483d69a9b436ecf836cb9
# [('股票简称', '中芯国际'), ('交易金额', '575万港元'), ('交易股票/股份数量', '31.5万'), ('披露时间', '5月19日'), ('交易完成时间', '5月19日'), ('减持方', '陈山枝'), ('每股交易价格', '18.3港元')]
# [('减持方', '高点'), ('股票简称', '中芯国际'), ('交易金额', '575万港元'), ('交易金额', '约375万港'), ('交易完成时间', '次日'), ('交易股票/股份数量', '31.5万'), ('每股交易价格', '6.4港元'), ('交易完成时间', '5月19日'), ('减持方', '陈山枝'), ('每股交易价格', '18.3港元')]
# 4550ecce93a5825529dc99f09cab9ad8
# [('公司名称', '中行某市分行'), ('约谈机构', '银保监局'), ('披露时间', '今天上午')]
# [('公司名称', '中行某市分行'), ('公司名称', '中行长三角地区'), ('约谈机构', '当地银保监局'), ('被约谈时间', '今天上午')]
# 57f7010f6177bea90e94b14be1c988f0
# [('股票简称', '金字火腿'), ('减持方', '夏璠林'), ('交易股票/股份数量', '不超过 41.00万'), ('交易股票/股份数量', '不超76.87'), ('减持方', '王启辉'), ('交易股票/股份数量', '不超过4891.57万'), ('减持部分占总股本比例', '0.0419%'), ('减持方', '施延军'), ('减持方', '薛长煌'), ('披露时间', '10月22日晚间'), ('减持部分占总股本比例', '5%'), ('减持部分占总股本比例', '0.0786%'), ('减持方', '施雄飚')]
# [('股票简称', '金字火腿'), ('减持方', '夏璠林'), ('交易股票/股份数量', '不超过 41.00万'), ('减持方', '实控人高管火线'), ('减持部分占总股本比例', '5.12%'), ('交易股票/股份数量', '不超76.87'), ('披露时间', '10月22日晚间'), ('减持方', '王启辉'), ('交易股票/股份数量', '不超过4891.57万'), ('减持方', '施延军'), ('减持方', '薛长煌'), ('减持方', '高高管火线'), ('减持部分占总股本比例', '5%'), ('减持部分占总股本比例', '0.0786%'), ('减持方', '施雄飚')]
# 62d4c9cb539dab354faf591b6fe96952
# [('披露时间', '3月19日'), ('破产公司', '太阳马戏娱乐集团')]
# []
# 5ef130d81fcde399d9d123e4c675fb12
# [('增持方', '高管'), ('交易金额', '168.63万元'), ('股票简称', '成都银行'), ('增持方', '非独立董事'), ('交易股票/股份数量', '20.07万'), ('交易完成时间', '截止今日'), ('披露时间', '近日')]
# [('增持方', '高管'), ('交易金额', '168.63万元'), ('增持方', '12名非独立董事'), ('交易金额', '不低于133.43万元'), ('股票简称', '成都银行'), ('交易金额', '168万'), ('交易金额', '311.01亿元'), ('增持方', '非非独立董事'), ('增持方', '高高管'), ('交易股票/股份数量', '20.07万'), ('交易完成时间', '截止今日'), ('披露时间', '近日')]
# e6160a3c31f3f4b4c879ff0bc32bd025
# [('披露日期', '7月24日'), ('任职公司', '北京沃芽科技有限公司'), ('高管姓名', '龚玥婷'), ('高管姓名', '郑建强'), ('变动类型', '接任'), ('高管职位', '监事'), ('变动类型', '卸任')]
# [('变动后公司名称', '京沃芽科技有限公司'), ('高管职位', '法定代表人'), ('任职公司', '上海滴滴沃芽科技有限公司'), ('变动后职位', '法定代表人'), ('变动后职位', '执行董事'), ('任职公司', '北京沃芽科技有限公司'), ('高管姓名', '龚玥婷'), ('高管姓名', '郑建强'), ('任职公司', '北京沃芽科技有公'), ('变动类型', '接任'), ('高管职位', '监事'), ('变动类型', '卸任'), ('事件时间', '7月24日'), ('高管职位', '执行董事'), ('任职公司', '苏州沃')]
# a0e9cf0b693b1404c47acda576478d83
# [('交易金额', '48亿元人民币'), ('收购方', '苏宁国际'), ('被收购方', '家乐福中国'), ('披露时间', '两个月前'), ('收购标的', '80%股份')]
# [('被收购方', '荷兰家乐福中国控股公司'), ('被收购方', '家乐福'), ('交易金额', '48亿元人民币'), ('收购方', '苏宁国际'), ('披露时间', '8月26日晚'), ('收购标的', '80%股份')]
# 17618ee5a8093a0d3faa3745a1711db2
# [('回购股份数量', '550万'), ('回购完成时间', '2020年5月8日'), ('披露时间', '5月8日'), ('交易金额', '3234.54万港元'), ('每股交易价格', '5.80-5.93港元')]
# [('回购股份数量', '550万'), ('回购完成时间', '2020年5月8日'), ('交易金额', '3234.54万港元'), ('披露时间', '5月8日'), ('每股交易价格', '5.80-5.93港元'), ('回购方', '兖州煤业股份')]
# 5eb169e8a7709e83a3844aab9e5bd618
# [('质押物所属公司', '中青宝'), ('质押股票/股份数量', '约为366万'), ('质押方', '深圳市宝德投资控股有限公司'), ('质押物占持股比', '7.91%'), ('披露时间', '5月13日晚间'), ('质押物', '股份'), ('质权方', '华泰联合证券有限责任公司')]
# [('质押物所属公司', '中青宝'), ('质押股票/股份数量', '约为366万'), ('质押物占持股比', '7.91%'), ('质押股票/股份数量', '366万'), ('披露时间', '5月13日晚间'), ('质押方', '深圳市宝德投资控股有限公司'), ('质押物', '股份'), ('质权方', '华泰联合证券有限责任公司')]
# 6cb030f29839a21abb1a5afced823d7f
# [('回购股份数量', '294.9万'), ('披露时间', '2020年9月18日'), ('每股交易价格', '1.71-1.72港元'), ('交易金额', '506.28万港元'), ('回购完成时间', '2020年9月18日'), ('回购方', '雷蛇')]
# [('每股交易价格', '1.71-1.72港'), ('回购股份数量', '294.9万'), ('交易金额', '506.28万港元'), ('回购完成时间', '2020年9月18日'), ('回购方', '雷蛇')]
# bee0efc875a700f4cc19cadabf62c750
# [('中标公司', '海伦哲'), ('中标金额', '近日'), ('中标标的', '军品消防车项目'), ('披露日期', '2019年4月2日'), ('招标方', '军方某部'), ('中标金额', '12,697.98万元')]
# [('中标公司', '海伦哲'), ('中标标的', '军品消防车项目'), ('披露日期', '2019年4月2日'), ('披露日期', '8月9日'), ('招标方', '军方某部'), ('中标金额', '1.27亿元'), ('中标金额', '12,697.98万元'), ('中标日期', '近日')]
# a1b8886107b089c27d5312bf77f73f95
# [('收购完成时间', '2019年11月'), ('交易金额', '740亿美元'), ('被收购方', '夏尔'), ('收购完成时间', '2019年1月'), ('交易金额', '620亿美元'), ('披露时间', '2019年1月'), ('收购方', '百时美施贵宝'), ('被收购方', '新基公司'), ('收购方', '武田')]
# []
# da952dae7579b776d6d492dd370f4bf0
# [('交易完成时间', '本减持计划公告之日起15个交易日后的6个月内'), ('减持部分占总股本比例', '3.03%'), ('减持方', '世纪维盛'), ('股票简称', '圣邦股份'), ('交易股票/股份数量', '不超过470.33万')]
# [('交易完成时间', '本减持计划公告之日起15个交易日后的6个月'), ('交易股票/股份数量', '不超过470.33万'), ('减持方', '世纪维盛'), ('股票简称', '圣邦股份')]
# f1cb7078b587eb7d3a66108e304abd36
# [('中标日期', '近日'), ('中标公司', '上海市浦东新区建设（集团）有限公司'), ('中标金额', '10.14亿元')]
# [('中标标的', '重大工程项目'), ('中标公司', '上海市浦东新区建设（集团）有限公司'), ('中标金额', '10.14亿元'), ('中标日期', '近日'), ('中标日期', '近期')]
# 6b8105ebc41d2f587aec328dd87f82bc
# [('中标日期', '日前'), ('中标公司', '中国西电集团'), ('中标标的', '西部电网改造EPC工程项目LOT1'), ('招标方', '乌克兰国家电网公司')]
# [('中标日期', '日前'), ('中标公司', '中国西电集团'), ('招标方', '乌克兰国家电网公司'), ('中标标的', '西部电网改造EPC工程项目OT1'), ('中标标的', 'LOT1')]
# 94e281cf1486f22d3c97c9d74c8060c8
# [('披露日期', '7月25日晚间'), ('中标金额', '约4.22亿元'), ('中标标的', '生活垃圾焚烧发电项目'), ('招标方', '辉县市'), ('中标公司', '城发环境')]
# [('披露日期', '7月25日晚间'), ('中标标的', '辉县市生活垃圾焚烧发电项目'), ('中标金额', '约4.22亿元'), ('中标公司', '城发环境')]
# 5cfed79f3efdf2827b12970d4bce6479
# [('质押方', '国安通信'), ('质权方', '兴业银行股份有限公司北京朝阳支行'), ('质押物', '无限售条件流通股'), ('披露时间', '7月13日晚间'), ('事件时间', '2020年7月10日'), ('质押股票/股份数量', '500万'), ('质押物所属公司', '江苏有线')]
# [('减持方', '李茂洪'), ('股票简称', '弘亚数控'), ('交易股票/股份数量', '432万'), ('披露时间', '前一天'), ('减持部分占总股本比例', '不超公司总股本的2%')]
# [('减持方', '李茂洪'), ('减持部分占总股本比例', '不超公司总股本的%'), ('减持部分占总股本比例', '2%'), ('股票简称', '弘亚数控'), ('交易股票/股份数量', '432万'), ('披露时间', '11')]
# baa88f72437e3a00639709eaa9a41040
# [('上市公司', '康德莱医械'), ('证券代码', '01501'), ('环节', '正式上市')]
# [('事件时间', '次日'), ('证券代码', '01501)'), ('上市公司', '康德莱医械'), ('环节', '正式上市'), ('披露时间', '日')]
# d966584111dbc344e4df47da9a36a67e
# [('中标公司', '中铁十一局集团有限公司'), ('中标公司', '云南建投第七建设有限公司'), ('中标公司', '云南工程建设总承包股份有限公司'), ('披露日期', '8月28日晚间'), ('中标公司', 'ST云投'), ('中标公司', '云南云投建设有限公司'), ('中标标的', '云南省重大传染病救治能力和疾控机构核心能力提升工程工程总承包（FEPC）'), ('中标金额', '80.14亿元')]
# [('中标公司', '中铁十一局集团有限公司'), ('中标公司', '云南建投第七建设有限公司'), ('中标公司', '云南工程建设总承包股份有限公司'), ('中标标的', '云南省重大传染病救治能力和疾控机构核心能力提升工程工程总承包（FEPC）”'), ('披露日期', '8月28日晚间'), ('中标公司', 'ST云投'), ('中标公司', '云南云投建设有限公司')]
# 745cf47e22d121da288f6ecb8da08173
# [('质权方', '上海浦东发展银行股份有限公司深圳分行'), ('质押物占持股比', '57.36%'), ('披露时间', '8月8日'), ('质押物所属公司', '麦格米特'), ('质押方', '李升付'), ('质押股票/股份数量', '12,530,000'), ('质押物占持股比', '35.98%'), ('质押物', '股份'), ('事件时间', '截至本公告披露日'), ('质押物占总股比', '2.67%'), ('质押股票/股份数量', '786万')]
# [('质权方', '上海浦东发展银行股份有限公司深圳分行'), ('质押物占持股比', '57.36%'), ('披露时间', '8月8日'), ('质押物所属公司', '麦格米特'), ('事件时间', '截'), ('质押方', '李升付'), ('质押股票/股份数量', '12,530,000'), ('质押物占持股比', '35.98%'), ('质押物', '股份'), ('事件时间', '截至本公告披露日'), ('质押物占总股比', '2.67%'), ('质押股票/股份数量', '786万')]
# f7234e3c850238317266871b9a80ce46
# [('减持部分占总股本比例', '不超过5.91%'), ('交易股票/股份数量', '不超过2518.04万'), ('股票简称', '天泽信息'), ('交易完成时间', '15个交易日后的6个月内'), ('减持方', '孙伯荣'), ('披露时间', '6月9日晚间')]
# [('减持部分占总股本比例', '6%'), ('减持部分占总股本比例', '不超过5.91%'), ('减持方', '中住集团'), ('交易股票/股份数量', '不超过2518.04万'), ('股票简称', '英可瑞'), ('股票简称', '天铁股份'), ('股票简称', '旗'), ('交易完成时间', '115个交易日后的6个月内'), ('股票简称', '天泽信息'), ('交易完成时间', '6月9日晚间'), ('减持部分占总股本比例', '不超过6%'), ('减持方', '孙伯荣'), ('披露时间', '6月9日晚间'), ('股票简称', '宣'), ('股票简称', '捷捷微电')]
# fd32290984416e3f4697b5e647beaacd
# [('披露时间', '2020年6月23日'), ('回购方', '浩云科技股份有限公司'), ('回购完成时间', '2020年6月22日'), ('回购股份数量', '332,037')]
# [('回购方', '浩云科技股份有限公司'), ('回购股份数量', '332,037'), ('披露时间', '2020年7月1')]
# c151f85ef79ca6f4a270badc6ce7c146
# [('中标日期', '日前'), ('招标方', '中原农业保险股份有限公司'), ('披露日期', '7月10日'), ('中标公司', '北京令才科技有限公司'), ('中标标的', '费用智能审核与RPA财务标准化流程系统采购项目')]
# [('中标标的', 'RRPA财务标准化流程系统采购项目'), ('中标日期', '日前'), ('招标方', '中原农业保险股份有限公司'), ('披露日期', '7月10日'), ('中标公司', '北京令才科技有限公司'), ('中标标的', '费用智能审核与RPA财务标准化流程系统采购项目')]

# %%
count
# Out:
# 643

# %%
for d_json in sentences_role_data:
    if d_json['id'] == '28488b2dd838cfdf73bba1670c5efd0c':
        r_ret = extract_result_multilabel(d_json["text"], d_json["pred"]["labels"])
        print(d_json["text"])
#         print(d_json["pred"]["labels"][d_json["text"].find("8-10美元"):d_json["text"].find("8-10美元")+1])
#         print(d_json["pred"]["probs"][d_json["text"].find("8-10美元")+1:d_json["text"].find("8-10美元")+2][0])
        print(d_json["pred"]["labels"])
        print(r_ret)
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-1-cce9164a75ac> in <module>
# ----> 1 for d_json in sentences_role_data:
#       2     if d_json['id'] == '28488b2dd838cfdf73bba1670c5efd0c':
#       3         r_ret = extract_result_multilabel(d_json["text"], d_json["pred"]["labels"])
#       4         print(d_json["text"])
#       5 #         print(d_json["pred"]["labels"][d_json["text"].find("8-10美元"):d_json["text"].find("8-10美元")+1])
#
# NameError: name 'sentences_role_data' is not defined

# %%
def evaluate_mergedata(predict_doc, true_merge_dataset_path):
    true_data_list = []
    with open(true_merge_dataset_path, 'r', encoding='utf-8') as f:
        for line in f:
            json_data = json.loads(line)
            true_data_list.append(json_data)
    predict_mapping_dict = {}
    for doc in predict_doc:
        predict_mapping_dict[doc['id']] = doc
    count_predict = 0
    count_true = 0
    count_correct = 0
    for true_data in true_data_list:
        if true_data['id'] not in predict_mapping_dict:
            if 'event_list' in true_data:
                print('error: ', true_data)
        else:
            predict_doc = predict_mapping_dict[true_data['id']]
            pred_data_set = set([(pred_event['event_type'], argument['role'], argument['argument']) for pred_event in predict_doc.get('event_list', []) for argument in pred_event.get('arguments')])
            true_data_set = set([(true_event['event_type'], argument['role'], argument['argument']) for true_event in true_data.get('event_list', []) for argument in true_event.get('arguments')])
            count_predict += len(list(pred_data_set))
            count_true += len(list(true_data_set))
            count_correct += len(list(pred_data_set & true_data_set))
    p = count_correct / max(1, count_predict)  # precision
    r = count_correct / max(1, count_true)  # recall
    f1 = 2 * r * p / max(1e-9, r + p) # f1 score
    s = count_true  # support

    print("{:>10}{:>10}{:>10}{:>10}\n".format("precision", "recall", "f1-score", "support"))
    formatter = "{:>10.3f}{:>10.3f}{:>10.3f}{:>10d}".format
    print(formatter(p, r, f1, s))
    print("")

# %%
evaluate_mergedata(doc_pred, duee_fin_dev_path)
# Out:
#  precision    recall  f1-score   support
#
#      0.698     0.734     0.716      7061
